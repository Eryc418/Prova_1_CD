# %% [markdown]
# <a href="https://colab.research.google.com/github/Eryc418/Prova_1_CD/blob/main/Prova_Unidade_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bibliotecas necessárias

# %%
import pandas as pd
import numpy as np

import requests as rq
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ### Obtendo dados e salvando em um objeto BeautifulSoup

# %%
inserir = input("Digite o conteúdo que deseja buscar no StackOverflow: ")
url = rq.get('https://stackoverflow.com/questions/tagged/' + inserir) # URL + Palavra chave que será pesquisada
soup = BeautifulSoup(url.text,'html.parser') #objeto BeautifulSoup
# Out:
# Digite o conteúdo que deseja buscar no StackOverflow: java

# %%
print(soup) # Conteúdo da Página
# Out:
# <!DOCTYPE html>
#
# <html class="html__responsive ">
# <head>
# <title>Newest 'java' Questions - Stack Overflow</title>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" rel="shortcut icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="image_src"/>
# <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="website" property="og:type">
# <meta content="https://stackoverflow.com/questions/tagged/java" property="og:url"/>
# <meta content="Stack Overflow" property="og:site_name"/>
# <meta content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" itemprop="image primaryImageOfPage" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="stackoverflow.com" name="twitter:domain"/>
# <meta content="Newest 'java' Questions" itemprop="name" name="twitter:title" property="og:title"/>
# <meta content="Stack Overflow | The World’s Largest Online Community for Developers" itemprop="description" name="twitter:description" property="og:description"/>
# <script id="webpack-public-path" type="text/uri-list">https://cdn.sstatic.net/</script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# <script async="" src="https://cdn.sstatic.net/Js/third-party/stacks/stacks.min.js?v=587378ef592b"></script>
# <script src="https://cdn.sstatic.net/Js/stub.en.js?v=17e20b4b4731"></script>
# <link href="https://cdn.sstatic.net/Shared/stacks.css?v=15473555f232" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=de9fb8b74f61" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/secondary.css?v=9532f59e9743" rel="stylesheet" type="text/css"/>
# <link href="/feeds/tag?tagnames=java&amp;sort=newest" rel="alternate" title="Newest java questions feed" type="application/atom+xml">
# <link href="https://cdn.sstatic.net/Shared/Channels/channels.css?v=47a5e0f03c81" rel="stylesheet" type="text/css"/>
# <script>
#         StackExchange.init({"locale":"en","serverTime":1639187528,"routeName":"Questions/ListByTag","stackAuthUrl":"https://stackauth.com","networkMetaHostname":"meta.stackexchange.com","site":{"name":"Stack Overflow","description":"Q&A for professional and enthusiast programmers","isNoticesTabEnabled":true,"enableNewTagCreationWarning":true,"insertSpaceAfterNameTabCompletion":false,"id":1,"cookieDomain":".stackoverflow.com","childUrl":"https://meta.stackoverflow.com","negativeVoteScoreFloor":null,"enableSocialMediaInSharePopup":true,"protocol":"https"},"user":{"fkey":"c8502838d06feccb2607165cf1402428147ff3909b480d87cf7341f1c14d95d6","tid":"7f474628-17eb-09fe-d8e3-020dee5eb882","rep":0,"isAnonymous":true,"isAnonymousNetworkWide":true},"events":{"postType":{"question":1},"postEditionSection":{"title":1,"body":2,"tags":3}},"story":{"minCompleteBodyLength":75,"likedTagsMaxLength":300,"dislikedTagsMaxLength":300},"jobPreferences":{"maxNumDeveloperRoles":2,"maxNumIndustries":4},"svgIconPath":"https://cdn.sstatic.net/Img/stacks-icons","svgIconHash":"d9a8a2f90b12"}, {"userProfile":{"openGraphAPIKey":"4a307e43-b625-49bb-af15-ffadf2bda017"},"userMessaging":{"showNewFeatureNotice":true},"tags":{},"subscriptions":{"defaultBasicMaxTrueUpSeats":250,"defaultFreemiumMaxTrueUpSeats":50,"defaultMaxTrueUpSeats":1000},"snippets":{"renderDomain":"stacksnippets.net","snippetsEnabled":true},"site":{"allowImageUploads":true,"enableImgurHttps":true,"enableUserHovercards":true,"forceHttpsImages":true,"styleCode":true},"questions":{"enableDeleteVoteRetraction":true,"enableQuestionTitleLengthLiveWarning":true,"maxTitleSize":150,"questionTitleLengthStartLiveWarningChars":50},"intercom":{"appId":"inf0secd","hostBaseUrl":"https://stacksnippets.net"},"paths":{},"monitoring":{"clientTimingsAbsoluteTimeout":30000,"clientTimingsDebounceTimeout":1000},"mentions":{"maxNumUsersInDropdown":50},"markdown":{"enableTables":true},"legal":{"oneTrustConfigId":"c3d9f1e3-55f3-4eba-b268-46cee4c6789c"},"flags":{"allowRetractingCommentFlags":true,"allowRetractingFlags":true},"elections":{"opaVoteResultsBaseUrl":"https://www.opavote.com/results/"},"comments":{},"accounts":{"currentPasswordRequiredForChangingStackIdPassword":true}});
#         StackExchange.using.setCacheBreakers({"js/adops.en.js":"6da43f5e0a84","js/ask.en.js":"7ff9a9068fd6","js/begin-edit-event.en.js":"dd955babf04d","js/copy-transpiled.en.js":"51a328039b9e","js/cm.en.js":"75dcb3984aa6","js/events.en.js":"716b95b6374c","js/explore-qlist.en.js":"2b1f34938b8b","js/full-anon.en.js":"70f6560d9b2d","js/full.en.js":"3ffc71953b78","js/help.en.js":"2b4af0ad5c0c","js/highlightjs-loader.en.js":"0026055c3561","js/inline-tag-editing.en.js":"c0cbc31e5702","js/keyboard-shortcuts.en.js":"5ffcb8f50446","js/markdown-it-loader.en.js":"dfad6619ffdd","js/modElections.en.js":"5114e9d6e1cf","js/mobile.en.js":"320aa423a438","js/moderator.en.js":"e83e4187e0ec","js/postCollections-transpiled.en.js":"4b407fb73054","js/post-validation.en.js":"569f8b05c015","js/question-editor.en.js":"","js/review-v2-transpiled.en.js":"b7e059a9fe83","js/revisions.en.js":"839f528889ff","js/stacks-editor.en.js":"04f5018456af","js/tageditor.en.js":"825c9597ce2d","js/tageditornew.en.js":"5215bc97928a","js/tagsuggestions.en.js":"1bcff7d98f97","js/unlimited-transpiled.en.js":"7ed67670b600","js/wmd.en.js":"4689e82c85e7","js/snippet-javascript-codemirror.en.js":"209508902bf4"});
#         StackExchange.using("gps", function() {
#              StackExchange.gps.init(false);
#         });
#     </script>
# <noscript id="noscript-css"><style>body,.top-bar{margin-top:1.9em}</style></noscript>
# </link></meta></head>
# <body class="tagged-questions-page unified-theme">
# <div id="notify-container"></div>
# <div id="custom-header"></div>
# <header class="top-bar js-top-bar top-bar__network">
# <div class="wmx12 mx-auto d-flex ai-center h100" role="menubar">
# <div class="-main flex--item">
# <a aria-controls="left-sidebar" aria-expanded="false" aria-haspopup="true" class="left-sidebar-toggle p0 ai-center jc-center js-left-sidebar-toggle" href="#" role="menuitem"><span class="ps-relative"></span></a>
# <div class="topbar-dialog leftnav-dialog js-leftnav-dialog dno">
# <div class="left-sidebar js-unpinned-left-sidebar" data-can-be="left-sidebar" data-is-here-when="sm"></div>
# </div>
# <a class="-logo js-gps-track" data-gps-track="top_nav.click({is_current:false, location:5, destination:8})" href="https://stackoverflow.com">
# <span class="-img _glyph">Stack Overflow</span>
# </a>
# </div>
# <ol class="list-reset d-flex gs4" role="presentation">
# <li class="flex--item md:d-none">
# <a class="-marketing-link js-gps-track" data-ga='["top navigation","about menu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:7})" href="/company">About</a>
# </li>
# <li class="flex--item">
# <a aria-controls="products-popover" class="-marketing-link js-gps-track js-products-menu" data-action="s-popover#toggle" data-controller="s-popover" data-ga='["top navigation","products menu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:1})" data-s-popover-placement="bottom" data-s-popover-toggle-class="is-selected" href="#">
#                         Products
#                     </a>
# </li>
# <li class="flex--item md:d-none">
# <a class="-marketing-link js-gps-track" data-ga='["top navigation","learn more - teams",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:7})" href="/teams">For Teams</a>
# </li>
# </ol>
# <div aria-hidden="true" class="s-popover ws2 mtn2 p0" id="products-popover" role="menu">
# <div class="s-popover--arrow"></div>
# <ol class="list-reset s-anchors s-anchors__inherit">
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","public qa submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:2})" href="/questions">
# <span class="fs-body1 d-block">Stack Overflow</span>
# <span class="fs-caption d-block fc-light">Public questions &amp; answers</span>
# </a>
# </li>
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","teams submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:3})" href="/teams">
# <span class="fs-body1 d-block">Stack Overflow for Teams</span>
# <span class="fs-caption d-block fc-light">Where developers &amp; technologists share private knowledge with coworkers</span>
# </a>
# </li>
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","jobs submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:9})" href="/jobs?so_source=ProductsMenu&amp;so_medium=StackOverflow">
# <span class="fs-body1 d-block">Jobs</span>
# <span class="fs-caption d-block fc-light">Programming &amp; related technical career opportunities</span>
# </a>
# </li>
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","talent submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:5})" href="https://stackoverflow.com/talent">
# <span class="fs-body1 d-block">Talent</span>
# <span class="fs-caption d-block fc-light">Recruit tech talent &amp; build your employer brand</span>
# </a>
# </li>
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","advertising submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:6})" href="https://stackoverflow.com/advertising">
# <span class="fs-body1 d-block">Advertising</span>
# <span class="fs-caption d-block fc-light">Reach developers &amp; technologists worldwide</span>
# </a>
# </li>
# <li class="bg-black-025 bt bc-black-075 py6 px6 bbr-md">
# <a class="fc-light d-block py6 px6 h:fc-black-800 js-gps-track" data-ga='["top navigation","about submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:7})" href="/company">About the company</a>
# </li>
# </ol>
# </div>
# <form action="/search" autocomplete="off" class="flex--item fl-grow1 searchbar px12 js-searchbar " id="search" role="search">
# <div class="ps-relative">
# <input aria-controls="top-search" aria-label="Search" autocomplete="off" class="s-input s-input__search js-search-field " data-action="focus-&gt;s-popover#show" data-controller="s-popover" data-s-popover-placement="bottom-start" maxlength="240" name="q" placeholder="Search…" type="text" value="[java]"/>
# <svg aria-hidden="true" class="s-input-icon s-input-icon__search svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18"><path d="m18 16.5-5.14-5.18h-.35a7 7 0 10-1.19 1.19v.35L16.5 18l1.5-1.5ZM12 7A5 5 0 112 7a5 5 0 0110 0Z"></path></svg>
# <div class="s-popover p0 wmx100 wmn4 sm:wmn-initial js-top-search-popover" id="top-search" role="menu">
# <div class="s-popover--arrow"></div>
# <div class="js-spinner p24 d-flex ai-center jc-center d-none">
# <div class="s-spinner s-spinner__sm fc-orange-400">
# <div class="v-visible-sr">Loading…</div>
# </div>
# </div>
# <span class="v-visible-sr js-screen-reader-info"></span>
# <div class="js-ac-results overflow-y-auto hmx3 d-none"></div>
# <div aria-describedby="Tips for searching" class="js-search-hints"></div>
# </div>
# </div>
# </form>
# <ol class="overflow-x-auto ml-auto -secondary d-flex ai-center list-reset h100 user-logged-out" role="presentation">
# <li class="-item searchbar-trigger"><a aria-controls="search" aria-haspopup="true" aria-label="Search" class="-link js-searchbar-trigger" href="#" role="button" title="Click to show search"><svg aria-hidden="true" class="svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18"><path d="m18 16.5-5.14-5.18h-.35a7 7 0 10-1.19 1.19v.35L16.5 18l1.5-1.5ZM12 7A5 5 0 112 7a5 5 0 0110 0Z"></path></svg></a></li>
# <li class="-ctas">
# <a class="login-link s-btn s-btn__filled py8 js-gps-track" data-ga='["top navigation","login button click",null,null,null]' data-gps-track="login.click" href="https://stackoverflow.com/users/login?ssrc=head&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2ftagged%2fjava" rel="nofollow">Log in</a>
# <a class="login-link s-btn s-btn__primary py8" data-ga='["sign up","Sign Up Navigation","Header",null,null]' href="https://stackoverflow.com/users/signup?ssrc=head&amp;returnurl=%2fusers%2fstory%2fcurrent" rel="nofollow">Sign up</a>
# </li>
# <li class="js-topbar-dialog-corral" role="presentation">
# <div class="topbar-dialog siteSwitcher-dialog dno" role="menu">
# <div class="header fw-wrap">
# <h3 class="flex--item">
# <a href="https://stackoverflow.com">current community</a>
# </h3>
# <div class="flex--item fl1">
# <div class="ai-center d-flex jc-end">
# <button aria-label="Close" class="js-close-button s-btn s-btn__muted p0 ml8 d-none sm:d-block" type="button">
# <svg aria-hidden="true" class="svg-icon iconClear" height="18" viewbox="0 0 18 18" width="18"><path d="M15 4.41 13.59 3 9 7.59 4.41 3 3 4.41 7.59 9 3 13.59 4.41 15 9 10.41 13.59 15 15 13.59 10.41 9 15 4.41Z"></path></svg>
# </button>
# </div>
# </div>
# </div>
# <div class="modal-content bg-powder-050 current-site-container">
# <ul class="current-site ">
# <li class="d-flex">
# <div class="fl1">
# <a class="current-site-link site-link js-gps-track d-flex gs8 gsx" data-gps-track="site_switcher.click({ item_type:3 })" data-id="1" href="https://stackoverflow.com">
# <div class="favicon favicon-stackoverflow site-icon flex--item" title="Stack Overflow"></div>
# <span class="flex--item fl1">
#             Stack Overflow
#         </span>
# </a>
# </div>
# <div class="related-links">
# <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:14 })" href="https://stackoverflow.com/help">help</a>
# <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:6 })" href="https://chat.stackoverflow.com/?tab=site&amp;host=stackoverflow.com">chat</a>
# </div>
# </li>
# <li class="related-site d-flex">
# <div class="L-shaped-icon-container">
# <span class="L-shaped-icon"></span>
# </div>
# <a class=" site-link js-gps-track d-flex gs8 gsx" data-gps-track="site.switch({ target_site:552, item_type:3 }),site_switcher.click({ item_type:4 })" data-id="552" href="https://meta.stackoverflow.com">
# <div class="favicon favicon-stackoverflowmeta site-icon flex--item" title="Meta Stack Overflow"></div>
# <span class="flex--item fl1">
#             Meta Stack Overflow
#         </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="header" id="your-communities-header">
# <h3>
# your communities            </h3>
# </div>
# <div class="modal-content" id="your-communities-section">
# <div class="call-to-login">
# <a class="login-link js-gps-track" data-gps-track="site_switcher.click({ item_type:10 })" href="https://stackoverflow.com/users/signup?ssrc=site_switcher&amp;returnurl=%2fusers%2fstory%2fcurrent">Sign up</a> or <a class="login-link js-gps-track" data-gps-track="site_switcher.click({ item_type:11 })" href="https://stackoverflow.com/users/login?ssrc=site_switcher&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2ftagged%2fjava">log in</a> to customize your list.                </div>
# </div>
# <div class="header">
# <h3><a href="https://stackexchange.com/sites">more stack exchange communities</a>
# </h3>
# <a class="float-right" href="https://stackoverflow.blog">company blog</a>
# </div>
# <div class="modal-content">
# <div class="child-content"></div>
# </div>
# </div>
# </li>
# </ol>
# </div>
# </header>
# <script>
#         StackExchange.ready(function () { StackExchange.topbar.init(); });
#         StackExchange.scrollPadding.setPaddingTop(50, 10);
#     </script>
# <div class="container">
# <div class="left-sidebar js-pinned-left-sidebar ps-relative" data-is-here-when="md lg" id="left-sidebar">
# <div class="left-sidebar--sticky-container js-sticky-leftnav">
# <nav role="navigation">
# <ol class="nav-links">
# <li class="">
# <a aria-controls="" class="pl8 js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:8})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                             Home
#                         </div>
# </div>
# </a>
# </li>
# <li>
# <ol class="nav-links">
# <li class="fs-fine tt-uppercase ml8 mt16 mb4 fc-light">Public</li>
# <li class=" youarehere">
# <a aria-controls="" class="pl8 js-gps-track nav-links--link -link__with-icon" data-controller="" data-gps-track="top_nav.click({is_current:true, location:5, destination:1})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/questions" id="nav-questions">
# <svg aria-hidden="true" class="svg-icon iconGlobe" height="18" viewbox="0 0 18 18" width="18"><path d="M9 1C4.64 1 1 4.64 1 9c0 4.36 3.64 8 8 8 4.36 0 8-3.64 8-8 0-4.36-3.64-8-8-8ZM8 15.32a6.46 6.46 0 01-4.3-2.74 6.46 6.46 0 01-.93-5.01L7 11.68v.8c0 .88.12 1.32 1 1.32v1.52Zm5.72-2c-.2-.66-1-1.32-1.72-1.32h-1v-2c0-.44-.56-1-1-1H6V7h1c.44 0 1-.56 1-1V5h2c.88 0 1.4-.72 1.4-1.6v-.33a6.45 6.45 0 013.83 4.51 6.45 6.45 0 01-1.51 5.73v.01Z"></path></svg> <span class="-link--channel-name">Questions</span>
# </a>
# </li>
# <li class="">
# <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:2})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/tags" id="nav-tags">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                             Tags
#                         </div>
# </div>
# </a>
# </li>
# <li class="">
# <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:3})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/users" id="nav-users">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                             Users
#                         </div>
# </div>
# </a>
# </li>
# <li class="d-flex ml8 mt16 mb4 jc-space-between">
# <div class="flex--item tt-uppercase tt-uppercase fs-fine fc-light">Collectives</div>
# <div class="flex--item fs-fine fc-light">
# <a aria-controls="popover-discover-collectives" class="s-link s-link__inherit mr8 js-gps-track" data-action="s-popover#toggle" data-controller="s-popover" data-gps-track="top_nav.click({is_current:false, location:5, destination:17})" data-s-popover-placement="top" data-s-popover-toggle-class="is-selected" href="javascript:void(0)" role="button">
# <svg aria-hidden="true" class="svg-icon iconInfoSm" height="14" viewbox="0 0 14 14" width="14"><path d="M7 1a6 6 0 110 12A6 6 0 017 1Zm1 10V6H6v5h2Zm0-6V3H6v2h2Z"></path></svg>
# </a>
# </div>
# </li>
# <li class="">
# <a aria-controls="" class="pl8 ai-center js-gps-track nav-links--link -link__with-icon" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:18})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/collectives" id="nav-collective-discover">
# <svg aria-hidden="true" class="mt-auto fc-orange-400 svg-icon iconStarVerified" height="18" viewbox="0 0 18 18" width="18"><path d="M9.86.89a1.14 1.14 0 00-1.72 0l-.5.58c-.3.35-.79.48-1.23.33l-.72-.25a1.14 1.14 0 00-1.49.85l-.14.76c-.1.45-.45.8-.9.9l-.76.14c-.67.14-1.08.83-.85 1.49l.25.72c.15.44.02.92-.33 1.23l-.58.5a1.14 1.14 0 000 1.72l.58.5c.35.3.48.79.33 1.23l-.25.72c-.23.66.18 1.35.85 1.49l.76.14c.45.1.8.45.9.9l.14.76c.14.67.83 1.08 1.49.85l.72-.25c.44-.15.92-.02 1.23.33l.5.58c.46.52 1.26.52 1.72 0l.5-.58c.3-.35.79-.48 1.23-.33l.72.25c.66.23 1.35-.18 1.49-.85l.14-.76c.1-.45.45-.8.9-.9l.76-.14c.67-.14 1.08-.83.85-1.49l-.25-.72c-.15-.44-.02-.92.33-1.23l.58-.5c.52-.46.52-1.26 0-1.72l-.58-.5c-.35-.3-.48-.79-.33-1.23l.25-.72a1.14 1.14 0 00-.85-1.49l-.76-.14c-.45-.1-.8-.45-.9-.9l-.14-.76a1.14 1.14 0 00-1.49-.85l-.72.25c-.44.15-.92.02-1.23-.33l-.5-.58Zm-.49 2.67L10.6 6.6c.05.15.19.24.34.25l3.26.22c.36.03.5.48.23.71l-2.5 2.1a.4.4 0 00-.14.4l.8 3.16a.4.4 0 01-.6.44L9.2 12.13a.4.4 0 00-.42 0l-2.77 1.74a.4.4 0 01-.6-.44l.8-3.16a.4.4 0 00-.13-.4l-2.5-2.1a.4.4 0 01.22-.7l3.26-.23a.4.4 0 00.34-.25l1.22-3.03a.4.4 0 01.74 0Z"></path></svg> <span class="-link--channel-name">Explore Collectives</span>
# </a>
# </li>
# <li class="fs-fine tt-uppercase ml8 mt16 mb4 fc-light">Find a Job</li>
# <li class="">
# <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:6})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/jobs?so_medium=StackOverflow&amp;so_source=SiteNav" id="nav-jobs">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                             Jobs
#                         </div>
# </div>
# </a>
# </li>
# <li class="">
# <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:12})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/jobs/companies?so_medium=StackOverflow&amp;so_source=SiteNav" id="nav-companies">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                             Companies
#                         </div>
# </div>
# </a>
# </li>
# </ol>
# </li>
# <li>
# <ol class="nav-links">
# <div class="js-freemium-cta ps-relative">
# <div class="fs-fine tt-uppercase ml8 mt16 mb8 fc-light">Teams</div>
# <div class="bt bl bb bc-black-075 p12 pb6 fc-black-600 blr-sm overflow-hidden">
# <strong class="fc-black-750 mb6">Stack Overflow for Teams</strong>
#         – Collaborate and share knowledge with a private group.
#
#         <img alt="" class="wmx100 mx-auto my8 h-auto d-block" height="114" src="https://cdn.sstatic.net/Img/teams/teams-illo-free-sidebar-promo.svg?v=47faa659a05e" width="139"/>
# <a class="w100 s-btn s-btn__primary s-btn__xs js-gps-track" data-ga='["teams left navigation - anonymous","left nav free cta","stackoverflow.com/teams/create/free",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: 6 })" href="https://stackoverflow.com/teams/create/free?utm_source=so-owned&amp;utm_medium=side-bar&amp;utm_campaign=campaign-38&amp;utm_content=cta">Create a free Team</a>
# <a class="w100 s-btn s-btn__muted s-btn__xs js-gps-track" data-ga='["teams left navigation - anonymous","left nav free cta","stackoverflow.com/teams",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: 5 })" href="https://stackoverflow.com/teams">What is Teams?</a>
# </div>
# </div>
# <li class="d-flex ai-center jc-space-between ml8 mt24 mb4 js-create-team-cta d-none">
# <div class="flex--item tt-uppercase fs-fine fc-light">Teams</div>
# <div class="flex--item">
# <a aria-controls="popover-teams-create-cta" class="s-link p12 fc-black-500 h:fc-black-800 js-gps-track" data-action="s-popover#toggle" data-controller="s-popover" data-ga='["teams left navigation - anonymous","left nav show teams info",null,null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: ShowInfo })" data-s-popover-placement="bottom-start" data-s-popover-toggle-class="is-selected" href="javascript:void(0)" role="button">
# <svg aria-hidden="true" class="svg-icon iconInfoSm" height="14" viewbox="0 0 14 14" width="14"><path d="M7 1a6 6 0 110 12A6 6 0 017 1Zm1 10V6H6v5h2Zm0-6V3H6v2h2Z"></path></svg>
# </a>
# </div>
# </li>
# <li class="ps-relative js-create-team-cta d-none">
# <a class="pl8 js-gps-track nav-links--link" data-ga='["teams left navigation - anonymous","left nav team click","stackoverflow.com/teams/create/free",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: FreemiumTeamsCreateClick })" href="https://stackoverflow.com/teams/create/free?utm_source=so-owned&amp;utm_medium=side-bar&amp;utm_campaign=campaign-38&amp;utm_content=cta" title="Stack Overflow for Teams is a private, secure spot for your organization's questions and answers.">
# <div class="d-flex ai-center">
# <div class="flex--item s-avatar va-middle bg-orange-400">
# <div class="s-avatar--letter mtn1">
# <svg aria-hidden="true" class="svg-icon iconBriefcaseSm" height="14" viewbox="0 0 14 14" width="14"><path d="M4 3a1 1 0 011-1h4a1 1 0 011 1v1h.5c.83 0 1.5.67 1.5 1.5v5c0 .83-.67 1.5-1.5 1.5h-7A1.5 1.5 0 012 10.5v-5C2 4.67 2.67 4 3.5 4H4V3Zm5 1V3H5v1h4Z"></path></svg>
# </div>
# <svg aria-hidden="true" class="native s-avatar--badge svg-icon iconShieldXSm" height="10" viewbox="0 0 9 10" width="9"><path d="M0 1.84 4.5 0 9 1.84v3.17C9 7.53 6.3 10 4.5 10 2.7 10 0 7.53 0 5.01V1.84Z" fill="var(--white)"></path><path d="M1 2.5 4.5 1 8 2.5v2.51C8 7.34 5.34 9 4.5 9 3.65 9 1 7.34 1 5.01V2.5Zm2.98 3.02L3.2 7h2.6l-.78-1.48a.4.4 0 01.15-.38c.34-.24.73-.7.73-1.14 0-.71-.5-1.23-1.41-1.23-.92 0-1.39.52-1.39 1.23 0 .44.4.9.73 1.14.12.08.18.23.15.38Z" fill="var(--black-500)"></path></svg>
# </div>
# <div class="flex--item pl6">
#                                                 Create free Team
#                                             </div>
# </div>
# </a>
# </li>
# </ol>
# </li>
# </ol>
# </nav>
# </div>
# <div aria-hidden="true" class="s-popover ws2" id="popover-discover-collectives" role="menu">
# <div class="s-popover--arrow"></div>
# <div>
# <svg aria-hidden="true" class="fc-orange-500 float-right ml24 svg-spot spotCollective" height="48" viewbox="0 0 48 48" width="48"><path d="M25.5 7a2.5 2.5 0 100-5 2.5 2.5 0 0 0 0 5zM14 18.25c0-.69.56-1.25 1.25-1.25h22.5c.69 0 1.25.56 1.25 1.25V37.5a1 1 0 01-1.6.8l-4.07-3.05a1.25 1.25 0 00-.75-.25H15.25c-.69 0-1.25-.56-1.25-1.25v-15.5zM7 24.5a2.5 2.5 0 11-5 0 2.5 2.5 0 0 1 5 0zM25.5 48a2.5 2.5 0 100-5 2.5 2.5 0 0 0 0 5zM48 24.5a2.5 2.5 0 11-5 0 2.5 2.5 0 0 1 5 0z" opacity=".2"></path><path d="M21 3.5a3.5 3.5 0 117 0 3.5 3.5 0 0 1-7 0zM24.5 2a1.5 1.5 0 100 3 1.5 1.5 0 0 0 0-3zM0 23.5a3.5 3.5 0 117 0 3.5 3.5 0 0 1-7 0zM3.5 22a1.5 1.5 0 100 3 1.5 1.5 0 0 0 0-3zM21 44.5a3.5 3.5 0 117 0 3.5 3.5 0 0 1-7 0zm3.5-1.5a1.5 1.5 0 100 3 1.5 1.5 0 0 0 0-3zm20-23a3.5 3.5 0 100 7 3.5 3.5 0 0 0 0-7zM43 23.5a1.5 1.5 0 113 0 1.5 1.5 0 0 1-3 0zm-23.23-3.14a1 1 0 01-.13 1.4l-2.08 1.74 2.08 1.73a1 1 0 11-1.28 1.54l-2.42-2.02a1.63 1.63 0 010-2.5l2.42-2.02a1 1 0 011.4.13zm7.59 1.41a1 1 0 111.28-1.54l2.42 2.02c.78.65.78 1.85 0 2.5l-2.42 2.02a1 1 0 11-1.28-1.54l2.08-1.73-2.08-1.73zM24.12 18a1 1 0 01.87 1.12l-1 8a1 1 0 11-1.98-.24l1-8a1 1 0 011.11-.87zm-11.87-5C11.01 13 10 14 10 15.25v15.5c0 1.24 1 2.25 2.25 2.25h17.33c.06 0 .11.02.15.05l4.07 3.05a2 2 0 003.2-1.6V15.25c0-1.24-1-2.25-2.25-2.25h-22.5zM12 15.25c0-.14.11-.25.25-.25h22.5c.14 0 .25.11.25.25V34.5l-4.07-3.05a2.2 2.2 0 00-1.35-.45H12.25a.25.25 0 01-.25-.25v-15.5zm7.24-10.68a1 1 0 10-.48-1.94A22.04 22.04 0 002.91 17.7a1 1 0 101.92.58 20.04 20.04 0 0 1 14.4-13.72zm11.05-1.66a1 1 0 00-.58 1.92c6.45 1.92 11.54 7 13.46 13.46a1 1 0 101.92-.58 22.05 22.05 0 0 0-14.8-14.8zM4.57 28.76a1 1 0 00-1.94.48 22.03 22.03 0 0 0 16.13 16.13 1 1 0 1 0 .48-1.94A20.03 20.03 0 014.57 28.76zm40.8.48a1 1 0 10-1.94-.48 20.04 20.04 0 0 1-13.72 14.41 1 1 0 0 0 .58 1.92 22.04 22.04 0 0 0 15.08-15.85z"></path></svg>
# <div class="pt4 fw-bold">Collectives on Stack Overflow</div>
# <p class="my16 fs-caption fc-medium">Find centralized, trusted content and collaborate around the technologies you use most.</p>
# <a class="js-gps-track s-btn s-btn__primary s-btn__xs" data-gps-track="top_nav.click({is_current:false, location:5, destination:18})" href="/collectives">
#                     Learn more
#                 </a>
# </div>
# </div>
# <div aria-hidden="true" class="s-popover" id="popover-teams-create-cta" role="menu">
# <div class="s-popover--arrow"></div>
# <div class="ps-relative overflow-hidden">
# <p class="mb2"><strong>Teams</strong></p>
# <p class="mb12 fs-caption fc-black-400">Q&amp;A for work</p>
# <p class="mb12 fs-caption fc-medium">Connect and share knowledge within a single location that is structured and easy to search.</p>
# <a class="js-gps-track s-btn s-btn__primary s-btn__xs" data-ga='["teams left navigation - anonymous","left nav cta","stackoverflow.com/teams",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: CtaClick })" href="https://stackoverflow.com/teams">
#                     Learn more
#                 </a>
# </div>
# <div class="ps-absolute t8 r8">
# <svg aria-hidden="true" class="fc-orange-500 svg-spot spotPeople" height="48" viewbox="0 0 48 48" width="48"><path d="M13.5 28a4.5 4.5 0 100-9 4.5 4.5 0 0 0 0 9zM7 30a1 1 0 011-1h11a1 1 0 011 1v5h11v-5a1 1 0 011-1h12a1 1 0 011 1v10a2 2 0 01-2 2H33v5a1 1 0 01-1 1H20a1 1 0 01-1-1v-5H8a1 1 0 01-1-1V30zm25-6.5a4.5 4.5 0 109 0 4.5 4.5 0 0 0-9 0zM24.5 34a4.5 4.5 0 100-9 4.5 4.5 0 0 0 0 9z" opacity=".2"></path><path d="M16.4 26.08A6 6 0 107.53 26C5.64 26.06 4 27.52 4 29.45V40a1 1 0 001 1h9a1 1 0 100-2h-4v-7a1 1 0 10-2 0v7H6v-9.55c0-.73.67-1.45 1.64-1.45H16a1 1 0 00.4-1.92zM12 18a4 4 0 110 8 4 4 0 0 1 0-8zm16.47 14a6 6 0 10-8.94 0A3.6 3.6 0 0016 35.5V46a1 1 0 001 1h14a1 1 0 001-1V35.5c0-1.94-1.64-3.42-3.53-3.5zM20 28a4 4 0 118 0 4 4 0 0 1-8 0zm-.3 6h8.6c1 0 1.7.75 1.7 1.5V45h-2v-7a1 1 0 10-2 0v7h-4v-7a1 1 0 10-2 0v7h-2v-9.5c0-.75.7-1.5 1.7-1.5zM42 22c0 1.54-.58 2.94-1.53 4A3.5 3.5 0 0144 29.45V40a1 1 0 01-1 1h-9a1 1 0 110-2h4v-7a1 1 0 112 0v7h2v-9.55A1.5 1.5 0 0040.48 28H32a1 1 0 01-.4-1.92A6 6 0 1142 22zm-2 0a4 4 0 10-8 0 4 4 0 0 0 8 0z"></path><path d="M17 10a1 1 0 011-1h12a1 1 0 110 2H18a1 1 0 01-1-1zm1-5a1 1 0 100 2h12a1 1 0 100-2H18zm-4-4a1 1 0 00-1 1v12a1 1 0 001 1h5.09l4.2 4.2a1 1 0 001.46-.04l3.7-4.16H34a1 1 0 001-1V2a1 1 0 00-1-1H14zm1 12V3h18v10h-5a1 1 0 00-.75.34l-3.3 3.7-3.74-3.75a1 1 0 00-.71-.29H15z" opacity=".35"></path></svg>
# </div>
# </div>
# </div>
# <div class="snippet-hidden" id="content">
# <div id="mainbar">
# <div class="d-flex">
# <div class="d-flex fl1 mb24">
# <h1 class="flex--item fs-headline1 mb0">
# Questions tagged [java]        </h1>
# </div>
# <div class="ml12 aside-cta flex--item print:d-none">
# <a class="ws-nowrap s-btn s-btn__primary" href="/questions/ask">
#         Ask Question
#     </a>
# </div>
# </div>
# <style>
# </style>
# <div class="js-zone-container zone-container-main">
# <div class="everyonelovesstackoverflow everyoneloves__tag-sponsorship theme-light__forced bg-white" id="dfp-tag"></div>
# <div class="js-report-ad-button-container " style="width: 728px"></div>
# </div>
# <div class="mb24">
# <p>
# Java is a high-level object oriented programming language. Use this tag when you're having problems using or understanding the language itself. This tag is frequently used alongside other tags for libraries and/or frameworks used by Java developers.                    </p>
# <div class=" d-flex gs12 jc-space-between ai-center fw-wrap">
# <div class="flex--item">
# <ul class="d-flex gs12 list-ls-none fw-wrap">
# <li class="flex--item">
# <a href="/tags/java/info" title="Tag wiki">Learn more…</a>
# </li>
# <li class="flex--item">
# <a href="/tags/java/topusers" title="Top answerers and askers in this tag">Top users</a>
# </li>
# <li class="flex--item">
# <a href="/tags/java/synonyms" title="Common, alternate spellings or phrasings for this tag">Synonyms (11)</a>
# </li>
# <li class="flex--item">
# <a href="/jobs/developer-jobs-using-java?med=site-ui&amp;ref=tag-page_java" title="Find yourself a job">java jobs</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <script>
#     StackExchange.ready(function () {
#         initTagRenderer("".split(" "), "".split(" "));
#         StackExchange.userQuestionList.init({
#             sharingUrl: ""
#         });
#     });
# </script>
# <div data-controller="se-uql" data-se-uql-id="" data-se-uql-sanitize-tag-query="false">
# <div class="d-flex ai-center jc-space-between mb12 sm:fd-column sm:ai-stretch">
# <div class="fs-body3 flex--item fl1 mr12 sm:mr0 sm:mb12">
#             1,816,414
#             questions
#         </div>
# <div class="uql-nav flex--item" data-action="se-uql-list:edit-current-requested@document-&gt;se-uql#toggleEditor">
# <div class="d-flex ai-center jc-space-between">
# <div class="js-uql-navigation s-btn-group flex--item mr16 ff-row-nowrap">
# <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex is-selected" data-nav-value="Newest" data-shortcut="N" href="/questions/tagged/java?tab=Newest">
# <div class="flex--item">Newest</div>
# </a>
# <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex" data-nav-value="Active" data-shortcut="A" href="/questions/tagged/java?tab=Active">
# <div class="flex--item">Active</div>
# </a>
# <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex uql-nav--expanded-item" data-nav-value="Bounties" data-shortcut="E" href="/questions/tagged/java?tab=Bounties">
# <div class="flex--item">Bountied</div>
# <div class="s-badge s-badge__bounty s-badge__bounty s-badge__sm lh-xs ml4 px4 flex--item">20</div>
# </a>
# <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex uql-nav--expanded-item" data-nav-value="Unanswered" data-shortcut="U" href="/questions/tagged/java?tab=Unanswered">
# <div class="flex--item">Unanswered</div>
# </a>
# <button aria-controls="uql-more-popover" aria-expanded="false" aria-haspopup="true" class="s-btn s-btn__muted s-btn__outlined s-btn__sm s-btn__dropdown" data-action="s-popover#toggle" data-controller="s-popover" data-se-uql-target="toggleMoreButton" role="button">
#                         More
#                     </button>
# </div>
# <div class="s-popover z-dropdown ws2" data-se-uql-target="morePopover" id="uql-more-popover">
# <div class="s-popover--arrow"></div>
# <ul class="list-reset mtn8 mbn8 js-uql-navigation">
# <li class="uql-item my0 uql-nav--collapsed-item">
# <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="" href="/questions/tagged/java?tab=Bounties">
#                                         Bountied
#                                             <span class="s-badge s-badge__bounty s-badge__bounty s-badge__sm lh-xs px4">20</span>
# </a>
# </li>
# <li class="uql-item my0 uql-nav--collapsed-item">
# <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="" href="/questions/tagged/java?tab=Unanswered">
#                                         Unanswered
#                                     </a>
# </li>
# <li class="uql-item my0">
# <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="F" href="/questions/tagged/java?tab=Frequent">
#                                         Frequent
#                                     </a>
# </li>
# <li class="uql-item my0">
# <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="V" href="/questions/tagged/java?tab=Votes">
#                                         Votes
#                                     </a>
# </li>
# <li class="uql-item uql-item__separator bg-black-075 d:bg-black-025"></li>
# <li class="uql-item my0">
# <span class="s-block-link c-default fc-black-350 mln12 mrn12 px12 py6">Unanswered (my tags)</span>
# </li>
# </ul>
# </div>
# <div class="flex--item">
# <button aria-controls="uql-form" aria-expanded="false" class="s-btn s-btn__filled s-btn__sm s-btn__icon ws-nowrap" data-controller="s-expandable-control" data-s-expandable-control-toggle-class="is-selected" data-se-uql-target="toggleFormButton" role="button">
# <svg aria-hidden="true" class="svg-icon iconFilter" height="18" viewbox="0 0 18 18" width="18"><path d="M2 4h14v2H2V4Zm2 4h10v2H4V8Zm8 4H6v2h6v-2Z"></path></svg> Filter
#                     </button>
# </div>
# </div>
# </div>
# </div>
# <form class="s-expandable ps-relative z-active" data-action="se-uql#navigate" data-se-uql-target="form" id="uql-form">
# <input name="uqlId" type="hidden"/>
# <div class="s-expandable--content">
# <div class="bg-black-050 ba bc-black-100 bar-sm mb16">
# <div class="px12 py16">
# <div class="d-flex gs32 fw-wrap">
# <div class="flex--item">
# <fieldset class="d-flex gs8 gsy fd-column">
# <legend class="flex--item s-label px0">Filter by</legend>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-checkbox d-block" id="7d4b1108-7a58-49f2-aa10-a2370cb30668" name="filterId" type="checkbox" value="NoAnswers"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="7d4b1108-7a58-49f2-aa10-a2370cb30668">No answers</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-checkbox d-block" id="062f790c-5c33-4df7-a1ec-982b49098774" name="filterId" type="checkbox" value="NoAcceptedAnswer"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="062f790c-5c33-4df7-a1ec-982b49098774">No accepted answer</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-checkbox d-block" id="95181a74-afa5-4d41-8fff-0aeeb4371521" name="filterId" type="checkbox" value="Bounty"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="95181a74-afa5-4d41-8fff-0aeeb4371521">Has bounty</label>
# </div>
# </div>
# </fieldset>
# </div>
# <div class="flex--item">
# <fieldset class="d-flex gs8 gsy fd-column">
# <legend class="flex--item s-label px0">Sorted by</legend>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input checked="checked" class="s-radio d-block" id="e5873541-3e3d-4795-913e-9c992b13be03" name="sortId" type="radio" value="Newest"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="e5873541-3e3d-4795-913e-9c992b13be03">Newest</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-radio d-block" id="86b630e5-b281-4dfe-abdf-9f72f0963850" name="sortId" type="radio" value="RecentActivity"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="86b630e5-b281-4dfe-abdf-9f72f0963850">Recent activity</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-radio d-block" id="fa505287-5f01-4ac0-99ca-2561ff250d50" name="sortId" type="radio" value="MostVotes"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="fa505287-5f01-4ac0-99ca-2561ff250d50">Most votes</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-radio d-block" id="3f90d890-df34-4c3b-a086-4ec3981f1550" name="sortId" type="radio" value="MostFrequent"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="3f90d890-df34-4c3b-a086-4ec3981f1550">Most frequent</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-radio d-block" id="73c45878-ad48-4552-9fd4-c05257fa254a" name="sortId" type="radio" value="BountyEndingSoon"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="73c45878-ad48-4552-9fd4-c05257fa254a">Bounty ending soon</label>
# </div>
# </div>
# </fieldset>
# </div>
# <div class="flex--item">
# <fieldset class="d-flex gs8 gsy fd-column">
# <legend class="flex--item s-label px0">Tagged with</legend>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-radio d-block" id="6888d9c1-e225-4f40-bfeb-4108f3892172" name="tagModeId" type="radio" value="Watched"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="6888d9c1-e225-4f40-bfeb-4108f3892172">My watched tags</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input checked="checked" class="s-radio d-block" id="9855fdb1-a0cf-4d39-8628-e27bcc47a113" name="tagModeId" type="radio" value="Specified"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="9855fdb1-a0cf-4d39-8628-e27bcc47a113">The following tags:</label>
# </div>
# </div>
# </fieldset>
# <div class="ps-relative ml24 mt8 ws2">
# <input class="w100 s-input" data-se-uql-target="tagQuery" id="uql-modal-tag-input" name="tagQuery" placeholder="e.g. javascript or python" size="60" tabindex="0" type="text" value="java"/>
# </div>
# </div>
# </div>
# </div>
# <div class="p12 bt bc-black-100">
# <div class="d-flex">
# <div class="d-flex gs4 gsx fl1">
# <button class="s-btn s-btn__sm s-btn__primary flex--item" data-se-uql-target="applyButton" type="submit">Apply filter</button>
# </div>
# <div class="flex--item">
# <button class="s-btn s-btn__sm" data-action="se-uql#cancelEditor" type="button">Cancel</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# <div class="bt bc-black-100 mln24 pl24" id="questions">
# <div class="mln24">
# <div class="question-summary" id="question-summary-70312057">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post "><strong>0</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status unanswered">
# <strong>0</strong>answers
#             </div>
# </div>
# <div class="views " title="4 views">
#     4 views
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/70312057/match-every-single-string-after-character-in-java-regex">Match every single String after character in Java (RegEx)</a></h3>
# <div class="excerpt">
#             I need help with this, so uhm... I have a String:
# Hey ~firstname ~lastname today is the ~date
#
# I want the program to print out this output:
# firstname lastname date
#
# in a list from the matcher (I ...
#         </div>
# <div class="d-flex ai-start fw-wrap">
# <div class="flex--item">
# <div class="d-flex gs4 fw-wrap tags t-java t-regex t-string t-pattern-matching t-match">
# <a class="post-tag flex--item" href="/questions/tagged/java" rel="tag" title="show questions tagged 'java'">java</a> <a class="post-tag flex--item" href="/questions/tagged/regex" rel="tag" title="show questions tagged 'regex'">regex</a> <a class="post-tag flex--item" href="/questions/tagged/string" rel="tag" title="show questions tagged 'string'">string</a> <a class="post-tag flex--item" href="/questions/tagged/pattern-matching" rel="tag" title="show questions tagged 'pattern-matching'">pattern-matching</a> <a class="post-tag flex--item" href="/questions/tagged/match" rel="tag" title="show questions tagged 'match'">match</a> </div>
# </div>
# <div class="flex--item ml-auto fl-shrink0 started mt0">
# <div class="user-info ">
# <div class="user-action-time">
#         asked <span class="relativetime" title="2021-12-11 01:48:58Z">3 mins ago</span>
# </div>
# <div class="user-gravatar32">
# <a href="/users/16028444/momothesim"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://lh3.googleusercontent.com/a-/AOh14GgZXASPL_t6GhQ6IuxtUI68NXXUStfr52oPD1P1=k-s64" width="32"/></div></a>
# </div>
# <div class="user-details">
# <a href="/users/16028444/momothesim">MomoTheSiM</a>
# <div class="-flair">
# <span class="reputation-score" dir="ltr" title="reputation score ">27</span><span aria-hidden="true" title="2 bronze badges"><span class="badge3"></span><span class="badgecount">2</span></span><span class="v-visible-sr">2 bronze badges</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mln24">
# <div class="question-summary" id="question-summary-70312009">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post "><strong>0</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status unanswered">
# <strong>0</strong>answers
#             </div>
# </div>
# <div class="views " title="6 views">
#     6 views
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/70312009/how-to-highlight-specific-subpanel-in-a-master-jpane">How to highlight specific subpanel in a master JPane?</a></h3>
# <div class="excerpt">
#             I am building a GUI for a maze-based game.
# The main JPanel is made up of smaller JPanels I call Tiles. My goal is to have a specific tile JPanel be highlighted when the player is in that cell. It ...
#         </div>
# <div class="d-flex ai-start fw-wrap">
# <div class="flex--item">
# <div class="d-flex gs4 fw-wrap tags t-java t-swing t-jframe t-jpanel">
# <a class="post-tag flex--item" href="/questions/tagged/java" rel="tag" title="show questions tagged 'java'">java</a> <a class="post-tag flex--item" href="/questions/tagged/swing" rel="tag" title="show questions tagged 'swing'">swing</a> <a class="post-tag flex--item" href="/questions/tagged/jframe" rel="tag" title="show questions tagged 'jframe'">jframe</a> <a class="post-tag flex--item" href="/questions/tagged/jpanel" rel="tag" title="show questions tagged 'jpanel'">jpanel</a> </div>
# </div>
# <div class="flex--item ml-auto fl-shrink0 started mt0">
# <div class="user-info ">
# <div class="user-action-time">
#         asked <span class="relativetime" title="2021-12-11 01:34:06Z">18 mins ago</span>
# </div>
# <div class="user-gravatar32">
# <a href="/users/7966156/nova"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/01e855e8cc4b0867c0685b6cbbd052ec?s=64&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
# </div>
# <div class="user-details">
# <a href="/users/7966156/nova">Nova</a>
# <div class="-flair">
# <span class="reputation-score" dir="ltr" title="reputation score ">466</span><span aria-hidden="true" title="2 silver badges"><span class="badge2"></span><span class="badgecount">2</span></span><span class="v-visible-sr">2 silver badges</span><span aria-hidden="true" title="12 bronze badges"><span class="badge3"></span><span class="badgecount">12</span></span><span class="v-visible-sr">12 bronze badges</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mln24">
# <div class="question-summary" id="question-summary-70311901">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post "><strong>-3</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status unanswered">
# <strong>0</strong>answers
#             </div>
# </div>
# <div class="views " title="16 views">
#     16 views
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/70311901/final-class-and-extending-from-other-classes">Final Class and extending from other classes? [closed]</a></h3>
# <div class="excerpt">
#             public class Parent {
# //implementation
# }
#
# public final class Child extends Parent {
# //implementation
# }
#
# public class Baby extends Parent {
# //implementation
# }
#
# What is wrong with this code given? My ...
#         </div>
# <div class="d-flex ai-start fw-wrap">
# <div class="flex--item">
# <div class="d-flex gs4 fw-wrap tags t-java t-class">
# <a class="post-tag flex--item" href="/questions/tagged/java" rel="tag" title="show questions tagged 'java'">java</a> <a class="post-tag flex--item" href="/questions/tagged/class" rel="tag" title="show questions tagged 'class'">class</a> </div>
# </div>
# <div class="flex--item ml-auto fl-shrink0 started mt0">
# <div class="user-info user-hover">
# <div class="user-action-time">
#         asked <span class="relativetime" title="2021-12-11 01:02:50Z">49 mins ago</span>
# </div>
# <div class="user-gravatar32">
# <a href="/users/10942422/minjun-seo"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/a4cf9778ea6fb3e9c9a0790b972db54f?s=64&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
# </div>
# <div class="user-details">
# <a href="/users/10942422/minjun-seo">Minjun Seo</a>
# <div class="-flair">
# <span class="reputation-score" dir="ltr" title="reputation score ">23</span><span aria-hidden="true" title="6 bronze badges"><span class="badge3"></span><span class="badgecount">6</span></span><span class="v-visible-sr">6 bronze badges</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mln24">
# <div class="question-summary" id="question-summary-70311829">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# ...
#     var clc = clc || {};
#     clc.collapse = { sb: !0, 'tag-sponsorship': !0, lb: !0, mlb: !0, smlb: !0, bmlb: !0, 'mobile-below-question': !0 };
#     clc.options = clc.options || {};
#     clc.options.sf = !0;
#     clc.options.hb = !1;
#     clc.options.ll = !0;
#     clc.options.targeting_consent = !1;
#     clc.options.performance_consent = !1;
#         clc.cmd = clc.cmd || [];
#         clc.cmd.push(function () { window.clc_request='A-bJV9dIvNkIAAAAAAAAAAACAAAAAQAAAAAABgAAAHxqYXZhfADyVs5sLHIJ5wuW'; clc.load(); });
#         StackExchange.ready(function () { googletag.cmd.push(function () { StackExchange.ads.init(googletag, '/ads/report-ad', 'Report this ad') }) });
# </script>
# <footer class="site-footer js-footer" id="footer" role="contentinfo">
# <div class="site-footer--container">
# <div class="site-footer--logo">
# <a href="https://stackoverflow.com"><svg aria-hidden="true" class="native svg-icon iconLogoGlyphMd" height="37" viewbox="0 0 32 37" width="32"><path d="M26 33v-9h4v13H0V24h4v9h22Z" fill="#BCBBBB"></path><path d="m21.5 0-2.7 2 9.9 13.3 2.7-2L21.5 0ZM26 18.4 13.3 7.8l2.1-2.5 12.7 10.6-2.1 2.5ZM9.1 15.2l15 7 1.4-3-15-7-1.4 3Zm14 10.79.68-2.95-16.1-3.35L7 23l16.1 2.99ZM23 30H7v-3h16v3Z" fill="#F48024"></path></svg></a>
# </div>
# <nav class="site-footer--nav">
# <div class="site-footer--col">
# <h5 class="-title"><a class="js-gps-track" data-gps-track="footer.click({ location: 5, link: 15})" href="https://stackoverflow.com">Stack Overflow</a></h5>
# <ul class="-list js-primary-footer-links">
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 16})" href="/questions">Questions</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 17})" href="https://stackoverflow.com/jobs">Jobs</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 11})" href="https://stackoverflow.com/jobs/directory/developer-jobs">Developer Jobs Directory</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 28})" href="https://stackoverflow.com/jobs/salary">Salary Calculator</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 3 })" href="/help">Help</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 12 })" onclick='StackExchange.switchMobile("on")'>Mobile</a></li>
# </ul>
# </div>
# <div class="site-footer--col">
# <h5 class="-title"><a class="js-gps-track" data-gps-track="footer.click({ location: 5, link: 19 })" href="https://stackoverflowbusiness.com">Products</a></h5>
# <ul class="-list">
# <li><a class="js-gps-track -link" data-ga='["teams traffic","footer - site nav","stackoverflow.com/teams",null,{"dimension4":"teams"}]' data-gps-track="footer.click({ location: 5, link: 29 })" href="https://stackoverflow.com/teams">Teams</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 20 })" href="https://stackoverflow.com/talent">Talent</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 21 })" href="https://stackoverflow.com/advertising">Advertising</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 22 })" href="https://stackoverflowsolutions.com/explore-teams">Enterprise</a></li>
# </ul>
# </div>
# <div class="site-footer--col">
# <h5 class="-title"><a class="js-gps-track" data-gps-track="footer.click({ location: 5, link: 1 })" href="https://stackoverflow.com/company">Company</a></h5>
# <ul class="-list">
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 1 })" href="https://stackoverflow.com/company">About</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 27 })" href="https://stackoverflow.com/company/press">Press</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 9 })" href="https://stackoverflow.com/company/work-here">Work Here</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 7 })" href="https://stackoverflow.com/legal">Legal</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 8 })" href="https://stackoverflow.com/legal/privacy-policy">Privacy Policy</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 37 })" href="https://stackoverflow.com/legal/terms-of-service">Terms of Service</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 13 })" href="https://stackoverflow.com/company/contact">Contact Us</a></li>
# <li class="" id="consent-footer-link"><a class="js-gps-track -link js-cookie-settings" data-consent-popup-loader="footer" data-gps-track="footer.click({ location: 5, link: 38 })" href="#">Cookie Settings</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 39 })" href="https://stackoverflow.com/legal/cookie-policy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="site-footer--col site-footer--categories-nav">
# <div>
# <h5 class="-title"><a data-gps-track="footer.click({ location: 5, link: 30 })" href="https://stackexchange.com">Stack Exchange Network</a></h5>
# <ul class="-list">
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#technology">
#                                     Technology
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#culturerecreation">
#                                     Culture &amp; recreation
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#lifearts">
#                                     Life &amp; arts
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#science">
#                                     Science
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#professional">
#                                     Professional
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#business">
#                                     Business
#                                 </a>
# </li>
# <li class="mt16 md:mt0">
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://api.stackexchange.com/">
#                                     API
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://data.stackexchange.com/">
#                                     Data
#                                 </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="site-footer--copyright fs-fine md:mt24">
# <ul class="-list -social md:mb8">
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link:4 })" href="https://stackoverflow.blog?blb=1">Blog</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 31 })" href="https://www.facebook.com/officialstackoverflow/">Facebook</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 32 })" href="https://twitter.com/stackoverflow">Twitter</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 33 })" href="https://linkedin.com/company/stack-overflow">LinkedIn</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 36 })" href="https://www.instagram.com/thestackoverflow">Instagram</a></li>
# </ul>
# <p class="md:mb0">
# site design / logo © 2021 Stack Exchange Inc; user contributions licensed under <a href="https://stackoverflow.com/help/licensing">cc by-sa</a>.                    <span id="svnrev">rev 2021.12.10.40971</span>
# </p>
# </div>
# </div>
# </footer>
# <script>StackExchange.ready(function () { StackExchange.responsiveness.addSwitcher(); })</script>
# <noscript>
# <div id="noscript-warning">Stack Overflow works best with JavaScript enabled
#             <img alt="" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=17440561&amp;cv=3.6.0&amp;cj=1"/>
# </div>
# </noscript>
# <script>
# (function(i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function() { (i[r].q = i[r].q || []).push(arguments) }, i[r].l = 1 * new Date(); a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m);
#             })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#             StackExchange.ready(function () {
#
#                 StackExchange.ga.init({
#                     autoLink: ["stackoverflow.blog","info.stackoverflowsolutions.com","stackoverflowsolutions.com"],
#                     sendTitles: true,
#                     tracker: window.ga,
#                     trackingCodes: [
#                         'UA-108242619-1'
#                     ],
#                         checkDimension: 'dimension42'
#                 });
#
#
#
#                     StackExchange.ga.setDimension('dimension2', '|java|');
#
#
#                     StackExchange.ga.setDimension('dimension3', 'Questions/ListByTag');
#
#
#                 StackExchange.ga.setDimension('dimension7', "1639187528.1706722618");
#
#                 StackExchange.ga.trackPageView();
#             });
#                 </script>
# <div class="ff-sans ps-fixed z-nav-fixed ws4 sm:w-auto p32 sm:p16 bg-black-750 fc-white bar-lg b16 l16 r16 js-consent-banner">
# <svg aria-hidden="true" class="mln4 mb24 sm:d-none svg-spot spotCookieLg" height="96" style="color: var(--theme-button-filled-background-color)" viewbox="0 0 96 96" width="96">
# <path d="M35 45.5a7.5 7.5 0 11-15 0 7.5 7.5 0 0115 0zM63.5 63a7.5 7.5 0 100-15 7.5 7.5 0 000 15zm-19 19a7.5 7.5 0 100-15 7.5 7.5 0 000 15z" opacity=".2"></path>
# <path d="M56.99 2.53a23.1 23.1 0 0114.66 6.15h.01l.01.02c.57.55.61 1.27.5 1.74v.07a10.95 10.95 0 01-3.07 4.77 9 9 0 01-6.9 2.5 10.34 10.34 0 01-9.72-10.44v-.08a10 10 0 011.03-3.74l.01-.03.02-.02c.28-.5.82-.92 1.52-.95.63-.02 1.27-.02 1.93.01zm12.04 7.83a20.1 20.1 0 00-12.2-4.83l-.92-.03c-.23.6-.38 1.25-.43 1.94a7.34 7.34 0 006.95 7.34 6 6 0 004.64-1.7c.94-.88 1.6-1.9 1.96-2.72zm15.3 8.76a6.84 6.84 0 00-5.09-.24 7.9 7.9 0 00-3.28 2.05 1.8 1.8 0 00-.3 1.95l.02.02v.02a15.16 15.16 0 008.74 7.47c.64.23 1.32.08 1.8-.33a6.63 6.63 0 001.63-1.97l.01-.03.01-.03c1.67-3.5-.12-7.32-3.54-8.91zm-5.5 3.28c.36-.25.82-.5 1.35-.67.92-.3 1.92-.35 2.89.1 2.14 1 2.92 3.14 2.11 4.88-.12.21-.26.41-.43.6l-.26-.1a12.29 12.29 0 01-5.66-4.81zM32 24a2 2 0 11-4 0 2 2 0 014 0zm12 21a2 2 0 11-4 0 2 2 0 014 0zm36 4a2 2 0 11-4 0 2 2 0 014 0zm-7 21a2 2 0 11-4 0 2 2 0 014 0zM59 81a2 2 0 11-4 0 2 2 0 014 0zM22 63a2 2 0 11-4 0 2 2 0 014 0zm27 7a9 9 0 11-18 0 9 9 0 0118 0zm-3 0a6 6 0 10-12 0 6 6 0 0012 0zM33 41a9 9 0 11-18 0 9 9 0 0118 0zm-15 0a6 6 0 1012 0 6 6 0 00-12 0zm50 11a9 9 0 11-18 0 9 9 0 0118 0zm-3 0a6 6 0 10-12 0 6 6 0 0012 0zM44.08 4.24c.31.48.33 1.09.05 1.58a17.46 17.46 0 00-2.36 8.8c0 9.55 7.58 17.24 16.85 17.24 2.97 0 5.75-.78 8.16-2.15a1.5 1.5 0 012.1.66 12.08 12.08 0 0011 6.74 12.4 12.4 0 007.85-2.75 1.5 1.5 0 012.38.74A45.76 45.76 0 0192 48.16c0 24.77-19.67 44.9-44 44.9S4 72.93 4 48.16C4 25.23 20.84 6.28 42.64 3.58a1.5 1.5 0 011.44.66zM40.22 7C21.32 10.71 7 27.7 7 48.16c0 23.17 18.39 41.9 41 41.9s41-18.73 41-41.9c0-3.52-.42-6.93-1.22-10.2a15.5 15.5 0 01-7.9 2.15c-5.5 0-10.36-2.83-12.97-7.1a19.46 19.46 0 01-8.28 1.85c-11 0-19.86-9.1-19.86-20.24 0-2.7.52-5.26 1.45-7.62zM92 91a2 2 0 100-4 2 2 0 000 4zM7 8.5a2.5 2.5 0 11-5 0 2.5 2.5 0 015 0zM82.5 90a1.5 1.5 0 100-3 1.5 1.5 0 000 3zm9.5-7.5a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zM13.5 8a1.5 1.5 0 100-3 1.5 1.5 0 000 3zM80 14.5a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zM53.5 20a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path>
# </svg>
# <p class="fs-body2 fw-bold mb4">
#                         Your privacy
#                     </p>
# <p class="mb16 s-anchors s-anchors__inherit s-anchors__underlined">
#                         By clicking “Accept all cookies”, you agree Stack Exchange can store cookies on your device and disclose information in accordance with our <a href="https://stackoverflow.com/legal/cookie-policy">Cookie Policy</a>.
#                     </p>
# <div class="d-flex gs8 ai-stretch fd-column sm:fd-row">
# <button class="flex--item s-btn s-btn__primary js-accept-cookies js-consent-banner-hide">
#                             Accept all cookies
#                         </button>
# <button class="flex--item s-btn s-btn__filled js-cookie-settings" data-consent-popup-loader="banner">
#                             Customize settings
#                         </button>
# </div>
# </div>
# <div class="d-none" id="onetrust-consent-sdk"></div>
# <div data-controller="s-modal" id="onetrust-banner-sdk"></div>
# <div class="d-none" id="ot-pc-content"></div>
# <div class="d-none" id="onetrust-style"> </div>
# <div class="d-none js-consent-banner-version" data-consent-banner-version="baseline"></div>
# </body>
# </html>

# %%
print(soup.prettify()) # Imprimindo de forma aninhada;
# Out:
# <!DOCTYPE html>
# <html class="html__responsive ">
#  <head>
#   <title>
#    Newest 'java' Questions - Stack Overflow
#   </title>
#   <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" rel="shortcut icon"/>
#   <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon"/>
#   <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="image_src"/>
#   <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>
#   <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
#   <meta content="website" property="og:type">
#    <meta content="https://stackoverflow.com/questions/tagged/java" property="og:url"/>
#    <meta content="Stack Overflow" property="og:site_name"/>
#    <meta content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" itemprop="image primaryImageOfPage" property="og:image"/>
#    <meta content="summary" name="twitter:card"/>
#    <meta content="stackoverflow.com" name="twitter:domain"/>
#    <meta content="Newest 'java' Questions" itemprop="name" name="twitter:title" property="og:title"/>
#    <meta content="Stack Overflow | The World’s Largest Online Community for Developers" itemprop="description" name="twitter:description" property="og:description"/>
#    <script id="webpack-public-path" type="text/uri-list">
#     https://cdn.sstatic.net/
#    </script>
#    <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js">
#    </script>
#    <script async="" src="https://cdn.sstatic.net/Js/third-party/stacks/stacks.min.js?v=587378ef592b">
#    </script>
#    <script src="https://cdn.sstatic.net/Js/stub.en.js?v=17e20b4b4731">
#    </script>
#    <link href="https://cdn.sstatic.net/Shared/stacks.css?v=15473555f232" rel="stylesheet" type="text/css"/>
#    <link href="https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=de9fb8b74f61" rel="stylesheet" type="text/css"/>
#    <link href="https://cdn.sstatic.net/Sites/stackoverflow/secondary.css?v=9532f59e9743" rel="stylesheet" type="text/css"/>
#    <link href="/feeds/tag?tagnames=java&amp;sort=newest" rel="alternate" title="Newest java questions feed" type="application/atom+xml">
#     <link href="https://cdn.sstatic.net/Shared/Channels/channels.css?v=47a5e0f03c81" rel="stylesheet" type="text/css"/>
#     <script>
#      StackExchange.init({"locale":"en","serverTime":1639187528,"routeName":"Questions/ListByTag","stackAuthUrl":"https://stackauth.com","networkMetaHostname":"meta.stackexchange.com","site":{"name":"Stack Overflow","description":"Q&A for professional and enthusiast programmers","isNoticesTabEnabled":true,"enableNewTagCreationWarning":true,"insertSpaceAfterNameTabCompletion":false,"id":1,"cookieDomain":".stackoverflow.com","childUrl":"https://meta.stackoverflow.com","negativeVoteScoreFloor":null,"enableSocialMediaInSharePopup":true,"protocol":"https"},"user":{"fkey":"c8502838d06feccb2607165cf1402428147ff3909b480d87cf7341f1c14d95d6","tid":"7f474628-17eb-09fe-d8e3-020dee5eb882","rep":0,"isAnonymous":true,"isAnonymousNetworkWide":true},"events":{"postType":{"question":1},"postEditionSection":{"title":1,"body":2,"tags":3}},"story":{"minCompleteBodyLength":75,"likedTagsMaxLength":300,"dislikedTagsMaxLength":300},"jobPreferences":{"maxNumDeveloperRoles":2,"maxNumIndustries":4},"svgIconPath":"https://cdn.sstatic.net/Img/stacks-icons","svgIconHash":"d9a8a2f90b12"}, {"userProfile":{"openGraphAPIKey":"4a307e43-b625-49bb-af15-ffadf2bda017"},"userMessaging":{"showNewFeatureNotice":true},"tags":{},"subscriptions":{"defaultBasicMaxTrueUpSeats":250,"defaultFreemiumMaxTrueUpSeats":50,"defaultMaxTrueUpSeats":1000},"snippets":{"renderDomain":"stacksnippets.net","snippetsEnabled":true},"site":{"allowImageUploads":true,"enableImgurHttps":true,"enableUserHovercards":true,"forceHttpsImages":true,"styleCode":true},"questions":{"enableDeleteVoteRetraction":true,"enableQuestionTitleLengthLiveWarning":true,"maxTitleSize":150,"questionTitleLengthStartLiveWarningChars":50},"intercom":{"appId":"inf0secd","hostBaseUrl":"https://stacksnippets.net"},"paths":{},"monitoring":{"clientTimingsAbsoluteTimeout":30000,"clientTimingsDebounceTimeout":1000},"mentions":{"maxNumUsersInDropdown":50},"markdown":{"enableTables":true},"legal":{"oneTrustConfigId":"c3d9f1e3-55f3-4eba-b268-46cee4c6789c"},"flags":{"allowRetractingCommentFlags":true,"allowRetractingFlags":true},"elections":{"opaVoteResultsBaseUrl":"https://www.opavote.com/results/"},"comments":{},"accounts":{"currentPasswordRequiredForChangingStackIdPassword":true}});
#         StackExchange.using.setCacheBreakers({"js/adops.en.js":"6da43f5e0a84","js/ask.en.js":"7ff9a9068fd6","js/begin-edit-event.en.js":"dd955babf04d","js/copy-transpiled.en.js":"51a328039b9e","js/cm.en.js":"75dcb3984aa6","js/events.en.js":"716b95b6374c","js/explore-qlist.en.js":"2b1f34938b8b","js/full-anon.en.js":"70f6560d9b2d","js/full.en.js":"3ffc71953b78","js/help.en.js":"2b4af0ad5c0c","js/highlightjs-loader.en.js":"0026055c3561","js/inline-tag-editing.en.js":"c0cbc31e5702","js/keyboard-shortcuts.en.js":"5ffcb8f50446","js/markdown-it-loader.en.js":"dfad6619ffdd","js/modElections.en.js":"5114e9d6e1cf","js/mobile.en.js":"320aa423a438","js/moderator.en.js":"e83e4187e0ec","js/postCollections-transpiled.en.js":"4b407fb73054","js/post-validation.en.js":"569f8b05c015","js/question-editor.en.js":"","js/review-v2-transpiled.en.js":"b7e059a9fe83","js/revisions.en.js":"839f528889ff","js/stacks-editor.en.js":"04f5018456af","js/tageditor.en.js":"825c9597ce2d","js/tageditornew.en.js":"5215bc97928a","js/tagsuggestions.en.js":"1bcff7d98f97","js/unlimited-transpiled.en.js":"7ed67670b600","js/wmd.en.js":"4689e82c85e7","js/snippet-javascript-codemirror.en.js":"209508902bf4"});
#         StackExchange.using("gps", function() {
#              StackExchange.gps.init(false);
#         });
#     </script>
#     <noscript id="noscript-css">
#      <style>
#       body,.top-bar{margin-top:1.9em}
#      </style>
#     </noscript>
#    </link>
#   </meta>
#  </head>
#  <body class="tagged-questions-page unified-theme">
#   <div id="notify-container">
#   </div>
#   <div id="custom-header">
#   </div>
#   <header class="top-bar js-top-bar top-bar__network">
#    <div class="wmx12 mx-auto d-flex ai-center h100" role="menubar">
#     <div class="-main flex--item">
#      <a aria-controls="left-sidebar" aria-expanded="false" aria-haspopup="true" class="left-sidebar-toggle p0 ai-center jc-center js-left-sidebar-toggle" href="#" role="menuitem">
#       <span class="ps-relative">
#       </span>
#      </a>
#      <div class="topbar-dialog leftnav-dialog js-leftnav-dialog dno">
#       <div class="left-sidebar js-unpinned-left-sidebar" data-can-be="left-sidebar" data-is-here-when="sm">
#       </div>
#      </div>
#      <a class="-logo js-gps-track" data-gps-track="top_nav.click({is_current:false, location:5, destination:8})" href="https://stackoverflow.com">
#       <span class="-img _glyph">
#        Stack Overflow
#       </span>
#      </a>
#     </div>
#     <ol class="list-reset d-flex gs4" role="presentation">
#      <li class="flex--item md:d-none">
#       <a class="-marketing-link js-gps-track" data-ga='["top navigation","about menu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:7})" href="/company">
#        About
#       </a>
#      </li>
#      <li class="flex--item">
#       <a aria-controls="products-popover" class="-marketing-link js-gps-track js-products-menu" data-action="s-popover#toggle" data-controller="s-popover" data-ga='["top navigation","products menu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:1})" data-s-popover-placement="bottom" data-s-popover-toggle-class="is-selected" href="#">
#        Products
#       </a>
#      </li>
#      <li class="flex--item md:d-none">
#       <a class="-marketing-link js-gps-track" data-ga='["top navigation","learn more - teams",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:7})" href="/teams">
#        For Teams
#       </a>
#      </li>
#     </ol>
#     <div aria-hidden="true" class="s-popover ws2 mtn2 p0" id="products-popover" role="menu">
#      <div class="s-popover--arrow">
#      </div>
#      <ol class="list-reset s-anchors s-anchors__inherit">
#       <li class="m6">
#        <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","public qa submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:2})" href="/questions">
#         <span class="fs-body1 d-block">
#          Stack Overflow
#         </span>
#         <span class="fs-caption d-block fc-light">
#          Public questions &amp; answers
#         </span>
#        </a>
#       </li>
#       <li class="m6">
#        <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","teams submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:3})" href="/teams">
#         <span class="fs-body1 d-block">
#          Stack Overflow for Teams
#         </span>
#         <span class="fs-caption d-block fc-light">
#          Where developers &amp; technologists share private knowledge with coworkers
#         </span>
#        </a>
#       </li>
#       <li class="m6">
#        <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","jobs submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:9})" href="/jobs?so_source=ProductsMenu&amp;so_medium=StackOverflow">
#         <span class="fs-body1 d-block">
#          Jobs
#         </span>
#         <span class="fs-caption d-block fc-light">
#          Programming &amp; related technical career opportunities
#         </span>
#        </a>
#       </li>
#       <li class="m6">
#        <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","talent submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:5})" href="https://stackoverflow.com/talent">
#         <span class="fs-body1 d-block">
#          Talent
#         </span>
#         <span class="fs-caption d-block fc-light">
#          Recruit tech talent &amp; build your employer brand
#         </span>
#        </a>
#       </li>
#       <li class="m6">
#        <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","advertising submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:6})" href="https://stackoverflow.com/advertising">
#         <span class="fs-body1 d-block">
#          Advertising
#         </span>
#         <span class="fs-caption d-block fc-light">
#          Reach developers &amp; technologists worldwide
#         </span>
#        </a>
#       </li>
#       <li class="bg-black-025 bt bc-black-075 py6 px6 bbr-md">
#        <a class="fc-light d-block py6 px6 h:fc-black-800 js-gps-track" data-ga='["top navigation","about submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:7})" href="/company">
#         About the company
#        </a>
#       </li>
#      </ol>
#     </div>
#     <form action="/search" autocomplete="off" class="flex--item fl-grow1 searchbar px12 js-searchbar " id="search" role="search">
#      <div class="ps-relative">
#       <input aria-controls="top-search" aria-label="Search" autocomplete="off" class="s-input s-input__search js-search-field " data-action="focus-&gt;s-popover#show" data-controller="s-popover" data-s-popover-placement="bottom-start" maxlength="240" name="q" placeholder="Search…" type="text" value="[java]"/>
#       <svg aria-hidden="true" class="s-input-icon s-input-icon__search svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18">
#        <path d="m18 16.5-5.14-5.18h-.35a7 7 0 10-1.19 1.19v.35L16.5 18l1.5-1.5ZM12 7A5 5 0 112 7a5 5 0 0110 0Z">
#        </path>
#       </svg>
#       <div class="s-popover p0 wmx100 wmn4 sm:wmn-initial js-top-search-popover" id="top-search" role="menu">
#        <div class="s-popover--arrow">
#        </div>
#        <div class="js-spinner p24 d-flex ai-center jc-center d-none">
#         <div class="s-spinner s-spinner__sm fc-orange-400">
#          <div class="v-visible-sr">
#           Loading…
#          </div>
#         </div>
#        </div>
#        <span class="v-visible-sr js-screen-reader-info">
#        </span>
#        <div class="js-ac-results overflow-y-auto hmx3 d-none">
#        </div>
#        <div aria-describedby="Tips for searching" class="js-search-hints">
#        </div>
#       </div>
#      </div>
#     </form>
#     <ol class="overflow-x-auto ml-auto -secondary d-flex ai-center list-reset h100 user-logged-out" role="presentation">
#      <li class="-item searchbar-trigger">
#       <a aria-controls="search" aria-haspopup="true" aria-label="Search" class="-link js-searchbar-trigger" href="#" role="button" title="Click to show search">
#        <svg aria-hidden="true" class="svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18">
#         <path d="m18 16.5-5.14-5.18h-.35a7 7 0 10-1.19 1.19v.35L16.5 18l1.5-1.5ZM12 7A5 5 0 112 7a5 5 0 0110 0Z">
#         </path>
#        </svg>
#       </a>
#      </li>
#      <li class="-ctas">
#       <a class="login-link s-btn s-btn__filled py8 js-gps-track" data-ga='["top navigation","login button click",null,null,null]' data-gps-track="login.click" href="https://stackoverflow.com/users/login?ssrc=head&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2ftagged%2fjava" rel="nofollow">
#        Log in
#       </a>
#       <a class="login-link s-btn s-btn__primary py8" data-ga='["sign up","Sign Up Navigation","Header",null,null]' href="https://stackoverflow.com/users/signup?ssrc=head&amp;returnurl=%2fusers%2fstory%2fcurrent" rel="nofollow">
#        Sign up
#       </a>
#      </li>
#      <li class="js-topbar-dialog-corral" role="presentation">
#       <div class="topbar-dialog siteSwitcher-dialog dno" role="menu">
#        <div class="header fw-wrap">
#         <h3 class="flex--item">
#          <a href="https://stackoverflow.com">
#           current community
#          </a>
#         </h3>
#         <div class="flex--item fl1">
#          <div class="ai-center d-flex jc-end">
#           <button aria-label="Close" class="js-close-button s-btn s-btn__muted p0 ml8 d-none sm:d-block" type="button">
#            <svg aria-hidden="true" class="svg-icon iconClear" height="18" viewbox="0 0 18 18" width="18">
#             <path d="M15 4.41 13.59 3 9 7.59 4.41 3 3 4.41 7.59 9 3 13.59 4.41 15 9 10.41 13.59 15 15 13.59 10.41 9 15 4.41Z">
#             </path>
#            </svg>
#           </button>
#          </div>
#         </div>
#        </div>
#        <div class="modal-content bg-powder-050 current-site-container">
#         <ul class="current-site ">
#          <li class="d-flex">
#           <div class="fl1">
#            <a class="current-site-link site-link js-gps-track d-flex gs8 gsx" data-gps-track="site_switcher.click({ item_type:3 })" data-id="1" href="https://stackoverflow.com">
#             <div class="favicon favicon-stackoverflow site-icon flex--item" title="Stack Overflow">
#             </div>
#             <span class="flex--item fl1">
#              Stack Overflow
#             </span>
#            </a>
#           </div>
#           <div class="related-links">
#            <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:14 })" href="https://stackoverflow.com/help">
#             help
#            </a>
#            <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:6 })" href="https://chat.stackoverflow.com/?tab=site&amp;host=stackoverflow.com">
#             chat
#            </a>
#           </div>
#          </li>
#          <li class="related-site d-flex">
#           <div class="L-shaped-icon-container">
#            <span class="L-shaped-icon">
#            </span>
#           </div>
#           <a class=" site-link js-gps-track d-flex gs8 gsx" data-gps-track="site.switch({ target_site:552, item_type:3 }),site_switcher.click({ item_type:4 })" data-id="552" href="https://meta.stackoverflow.com">
#            <div class="favicon favicon-stackoverflowmeta site-icon flex--item" title="Meta Stack Overflow">
#            </div>
#            <span class="flex--item fl1">
#             Meta Stack Overflow
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="header" id="your-communities-header">
#         <h3>
#          your communities
#         </h3>
#        </div>
#        <div class="modal-content" id="your-communities-section">
#         <div class="call-to-login">
#          <a class="login-link js-gps-track" data-gps-track="site_switcher.click({ item_type:10 })" href="https://stackoverflow.com/users/signup?ssrc=site_switcher&amp;returnurl=%2fusers%2fstory%2fcurrent">
#           Sign up
#          </a>
#          or
#          <a class="login-link js-gps-track" data-gps-track="site_switcher.click({ item_type:11 })" href="https://stackoverflow.com/users/login?ssrc=site_switcher&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2ftagged%2fjava">
#           log in
#          </a>
#          to customize your list.
#         </div>
#        </div>
#        <div class="header">
#         <h3>
#          <a href="https://stackexchange.com/sites">
#           more stack exchange communities
#          </a>
#         </h3>
#         <a class="float-right" href="https://stackoverflow.blog">
#          company blog
#         </a>
#        </div>
#        <div class="modal-content">
#         <div class="child-content">
#         </div>
#        </div>
#       </div>
#      </li>
#     </ol>
#    </div>
#   </header>
#   <script>
#    StackExchange.ready(function () { StackExchange.topbar.init(); });
#         StackExchange.scrollPadding.setPaddingTop(50, 10);
#   </script>
#   <div class="container">
#    <div class="left-sidebar js-pinned-left-sidebar ps-relative" data-is-here-when="md lg" id="left-sidebar">
#     <div class="left-sidebar--sticky-container js-sticky-leftnav">
#      <nav role="navigation">
#       <ol class="nav-links">
#        <li class="">
#         <a aria-controls="" class="pl8 js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:8})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/">
#          <div class="d-flex ai-center">
#           <div class="flex--item truncate">
#            Home
#           </div>
#          </div>
#         </a>
#        </li>
#        <li>
#         <ol class="nav-links">
#          <li class="fs-fine tt-uppercase ml8 mt16 mb4 fc-light">
#           Public
#          </li>
#          <li class=" youarehere">
#           <a aria-controls="" class="pl8 js-gps-track nav-links--link -link__with-icon" data-controller="" data-gps-track="top_nav.click({is_current:true, location:5, destination:1})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/questions" id="nav-questions">
#            <svg aria-hidden="true" class="svg-icon iconGlobe" height="18" viewbox="0 0 18 18" width="18">
#             <path d="M9 1C4.64 1 1 4.64 1 9c0 4.36 3.64 8 8 8 4.36 0 8-3.64 8-8 0-4.36-3.64-8-8-8ZM8 15.32a6.46 6.46 0 01-4.3-2.74 6.46 6.46 0 01-.93-5.01L7 11.68v.8c0 .88.12 1.32 1 1.32v1.52Zm5.72-2c-.2-.66-1-1.32-1.72-1.32h-1v-2c0-.44-.56-1-1-1H6V7h1c.44 0 1-.56 1-1V5h2c.88 0 1.4-.72 1.4-1.6v-.33a6.45 6.45 0 013.83 4.51 6.45 6.45 0 01-1.51 5.73v.01Z">
#             </path>
#            </svg>
#            <span class="-link--channel-name">
#             Questions
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:2})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/tags" id="nav-tags">
#            <div class="d-flex ai-center">
#             <div class="flex--item truncate">
#              Tags
#             </div>
#            </div>
#           </a>
#          </li>
#          <li class="">
#           <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:3})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/users" id="nav-users">
#            <div class="d-flex ai-center">
#             <div class="flex--item truncate">
#              Users
#             </div>
#            </div>
#           </a>
#          </li>
#          <li class="d-flex ml8 mt16 mb4 jc-space-between">
#           <div class="flex--item tt-uppercase tt-uppercase fs-fine fc-light">
#            Collectives
#           </div>
#           <div class="flex--item fs-fine fc-light">
#            <a aria-controls="popover-discover-collectives" class="s-link s-link__inherit mr8 js-gps-track" data-action="s-popover#toggle" data-controller="s-popover" data-gps-track="top_nav.click({is_current:false, location:5, destination:17})" data-s-popover-placement="top" data-s-popover-toggle-class="is-selected" href="javascript:void(0)" role="button">
#             <svg aria-hidden="true" class="svg-icon iconInfoSm" height="14" viewbox="0 0 14 14" width="14">
#              <path d="M7 1a6 6 0 110 12A6 6 0 017 1Zm1 10V6H6v5h2Zm0-6V3H6v2h2Z">
#              </path>
#             </svg>
#            </a>
#           </div>
#          </li>
#          <li class="">
#           <a aria-controls="" class="pl8 ai-center js-gps-track nav-links--link -link__with-icon" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:18})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/collectives" id="nav-collective-discover">
#            <svg aria-hidden="true" class="mt-auto fc-orange-400 svg-icon iconStarVerified" height="18" viewbox="0 0 18 18" width="18">
#             <path d="M9.86.89a1.14 1.14 0 00-1.72 0l-.5.58c-.3.35-.79.48-1.23.33l-.72-.25a1.14 1.14 0 00-1.49.85l-.14.76c-.1.45-.45.8-.9.9l-.76.14c-.67.14-1.08.83-.85 1.49l.25.72c.15.44.02.92-.33 1.23l-.58.5a1.14 1.14 0 000 1.72l.58.5c.35.3.48.79.33 1.23l-.25.72c-.23.66.18 1.35.85 1.49l.76.14c.45.1.8.45.9.9l.14.76c.14.67.83 1.08 1.49.85l.72-.25c.44-.15.92-.02 1.23.33l.5.58c.46.52 1.26.52 1.72 0l.5-.58c.3-.35.79-.48 1.23-.33l.72.25c.66.23 1.35-.18 1.49-.85l.14-.76c.1-.45.45-.8.9-.9l.76-.14c.67-.14 1.08-.83.85-1.49l-.25-.72c-.15-.44-.02-.92.33-1.23l.58-.5c.52-.46.52-1.26 0-1.72l-.58-.5c-.35-.3-.48-.79-.33-1.23l.25-.72a1.14 1.14 0 00-.85-1.49l-.76-.14c-.45-.1-.8-.45-.9-.9l-.14-.76a1.14 1.14 0 00-1.49-.85l-.72.25c-.44.15-.92.02-1.23-.33l-.5-.58Zm-.49 2.67L10.6 6.6c.05.15.19.24.34.25l3.26.22c.36.03.5.48.23.71l-2.5 2.1a.4.4 0 00-.14.4l.8 3.16a.4.4 0 01-.6.44L9.2 12.13a.4.4 0 00-.42 0l-2.77 1.74a.4.4 0 01-.6-.44l.8-3.16a.4.4 0 00-.13-.4l-2.5-2.1a.4.4 0 01.22-.7l3.26-.23a.4.4 0 00.34-.25l1.22-3.03a.4.4 0 01.74 0Z">
#             </path>
#            </svg>
#            <span class="-link--channel-name">
#             Explore Collectives
#            </span>
#           </a>
#          </li>
#          <li class="fs-fine tt-uppercase ml8 mt16 mb4 fc-light">
#           Find a Job
#          </li>
#          <li class="">
#           <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:6})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/jobs?so_medium=StackOverflow&amp;so_source=SiteNav" id="nav-jobs">
#            <div class="d-flex ai-center">
#             <div class="flex--item truncate">
#              Jobs
#             </div>
#            </div>
#           </a>
#          </li>
#          <li class="">
#           <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:12})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/jobs/companies?so_medium=StackOverflow&amp;so_source=SiteNav" id="nav-companies">
#            <div class="d-flex ai-center">
#             <div class="flex--item truncate">
#              Companies
#             </div>
#            </div>
#           </a>
#          </li>
#         </ol>
#        </li>
#        <li>
#         <ol class="nav-links">
#          <div class="js-freemium-cta ps-relative">
#           <div class="fs-fine tt-uppercase ml8 mt16 mb8 fc-light">
#            Teams
#           </div>
#           <div class="bt bl bb bc-black-075 p12 pb6 fc-black-600 blr-sm overflow-hidden">
#            <strong class="fc-black-750 mb6">
#             Stack Overflow for Teams
#            </strong>
#            – Collaborate and share knowledge with a private group.
#            <img alt="" class="wmx100 mx-auto my8 h-auto d-block" height="114" src="https://cdn.sstatic.net/Img/teams/teams-illo-free-sidebar-promo.svg?v=47faa659a05e" width="139"/>
#            <a class="w100 s-btn s-btn__primary s-btn__xs js-gps-track" data-ga='["teams left navigation - anonymous","left nav free cta","stackoverflow.com/teams/create/free",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: 6 })" href="https://stackoverflow.com/teams/create/free?utm_source=so-owned&amp;utm_medium=side-bar&amp;utm_campaign=campaign-38&amp;utm_content=cta">
#             Create a free Team
#            </a>
#            <a class="w100 s-btn s-btn__muted s-btn__xs js-gps-track" data-ga='["teams left navigation - anonymous","left nav free cta","stackoverflow.com/teams",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: 5 })" href="https://stackoverflow.com/teams">
#             What is Teams?
#            </a>
#           </div>
#          </div>
#          <li class="d-flex ai-center jc-space-between ml8 mt24 mb4 js-create-team-cta d-none">
#           <div class="flex--item tt-uppercase fs-fine fc-light">
#            Teams
#           </div>
#           <div class="flex--item">
#            <a aria-controls="popover-teams-create-cta" class="s-link p12 fc-black-500 h:fc-black-800 js-gps-track" data-action="s-popover#toggle" data-controller="s-popover" data-ga='["teams left navigation - anonymous","left nav show teams info",null,null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: ShowInfo })" data-s-popover-placement="bottom-start" data-s-popover-toggle-class="is-selected" href="javascript:void(0)" role="button">
#             <svg aria-hidden="true" class="svg-icon iconInfoSm" height="14" viewbox="0 0 14 14" width="14">
#              <path d="M7 1a6 6 0 110 12A6 6 0 017 1Zm1 10V6H6v5h2Zm0-6V3H6v2h2Z">
#              </path>
#             </svg>
#            </a>
#           </div>
#          </li>
#          <li class="ps-relative js-create-team-cta d-none">
#           <a class="pl8 js-gps-track nav-links--link" data-ga='["teams left navigation - anonymous","left nav team click","stackoverflow.com/teams/create/free",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: FreemiumTeamsCreateClick })" href="https://stackoverflow.com/teams/create/free?utm_source=so-owned&amp;utm_medium=side-bar&amp;utm_campaign=campaign-38&amp;utm_content=cta" title="Stack Overflow for Teams is a private, secure spot for your organization's questions and answers.">
#            <div class="d-flex ai-center">
#             <div class="flex--item s-avatar va-middle bg-orange-400">
#              <div class="s-avatar--letter mtn1">
#               <svg aria-hidden="true" class="svg-icon iconBriefcaseSm" height="14" viewbox="0 0 14 14" width="14">
#                <path d="M4 3a1 1 0 011-1h4a1 1 0 011 1v1h.5c.83 0 1.5.67 1.5 1.5v5c0 .83-.67 1.5-1.5 1.5h-7A1.5 1.5 0 012 10.5v-5C2 4.67 2.67 4 3.5 4H4V3Zm5 1V3H5v1h4Z">
#                </path>
#               </svg>
#              </div>
#              <svg aria-hidden="true" class="native s-avatar--badge svg-icon iconShieldXSm" height="10" viewbox="0 0 9 10" width="9">
#               <path d="M0 1.84 4.5 0 9 1.84v3.17C9 7.53 6.3 10 4.5 10 2.7 10 0 7.53 0 5.01V1.84Z" fill="var(--white)">
#               </path>
#               <path d="M1 2.5 4.5 1 8 2.5v2.51C8 7.34 5.34 9 4.5 9 3.65 9 1 7.34 1 5.01V2.5Zm2.98 3.02L3.2 7h2.6l-.78-1.48a.4.4 0 01.15-.38c.34-.24.73-.7.73-1.14 0-.71-.5-1.23-1.41-1.23-.92 0-1.39.52-1.39 1.23 0 .44.4.9.73 1.14.12.08.18.23.15.38Z" fill="var(--black-500)">
#               </path>
#              </svg>
#             </div>
#             <div class="flex--item pl6">
#              Create free Team
#             </div>
#            </div>
#           </a>
#          </li>
#         </ol>
#        </li>
#       </ol>
#      </nav>
#     </div>
#     <div aria-hidden="true" class="s-popover ws2" id="popover-discover-collectives" role="menu">
#      <div class="s-popover--arrow">
#      </div>
#      <div>
#       <svg aria-hidden="true" class="fc-orange-500 float-right ml24 svg-spot spotCollective" height="48" viewbox="0 0 48 48" width="48">
#        <path d="M25.5 7a2.5 2.5 0 100-5 2.5 2.5 0 0 0 0 5zM14 18.25c0-.69.56-1.25 1.25-1.25h22.5c.69 0 1.25.56 1.25 1.25V37.5a1 1 0 01-1.6.8l-4.07-3.05a1.25 1.25 0 00-.75-.25H15.25c-.69 0-1.25-.56-1.25-1.25v-15.5zM7 24.5a2.5 2.5 0 11-5 0 2.5 2.5 0 0 1 5 0zM25.5 48a2.5 2.5 0 100-5 2.5 2.5 0 0 0 0 5zM48 24.5a2.5 2.5 0 11-5 0 2.5 2.5 0 0 1 5 0z" opacity=".2">
#        </path>
#        <path d="M21 3.5a3.5 3.5 0 117 0 3.5 3.5 0 0 1-7 0zM24.5 2a1.5 1.5 0 100 3 1.5 1.5 0 0 0 0-3zM0 23.5a3.5 3.5 0 117 0 3.5 3.5 0 0 1-7 0zM3.5 22a1.5 1.5 0 100 3 1.5 1.5 0 0 0 0-3zM21 44.5a3.5 3.5 0 117 0 3.5 3.5 0 0 1-7 0zm3.5-1.5a1.5 1.5 0 100 3 1.5 1.5 0 0 0 0-3zm20-23a3.5 3.5 0 100 7 3.5 3.5 0 0 0 0-7zM43 23.5a1.5 1.5 0 113 0 1.5 1.5 0 0 1-3 0zm-23.23-3.14a1 1 0 01-.13 1.4l-2.08 1.74 2.08 1.73a1 1 0 11-1.28 1.54l-2.42-2.02a1.63 1.63 0 010-2.5l2.42-2.02a1 1 0 011.4.13zm7.59 1.41a1 1 0 111.28-1.54l2.42 2.02c.78.65.78 1.85 0 2.5l-2.42 2.02a1 1 0 11-1.28-1.54l2.08-1.73-2.08-1.73zM24.12 18a1 1 0 01.87 1.12l-1 8a1 1 0 11-1.98-.24l1-8a1 1 0 011.11-.87zm-11.87-5C11.01 13 10 14 10 15.25v15.5c0 1.24 1 2.25 2.25 2.25h17.33c.06 0 .11.02.15.05l4.07 3.05a2 2 0 003.2-1.6V15.25c0-1.24-1-2.25-2.25-2.25h-22.5zM12 15.25c0-.14.11-.25.25-.25h22.5c.14 0 .25.11.25.25V34.5l-4.07-3.05a2.2 2.2 0 00-1.35-.45H12.25a.25.25 0 01-.25-.25v-15.5zm7.24-10.68a1 1 0 10-.48-1.94A22.04 22.04 0 002.91 17.7a1 1 0 101.92.58 20.04 20.04 0 0 1 14.4-13.72zm11.05-1.66a1 1 0 00-.58 1.92c6.45 1.92 11.54 7 13.46 13.46a1 1 0 101.92-.58 22.05 22.05 0 0 0-14.8-14.8zM4.57 28.76a1 1 0 00-1.94.48 22.03 22.03 0 0 0 16.13 16.13 1 1 0 1 0 .48-1.94A20.03 20.03 0 014.57 28.76zm40.8.48a1 1 0 10-1.94-.48 20.04 20.04 0 0 1-13.72 14.41 1 1 0 0 0 .58 1.92 22.04 22.04 0 0 0 15.08-15.85z">
#        </path>
#       </svg>
#       <div class="pt4 fw-bold">
#        Collectives on Stack Overflow
#       </div>
#       <p class="my16 fs-caption fc-medium">
#        Find centralized, trusted content and collaborate around the technologies you use most.
#       </p>
#       <a class="js-gps-track s-btn s-btn__primary s-btn__xs" data-gps-track="top_nav.click({is_current:false, location:5, destination:18})" href="/collectives">
#        Learn more
#       </a>
#      </div>
#     </div>
#     <div aria-hidden="true" class="s-popover" id="popover-teams-create-cta" role="menu">
#      <div class="s-popover--arrow">
#      </div>
#      <div class="ps-relative overflow-hidden">
#       <p class="mb2">
#        <strong>
#         Teams
#        </strong>
#       </p>
#       <p class="mb12 fs-caption fc-black-400">
#        Q&amp;A for work
#       </p>
#       <p class="mb12 fs-caption fc-medium">
#        Connect and share knowledge within a single location that is structured and easy to search.
#       </p>
#       <a class="js-gps-track s-btn s-btn__primary s-btn__xs" data-ga='["teams left navigation - anonymous","left nav cta","stackoverflow.com/teams",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: CtaClick })" href="https://stackoverflow.com/teams">
#        Learn more
#       </a>
#      </div>
#      <div class="ps-absolute t8 r8">
#       <svg aria-hidden="true" class="fc-orange-500 svg-spot spotPeople" height="48" viewbox="0 0 48 48" width="48">
#        <path d="M13.5 28a4.5 4.5 0 100-9 4.5 4.5 0 0 0 0 9zM7 30a1 1 0 011-1h11a1 1 0 011 1v5h11v-5a1 1 0 011-1h12a1 1 0 011 1v10a2 2 0 01-2 2H33v5a1 1 0 01-1 1H20a1 1 0 01-1-1v-5H8a1 1 0 01-1-1V30zm25-6.5a4.5 4.5 0 109 0 4.5 4.5 0 0 0-9 0zM24.5 34a4.5 4.5 0 100-9 4.5 4.5 0 0 0 0 9z" opacity=".2">
#        </path>
#        <path d="M16.4 26.08A6 6 0 107.53 26C5.64 26.06 4 27.52 4 29.45V40a1 1 0 001 1h9a1 1 0 100-2h-4v-7a1 1 0 10-2 0v7H6v-9.55c0-.73.67-1.45 1.64-1.45H16a1 1 0 00.4-1.92zM12 18a4 4 0 110 8 4 4 0 0 1 0-8zm16.47 14a6 6 0 10-8.94 0A3.6 3.6 0 0016 35.5V46a1 1 0 001 1h14a1 1 0 001-1V35.5c0-1.94-1.64-3.42-3.53-3.5zM20 28a4 4 0 118 0 4 4 0 0 1-8 0zm-.3 6h8.6c1 0 1.7.75 1.7 1.5V45h-2v-7a1 1 0 10-2 0v7h-4v-7a1 1 0 10-2 0v7h-2v-9.5c0-.75.7-1.5 1.7-1.5zM42 22c0 1.54-.58 2.94-1.53 4A3.5 3.5 0 0144 29.45V40a1 1 0 01-1 1h-9a1 1 0 110-2h4v-7a1 1 0 112 0v7h2v-9.55A1.5 1.5 0 0040.48 28H32a1 1 0 01-.4-1.92A6 6 0 1142 22zm-2 0a4 4 0 10-8 0 4 4 0 0 0 8 0z">
#        </path>
#        <path d="M17 10a1 1 0 011-1h12a1 1 0 110 2H18a1 1 0 01-1-1zm1-5a1 1 0 100 2h12a1 1 0 100-2H18zm-4-4a1 1 0 00-1 1v12a1 1 0 001 1h5.09l4.2 4.2a1 1 0 001.46-.04l3.7-4.16H34a1 1 0 001-1V2a1 1 0 00-1-1H14zm1 12V3h18v10h-5a1 1 0 00-.75.34l-3.3 3.7-3.74-3.75a1 1 0 00-.71-.29H15z" opacity=".35">
#        </path>
#       </svg>
#      </div>
#     </div>
#    </div>
#    <div class="snippet-hidden" id="content">
#     <div id="mainbar">
#      <div class="d-flex">
#       <div class="d-flex fl1 mb24">
#        <h1 class="flex--item fs-headline1 mb0">
#         Questions tagged [java]
#        </h1>
#       </div>
#       <div class="ml12 aside-cta flex--item print:d-none">
#        <a class="ws-nowrap s-btn s-btn__primary" href="/questions/ask">
#         Ask Question
#        </a>
#       </div>
#      </div>
#      <style>
#      </style>
#      <div class="js-zone-container zone-container-main">
#       <div class="everyonelovesstackoverflow everyoneloves__tag-sponsorship theme-light__forced bg-white" id="dfp-tag">
#       </div>
#       <div class="js-report-ad-button-container " style="width: 728px">
#       </div>
#      </div>
#      <div class="mb24">
#       <p>
#        Java is a high-level object oriented programming language. Use this tag when you're having problems using or understanding the language itself. This tag is frequently used alongside other tags for libraries and/or frameworks used by Java developers.
#       </p>
#       <div class=" d-flex gs12 jc-space-between ai-center fw-wrap">
#        <div class="flex--item">
#         <ul class="d-flex gs12 list-ls-none fw-wrap">
#          <li class="flex--item">
#           <a href="/tags/java/info" title="Tag wiki">
#            Learn more…
#           </a>
#          </li>
#          <li class="flex--item">
#           <a href="/tags/java/topusers" title="Top answerers and askers in this tag">
#            Top users
#           </a>
#          </li>
#          <li class="flex--item">
#           <a href="/tags/java/synonyms" title="Common, alternate spellings or phrasings for this tag">
#            Synonyms (11)
#           </a>
#          </li>
#          <li class="flex--item">
#           <a href="/jobs/developer-jobs-using-java?med=site-ui&amp;ref=tag-page_java" title="Find yourself a job">
#            java jobs
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <script>
#       StackExchange.ready(function () {
#         initTagRenderer("".split(" "), "".split(" "));
#         StackExchange.userQuestionList.init({
#             sharingUrl: ""
#         });
#     });
#      </script>
#      <div data-controller="se-uql" data-se-uql-id="" data-se-uql-sanitize-tag-query="false">
#       <div class="d-flex ai-center jc-space-between mb12 sm:fd-column sm:ai-stretch">
#        <div class="fs-body3 flex--item fl1 mr12 sm:mr0 sm:mb12">
#         1,816,414
#             questions
#        </div>
#        <div class="uql-nav flex--item" data-action="se-uql-list:edit-current-requested@document-&gt;se-uql#toggleEditor">
#         <div class="d-flex ai-center jc-space-between">
#          <div class="js-uql-navigation s-btn-group flex--item mr16 ff-row-nowrap">
#           <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex is-selected" data-nav-value="Newest" data-shortcut="N" href="/questions/tagged/java?tab=Newest">
#            <div class="flex--item">
#             Newest
#            </div>
#           </a>
#           <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex" data-nav-value="Active" data-shortcut="A" href="/questions/tagged/java?tab=Active">
#            <div class="flex--item">
#             Active
#            </div>
#           </a>
#           <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex uql-nav--expanded-item" data-nav-value="Bounties" data-shortcut="E" href="/questions/tagged/java?tab=Bounties">
#            <div class="flex--item">
#             Bountied
#            </div>
#            <div class="s-badge s-badge__bounty s-badge__bounty s-badge__sm lh-xs ml4 px4 flex--item">
#             20
#            </div>
#           </a>
#           <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex uql-nav--expanded-item" data-nav-value="Unanswered" data-shortcut="U" href="/questions/tagged/java?tab=Unanswered">
#            <div class="flex--item">
#             Unanswered
#            </div>
#           </a>
#           <button aria-controls="uql-more-popover" aria-expanded="false" aria-haspopup="true" class="s-btn s-btn__muted s-btn__outlined s-btn__sm s-btn__dropdown" data-action="s-popover#toggle" data-controller="s-popover" data-se-uql-target="toggleMoreButton" role="button">
#            More
#           </button>
#          </div>
#          <div class="s-popover z-dropdown ws2" data-se-uql-target="morePopover" id="uql-more-popover">
#           <div class="s-popover--arrow">
#           </div>
#           <ul class="list-reset mtn8 mbn8 js-uql-navigation">
#            <li class="uql-item my0 uql-nav--collapsed-item">
#             <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="" href="/questions/tagged/java?tab=Bounties">
#              Bountied
#              <span class="s-badge s-badge__bounty s-badge__bounty s-badge__sm lh-xs px4">
#               20
#              </span>
#             </a>
#            </li>
#            <li class="uql-item my0 uql-nav--collapsed-item">
#             <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="" href="/questions/tagged/java?tab=Unanswered">
#              Unanswered
#             </a>
#            </li>
#            <li class="uql-item my0">
#             <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="F" href="/questions/tagged/java?tab=Frequent">
#              Frequent
#             </a>
#            </li>
#            <li class="uql-item my0">
#             <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="V" href="/questions/tagged/java?tab=Votes">
#              Votes
#             </a>
#            </li>
#            <li class="uql-item uql-item__separator bg-black-075 d:bg-black-025">
#            </li>
#            <li class="uql-item my0">
#             <span class="s-block-link c-default fc-black-350 mln12 mrn12 px12 py6">
#              Unanswered (my tags)
#             </span>
#            </li>
#           </ul>
#          </div>
#          <div class="flex--item">
#           <button aria-controls="uql-form" aria-expanded="false" class="s-btn s-btn__filled s-btn__sm s-btn__icon ws-nowrap" data-controller="s-expandable-control" data-s-expandable-control-toggle-class="is-selected" data-se-uql-target="toggleFormButton" role="button">
#            <svg aria-hidden="true" class="svg-icon iconFilter" height="18" viewbox="0 0 18 18" width="18">
#             <path d="M2 4h14v2H2V4Zm2 4h10v2H4V8Zm8 4H6v2h6v-2Z">
#             </path>
#            </svg>
#            Filter
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#       <form class="s-expandable ps-relative z-active" data-action="se-uql#navigate" data-se-uql-target="form" id="uql-form">
#        <input name="uqlId" type="hidden"/>
#        <div class="s-expandable--content">
#         <div class="bg-black-050 ba bc-black-100 bar-sm mb16">
#          <div class="px12 py16">
#           <div class="d-flex gs32 fw-wrap">
#            <div class="flex--item">
#             <fieldset class="d-flex gs8 gsy fd-column">
#              <legend class="flex--item s-label px0">
#               Filter by
#              </legend>
#              <div class="flex--item">
#               <div class="d-flex gs4 gsx ai-center">
#                <div class="flex--item">
#                 <input class="s-checkbox d-block" id="7d4b1108-7a58-49f2-aa10-a2370cb30668" name="filterId" type="checkbox" value="NoAnswers"/>
#                </div>
#                <label class="flex--item s-label fw-normal ws-nowrap" for="7d4b1108-7a58-49f2-aa10-a2370cb30668">
#                 No answers
#                </label>
#               </div>
#              </div>
#              <div class="flex--item">
#               <div class="d-flex gs4 gsx ai-center">
#                <div class="flex--item">
#                 <input class="s-checkbox d-block" id="062f790c-5c33-4df7-a1ec-982b49098774" name="filterId" type="checkbox" value="NoAcceptedAnswer"/>
#                </div>
#                <label class="flex--item s-label fw-normal ws-nowrap" for="062f790c-5c33-4df7-a1ec-982b49098774">
#                 No accepted answer
#                </label>
#               </div>
#              </div>
#              <div class="flex--item">
#               <div class="d-flex gs4 gsx ai-center">
#                <div class="flex--item">
#                 <input class="s-checkbox d-block" id="95181a74-afa5-4d41-8fff-0aeeb4371521" name="filterId" type="checkbox" value="Bounty"/>
#                </div>
#                <label class="flex--item s-label fw-normal ws-nowrap" for="95181a74-afa5-4d41-8fff-0aeeb4371521">
#                 Has bounty
#                </label>
#               </div>
#              </div>
#             </fieldset>
#            </div>
#            <div class="flex--item">
#             <fieldset class="d-flex gs8 gsy fd-column">
#              <legend class="flex--item s-label px0">
#               Sorted by
#              </legend>
#              <div class="flex--item">
#               <div class="d-flex gs4 gsx ai-center">
#                <div class="flex--item">
#                 <input checked="checked" class="s-radio d-block" id="e5873541-3e3d-4795-913e-9c992b13be03" name="sortId" type="radio" value="Newest"/>
#                </div>
#                <label class="flex--item s-label fw-normal ws-nowrap" for="e5873541-3e3d-4795-913e-9c992b13be03">
#                 Newest
#                </label>
#               </div>
#              </div>
#              <div class="flex--item">
#               <div class="d-flex gs4 gsx ai-center">
#                <div class="flex--item">
#                 <input class="s-radio d-block" id="86b630e5-b281-4dfe-abdf-9f72f0963850" name="sortId" type="radio" value="RecentActivity"/>
#                </div>
#                <label class="flex--item s-label fw-normal ws-nowrap" for="86b630e5-b281-4dfe-abdf-9f72f0963850">
#                 Recent activity
#                </label>
#               </div>
#              </div>
#              <div class="flex--item">
#               <div class="d-flex gs4 gsx ai-center">
#                <div class="flex--item">
#                 <input class="s-radio d-block" id="fa505287-5f01-4ac0-99ca-2561ff250d50" name="sortId" type="radio" value="MostVotes"/>
#                </div>
#                <label class="flex--item s-label fw-normal ws-nowrap" for="fa505287-5f01-4ac0-99ca-2561ff250d50">
#                 Most votes
#                </label>
#               </div>
#              </div>
#              <div class="flex--item">
#               <div class="d-flex gs4 gsx ai-center">
#                <div class="flex--item">
#                 <input class="s-radio d-block" id="3f90d890-df34-4c3b-a086-4ec3981f1550" name="sortId" type="radio" value="MostFrequent"/>
#                </div>
#                <label class="flex--item s-label fw-normal ws-nowrap" for="3f90d890-df34-4c3b-a086-4ec3981f1550">
#                 Most frequent
#                </label>
#               </div>
#              </div>
#              <div class="flex--item">
#               <div class="d-flex gs4 gsx ai-center">
#                <div class="flex--item">
#                 <input class="s-radio d-block" id="73c45878-ad48-4552-9fd4-c05257fa254a" name="sortId" type="radio" value="BountyEndingSoon"/>
#                </div>
#                <label class="flex--item s-label fw-normal ws-nowrap" for="73c45878-ad48-4552-9fd4-c05257fa254a">
#                 Bounty ending soon
#                </label>
#               </div>
#              </div>
#             </fieldset>
#            </div>
#            <div class="flex--item">
#             <fieldset class="d-flex gs8 gsy fd-column">
#              <legend class="flex--item s-label px0">
#               Tagged with
#              </legend>
#              <div class="flex--item">
#               <div class="d-flex gs4 gsx ai-center">
#                <div class="flex--item">
#                 <input class="s-radio d-block" id="6888d9c1-e225-4f40-bfeb-4108f3892172" name="tagModeId" type="radio" value="Watched"/>
#                </div>
#                <label class="flex--item s-label fw-normal ws-nowrap" for="6888d9c1-e225-4f40-bfeb-4108f3892172">
#                 My watched tags
#                </label>
#               </div>
#              </div>
#              <div class="flex--item">
#               <div class="d-flex gs4 gsx ai-center">
#                <div class="flex--item">
#                 <input checked="checked" class="s-radio d-block" id="9855fdb1-a0cf-4d39-8628-e27bcc47a113" name="tagModeId" type="radio" value="Specified"/>
#                </div>
#                <label class="flex--item s-label fw-normal ws-nowrap" for="9855fdb1-a0cf-4d39-8628-e27bcc47a113">
#                 The following tags:
#                </label>
#               </div>
#              </div>
#             </fieldset>
#             <div class="ps-relative ml24 mt8 ws2">
#              <input class="w100 s-input" data-se-uql-target="tagQuery" id="uql-modal-tag-input" name="tagQuery" placeholder="e.g. javascript or python" size="60" tabindex="0" type="text" value="java"/>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="p12 bt bc-black-100">
#           <div class="d-flex">
#            <div class="d-flex gs4 gsx fl1">
#             <button class="s-btn s-btn__sm s-btn__primary flex--item" data-se-uql-target="applyButton" type="submit">
#              Apply filter
#             </button>
#            </div>
#            <div class="flex--item">
#             <button class="s-btn s-btn__sm" data-action="se-uql#cancelEditor" type="button">
#              Cancel
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </form>
#      </div>
#      <div class="bt bc-black-100 mln24 pl24" id="questions">
#       <div class="mln24">
#        <div class="question-summary" id="question-summary-70312057">
#         <div class="statscontainer">
#          <div class="stats">
#           <div class="vote">
#            <div class="votes">
#             <span class="vote-count-post ">
#              <strong>
#               0
#              </strong>
#             </span>
#             <div class="viewcount">
#              votes
#             </div>
#            </div>
#           </div>
#           <div class="status unanswered">
#            <strong>
#             0
#            </strong>
#            answers
#           </div>
#          </div>
#          <div class="views " title="4 views">
#           4 views
#          </div>
#         </div>
#         <div class="summary">
#          <h3>
#           <a class="question-hyperlink" href="/questions/70312057/match-every-single-string-after-character-in-java-regex">
#            Match every single String after character in Java (RegEx)
#           </a>
#          </h3>
#          <div class="excerpt">
#           I need help with this, so uhm... I have a String:
# ...
#   </script>
#   <script>
#    var clc = clc || {};
#     clc.collapse = { sb: !0, 'tag-sponsorship': !0, lb: !0, mlb: !0, smlb: !0, bmlb: !0, 'mobile-below-question': !0 };
#     clc.options = clc.options || {};
#     clc.options.sf = !0;
#     clc.options.hb = !1;
#     clc.options.ll = !0;
#     clc.options.targeting_consent = !1;
#     clc.options.performance_consent = !1;
#         clc.cmd = clc.cmd || [];
#         clc.cmd.push(function () { window.clc_request='A-bJV9dIvNkIAAAAAAAAAAACAAAAAQAAAAAABgAAAHxqYXZhfADyVs5sLHIJ5wuW'; clc.load(); });
#         StackExchange.ready(function () { googletag.cmd.push(function () { StackExchange.ads.init(googletag, '/ads/report-ad', 'Report this ad') }) });
#   </script>
#   <footer class="site-footer js-footer" id="footer" role="contentinfo">
#    <div class="site-footer--container">
#     <div class="site-footer--logo">
#      <a href="https://stackoverflow.com">
#       <svg aria-hidden="true" class="native svg-icon iconLogoGlyphMd" height="37" viewbox="0 0 32 37" width="32">
#        <path d="M26 33v-9h4v13H0V24h4v9h22Z" fill="#BCBBBB">
#        </path>
#        <path d="m21.5 0-2.7 2 9.9 13.3 2.7-2L21.5 0ZM26 18.4 13.3 7.8l2.1-2.5 12.7 10.6-2.1 2.5ZM9.1 15.2l15 7 1.4-3-15-7-1.4 3Zm14 10.79.68-2.95-16.1-3.35L7 23l16.1 2.99ZM23 30H7v-3h16v3Z" fill="#F48024">
#        </path>
#       </svg>
#      </a>
#     </div>
#     <nav class="site-footer--nav">
#      <div class="site-footer--col">
#       <h5 class="-title">
#        <a class="js-gps-track" data-gps-track="footer.click({ location: 5, link: 15})" href="https://stackoverflow.com">
#         Stack Overflow
#        </a>
#       </h5>
#       <ul class="-list js-primary-footer-links">
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 16})" href="/questions">
#          Questions
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 17})" href="https://stackoverflow.com/jobs">
#          Jobs
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 11})" href="https://stackoverflow.com/jobs/directory/developer-jobs">
#          Developer Jobs Directory
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 28})" href="https://stackoverflow.com/jobs/salary">
#          Salary Calculator
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 3 })" href="/help">
#          Help
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 12 })" onclick='StackExchange.switchMobile("on")'>
#          Mobile
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="site-footer--col">
#       <h5 class="-title">
#        <a class="js-gps-track" data-gps-track="footer.click({ location: 5, link: 19 })" href="https://stackoverflowbusiness.com">
#         Products
#        </a>
#       </h5>
#       <ul class="-list">
#        <li>
#         <a class="js-gps-track -link" data-ga='["teams traffic","footer - site nav","stackoverflow.com/teams",null,{"dimension4":"teams"}]' data-gps-track="footer.click({ location: 5, link: 29 })" href="https://stackoverflow.com/teams">
#          Teams
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 20 })" href="https://stackoverflow.com/talent">
#          Talent
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 21 })" href="https://stackoverflow.com/advertising">
#          Advertising
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 22 })" href="https://stackoverflowsolutions.com/explore-teams">
#          Enterprise
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="site-footer--col">
#       <h5 class="-title">
#        <a class="js-gps-track" data-gps-track="footer.click({ location: 5, link: 1 })" href="https://stackoverflow.com/company">
#         Company
#        </a>
#       </h5>
#       <ul class="-list">
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 1 })" href="https://stackoverflow.com/company">
#          About
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 27 })" href="https://stackoverflow.com/company/press">
#          Press
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 9 })" href="https://stackoverflow.com/company/work-here">
#          Work Here
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 7 })" href="https://stackoverflow.com/legal">
#          Legal
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 8 })" href="https://stackoverflow.com/legal/privacy-policy">
#          Privacy Policy
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 37 })" href="https://stackoverflow.com/legal/terms-of-service">
#          Terms of Service
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 13 })" href="https://stackoverflow.com/company/contact">
#          Contact Us
#         </a>
#        </li>
#        <li class="" id="consent-footer-link">
#         <a class="js-gps-track -link js-cookie-settings" data-consent-popup-loader="footer" data-gps-track="footer.click({ location: 5, link: 38 })" href="#">
#          Cookie Settings
#         </a>
#        </li>
#        <li>
#         <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 39 })" href="https://stackoverflow.com/legal/cookie-policy">
#          Cookie Policy
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="site-footer--col site-footer--categories-nav">
#       <div>
#        <h5 class="-title">
#         <a data-gps-track="footer.click({ location: 5, link: 30 })" href="https://stackexchange.com">
#          Stack Exchange Network
#         </a>
#        </h5>
#        <ul class="-list">
#         <li>
#          <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#technology">
#           Technology
#          </a>
#         </li>
#         <li>
#          <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#culturerecreation">
#           Culture &amp; recreation
#          </a>
#         </li>
#         <li>
#          <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#lifearts">
#           Life &amp; arts
#          </a>
#         </li>
#         <li>
#          <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#science">
#           Science
#          </a>
#         </li>
#         <li>
#          <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#professional">
#           Professional
#          </a>
#         </li>
#         <li>
#          <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#business">
#           Business
#          </a>
#         </li>
#         <li class="mt16 md:mt0">
#          <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://api.stackexchange.com/">
#           API
#          </a>
#         </li>
#         <li>
#          <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://data.stackexchange.com/">
#           Data
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#     <div class="site-footer--copyright fs-fine md:mt24">
#      <ul class="-list -social md:mb8">
#       <li>
#        <a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link:4 })" href="https://stackoverflow.blog?blb=1">
#         Blog
#        </a>
#       </li>
#       <li>
#        <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 31 })" href="https://www.facebook.com/officialstackoverflow/">
#         Facebook
#        </a>
#       </li>
#       <li>
#        <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 32 })" href="https://twitter.com/stackoverflow">
#         Twitter
#        </a>
#       </li>
#       <li>
#        <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 33 })" href="https://linkedin.com/company/stack-overflow">
#         LinkedIn
#        </a>
#       </li>
#       <li>
#        <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 36 })" href="https://www.instagram.com/thestackoverflow">
#         Instagram
#        </a>
#       </li>
#      </ul>
#      <p class="md:mb0">
#       site design / logo © 2021 Stack Exchange Inc; user contributions licensed under
#       <a href="https://stackoverflow.com/help/licensing">
#        cc by-sa
#       </a>
#       .
#       <span id="svnrev">
#        rev 2021.12.10.40971
#       </span>
#      </p>
#     </div>
#    </div>
#   </footer>
#   <script>
#    StackExchange.ready(function () { StackExchange.responsiveness.addSwitcher(); })
#   </script>
#   <noscript>
#    <div id="noscript-warning">
#     Stack Overflow works best with JavaScript enabled
#     <img alt="" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=17440561&amp;cv=3.6.0&amp;cj=1"/>
#    </div>
#   </noscript>
#   <script>
#    (function(i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function() { (i[r].q = i[r].q || []).push(arguments) }, i[r].l = 1 * new Date(); a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m);
#             })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#             StackExchange.ready(function () {
#
#                 StackExchange.ga.init({
#                     autoLink: ["stackoverflow.blog","info.stackoverflowsolutions.com","stackoverflowsolutions.com"],
#                     sendTitles: true,
#                     tracker: window.ga,
#                     trackingCodes: [
#                         'UA-108242619-1'
#                     ],
#                         checkDimension: 'dimension42'
#                 });
#
#
#
#                     StackExchange.ga.setDimension('dimension2', '|java|');
#
#
#                     StackExchange.ga.setDimension('dimension3', 'Questions/ListByTag');
#
#
#                 StackExchange.ga.setDimension('dimension7', "1639187528.1706722618");
#
#                 StackExchange.ga.trackPageView();
#             });
#   </script>
#   <div class="ff-sans ps-fixed z-nav-fixed ws4 sm:w-auto p32 sm:p16 bg-black-750 fc-white bar-lg b16 l16 r16 js-consent-banner">
#    <svg aria-hidden="true" class="mln4 mb24 sm:d-none svg-spot spotCookieLg" height="96" style="color: var(--theme-button-filled-background-color)" viewbox="0 0 96 96" width="96">
#     <path d="M35 45.5a7.5 7.5 0 11-15 0 7.5 7.5 0 0115 0zM63.5 63a7.5 7.5 0 100-15 7.5 7.5 0 000 15zm-19 19a7.5 7.5 0 100-15 7.5 7.5 0 000 15z" opacity=".2">
#     </path>
#     <path d="M56.99 2.53a23.1 23.1 0 0114.66 6.15h.01l.01.02c.57.55.61 1.27.5 1.74v.07a10.95 10.95 0 01-3.07 4.77 9 9 0 01-6.9 2.5 10.34 10.34 0 01-9.72-10.44v-.08a10 10 0 011.03-3.74l.01-.03.02-.02c.28-.5.82-.92 1.52-.95.63-.02 1.27-.02 1.93.01zm12.04 7.83a20.1 20.1 0 00-12.2-4.83l-.92-.03c-.23.6-.38 1.25-.43 1.94a7.34 7.34 0 006.95 7.34 6 6 0 004.64-1.7c.94-.88 1.6-1.9 1.96-2.72zm15.3 8.76a6.84 6.84 0 00-5.09-.24 7.9 7.9 0 00-3.28 2.05 1.8 1.8 0 00-.3 1.95l.02.02v.02a15.16 15.16 0 008.74 7.47c.64.23 1.32.08 1.8-.33a6.63 6.63 0 001.63-1.97l.01-.03.01-.03c1.67-3.5-.12-7.32-3.54-8.91zm-5.5 3.28c.36-.25.82-.5 1.35-.67.92-.3 1.92-.35 2.89.1 2.14 1 2.92 3.14 2.11 4.88-.12.21-.26.41-.43.6l-.26-.1a12.29 12.29 0 01-5.66-4.81zM32 24a2 2 0 11-4 0 2 2 0 014 0zm12 21a2 2 0 11-4 0 2 2 0 014 0zm36 4a2 2 0 11-4 0 2 2 0 014 0zm-7 21a2 2 0 11-4 0 2 2 0 014 0zM59 81a2 2 0 11-4 0 2 2 0 014 0zM22 63a2 2 0 11-4 0 2 2 0 014 0zm27 7a9 9 0 11-18 0 9 9 0 0118 0zm-3 0a6 6 0 10-12 0 6 6 0 0012 0zM33 41a9 9 0 11-18 0 9 9 0 0118 0zm-15 0a6 6 0 1012 0 6 6 0 00-12 0zm50 11a9 9 0 11-18 0 9 9 0 0118 0zm-3 0a6 6 0 10-12 0 6 6 0 0012 0zM44.08 4.24c.31.48.33 1.09.05 1.58a17.46 17.46 0 00-2.36 8.8c0 9.55 7.58 17.24 16.85 17.24 2.97 0 5.75-.78 8.16-2.15a1.5 1.5 0 012.1.66 12.08 12.08 0 0011 6.74 12.4 12.4 0 007.85-2.75 1.5 1.5 0 012.38.74A45.76 45.76 0 0192 48.16c0 24.77-19.67 44.9-44 44.9S4 72.93 4 48.16C4 25.23 20.84 6.28 42.64 3.58a1.5 1.5 0 011.44.66zM40.22 7C21.32 10.71 7 27.7 7 48.16c0 23.17 18.39 41.9 41 41.9s41-18.73 41-41.9c0-3.52-.42-6.93-1.22-10.2a15.5 15.5 0 01-7.9 2.15c-5.5 0-10.36-2.83-12.97-7.1a19.46 19.46 0 01-8.28 1.85c-11 0-19.86-9.1-19.86-20.24 0-2.7.52-5.26 1.45-7.62zM92 91a2 2 0 100-4 2 2 0 000 4zM7 8.5a2.5 2.5 0 11-5 0 2.5 2.5 0 015 0zM82.5 90a1.5 1.5 0 100-3 1.5 1.5 0 000 3zm9.5-7.5a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zM13.5 8a1.5 1.5 0 100-3 1.5 1.5 0 000 3zM80 14.5a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zM53.5 20a1.5 1.5 0 100-3 1.5 1.5 0 000 3z">
#     </path>
#    </svg>
#    <p class="fs-body2 fw-bold mb4">
#     Your privacy
#    </p>
#    <p class="mb16 s-anchors s-anchors__inherit s-anchors__underlined">
#     By clicking “Accept all cookies”, you agree Stack Exchange can store cookies on your device and disclose information in accordance with our
#     <a href="https://stackoverflow.com/legal/cookie-policy">
#      Cookie Policy
#     </a>
#     .
#    </p>
#    <div class="d-flex gs8 ai-stretch fd-column sm:fd-row">
#     <button class="flex--item s-btn s-btn__primary js-accept-cookies js-consent-banner-hide">
#      Accept all cookies
#     </button>
#     <button class="flex--item s-btn s-btn__filled js-cookie-settings" data-consent-popup-loader="banner">
#      Customize settings
#     </button>
#    </div>
#   </div>
#   <div class="d-none" id="onetrust-consent-sdk">
#   </div>
#   <div data-controller="s-modal" id="onetrust-banner-sdk">
#   </div>
#   <div class="d-none" id="ot-pc-content">
#   </div>
#   <div class="d-none" id="onetrust-style">
#   </div>
#   <div class="d-none js-consent-banner-version" data-consent-banner-version="baseline">
#   </div>
#  </body>
# </html>

# %%
soup.head # Imprimindo Head da página;
# Out:
# <head>
# <title>Newest 'java' Questions - Stack Overflow</title>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" rel="shortcut icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="image_src"/>
# <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="website" property="og:type">
# <meta content="https://stackoverflow.com/questions/tagged/java" property="og:url"/>
# <meta content="Stack Overflow" property="og:site_name"/>
# <meta content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" itemprop="image primaryImageOfPage" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="stackoverflow.com" name="twitter:domain"/>
# <meta content="Newest 'java' Questions" itemprop="name" name="twitter:title" property="og:title"/>
# <meta content="Stack Overflow | The World’s Largest Online Community for Developers" itemprop="description" name="twitter:description" property="og:description"/>
# <script id="webpack-public-path" type="text/uri-list">https://cdn.sstatic.net/</script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# <script async="" src="https://cdn.sstatic.net/Js/third-party/stacks/stacks.min.js?v=587378ef592b"></script>
# <script src="https://cdn.sstatic.net/Js/stub.en.js?v=17e20b4b4731"></script>
# <link href="https://cdn.sstatic.net/Shared/stacks.css?v=15473555f232" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=de9fb8b74f61" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/secondary.css?v=9532f59e9743" rel="stylesheet" type="text/css"/>
# <link href="/feeds/tag?tagnames=java&amp;sort=newest" rel="alternate" title="Newest java questions feed" type="application/atom+xml">
# <link href="https://cdn.sstatic.net/Shared/Channels/channels.css?v=47a5e0f03c81" rel="stylesheet" type="text/css"/>
# <script>
#         StackExchange.init({"locale":"en","serverTime":1639187528,"routeName":"Questions/ListByTag","stackAuthUrl":"https://stackauth.com","networkMetaHostname":"meta.stackexchange.com","site":{"name":"Stack Overflow","description":"Q&A for professional and enthusiast programmers","isNoticesTabEnabled":true,"enableNewTagCreationWarning":true,"insertSpaceAfterNameTabCompletion":false,"id":1,"cookieDomain":".stackoverflow.com","childUrl":"https://meta.stackoverflow.com","negativeVoteScoreFloor":null,"enableSocialMediaInSharePopup":true,"protocol":"https"},"user":{"fkey":"c8502838d06feccb2607165cf1402428147ff3909b480d87cf7341f1c14d95d6","tid":"7f474628-17eb-09fe-d8e3-020dee5eb882","rep":0,"isAnonymous":true,"isAnonymousNetworkWide":true},"events":{"postType":{"question":1},"postEditionSection":{"title":1,"body":2,"tags":3}},"story":{"minCompleteBodyLength":75,"likedTagsMaxLength":300,"dislikedTagsMaxLength":300},"jobPreferences":{"maxNumDeveloperRoles":2,"maxNumIndustries":4},"svgIconPath":"https://cdn.sstatic.net/Img/stacks-icons","svgIconHash":"d9a8a2f90b12"}, {"userProfile":{"openGraphAPIKey":"4a307e43-b625-49bb-af15-ffadf2bda017"},"userMessaging":{"showNewFeatureNotice":true},"tags":{},"subscriptions":{"defaultBasicMaxTrueUpSeats":250,"defaultFreemiumMaxTrueUpSeats":50,"defaultMaxTrueUpSeats":1000},"snippets":{"renderDomain":"stacksnippets.net","snippetsEnabled":true},"site":{"allowImageUploads":true,"enableImgurHttps":true,"enableUserHovercards":true,"forceHttpsImages":true,"styleCode":true},"questions":{"enableDeleteVoteRetraction":true,"enableQuestionTitleLengthLiveWarning":true,"maxTitleSize":150,"questionTitleLengthStartLiveWarningChars":50},"intercom":{"appId":"inf0secd","hostBaseUrl":"https://stacksnippets.net"},"paths":{},"monitoring":{"clientTimingsAbsoluteTimeout":30000,"clientTimingsDebounceTimeout":1000},"mentions":{"maxNumUsersInDropdown":50},"markdown":{"enableTables":true},"legal":{"oneTrustConfigId":"c3d9f1e3-55f3-4eba-b268-46cee4c6789c"},"flags":{"allowRetractingCommentFlags":true,"allowRetractingFlags":true},"elections":{"opaVoteResultsBaseUrl":"https://www.opavote.com/results/"},"comments":{},"accounts":{"currentPasswordRequiredForChangingStackIdPassword":true}});
#         StackExchange.using.setCacheBreakers({"js/adops.en.js":"6da43f5e0a84","js/ask.en.js":"7ff9a9068fd6","js/begin-edit-event.en.js":"dd955babf04d","js/copy-transpiled.en.js":"51a328039b9e","js/cm.en.js":"75dcb3984aa6","js/events.en.js":"716b95b6374c","js/explore-qlist.en.js":"2b1f34938b8b","js/full-anon.en.js":"70f6560d9b2d","js/full.en.js":"3ffc71953b78","js/help.en.js":"2b4af0ad5c0c","js/highlightjs-loader.en.js":"0026055c3561","js/inline-tag-editing.en.js":"c0cbc31e5702","js/keyboard-shortcuts.en.js":"5ffcb8f50446","js/markdown-it-loader.en.js":"dfad6619ffdd","js/modElections.en.js":"5114e9d6e1cf","js/mobile.en.js":"320aa423a438","js/moderator.en.js":"e83e4187e0ec","js/postCollections-transpiled.en.js":"4b407fb73054","js/post-validation.en.js":"569f8b05c015","js/question-editor.en.js":"","js/review-v2-transpiled.en.js":"b7e059a9fe83","js/revisions.en.js":"839f528889ff","js/stacks-editor.en.js":"04f5018456af","js/tageditor.en.js":"825c9597ce2d","js/tageditornew.en.js":"5215bc97928a","js/tagsuggestions.en.js":"1bcff7d98f97","js/unlimited-transpiled.en.js":"7ed67670b600","js/wmd.en.js":"4689e82c85e7","js/snippet-javascript-codemirror.en.js":"209508902bf4"});
#         StackExchange.using("gps", function() {
#              StackExchange.gps.init(false);
#         });
#     </script>
# <noscript id="noscript-css"><style>body,.top-bar{margin-top:1.9em}</style></noscript>
# </link></meta></head>

# %%
soup.body # Imprimindo informações do Body;
# Out:
# <body class="tagged-questions-page unified-theme">
# <div id="notify-container"></div>
# <div id="custom-header"></div>
# <header class="top-bar js-top-bar top-bar__network">
# <div class="wmx12 mx-auto d-flex ai-center h100" role="menubar">
# <div class="-main flex--item">
# <a aria-controls="left-sidebar" aria-expanded="false" aria-haspopup="true" class="left-sidebar-toggle p0 ai-center jc-center js-left-sidebar-toggle" href="#" role="menuitem"><span class="ps-relative"></span></a>
# <div class="topbar-dialog leftnav-dialog js-leftnav-dialog dno">
# <div class="left-sidebar js-unpinned-left-sidebar" data-can-be="left-sidebar" data-is-here-when="sm"></div>
# </div>
# <a class="-logo js-gps-track" data-gps-track="top_nav.click({is_current:false, location:5, destination:8})" href="https://stackoverflow.com">
# <span class="-img _glyph">Stack Overflow</span>
# </a>
# </div>
# <ol class="list-reset d-flex gs4" role="presentation">
# <li class="flex--item md:d-none">
# <a class="-marketing-link js-gps-track" data-ga='["top navigation","about menu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:7})" href="/company">About</a>
# </li>
# <li class="flex--item">
# <a aria-controls="products-popover" class="-marketing-link js-gps-track js-products-menu" data-action="s-popover#toggle" data-controller="s-popover" data-ga='["top navigation","products menu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:1})" data-s-popover-placement="bottom" data-s-popover-toggle-class="is-selected" href="#">
#                         Products
#                     </a>
# </li>
# <li class="flex--item md:d-none">
# <a class="-marketing-link js-gps-track" data-ga='["top navigation","learn more - teams",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:7})" href="/teams">For Teams</a>
# </li>
# </ol>
# <div aria-hidden="true" class="s-popover ws2 mtn2 p0" id="products-popover" role="menu">
# <div class="s-popover--arrow"></div>
# <ol class="list-reset s-anchors s-anchors__inherit">
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","public qa submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:2})" href="/questions">
# <span class="fs-body1 d-block">Stack Overflow</span>
# <span class="fs-caption d-block fc-light">Public questions &amp; answers</span>
# </a>
# </li>
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","teams submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:3})" href="/teams">
# <span class="fs-body1 d-block">Stack Overflow for Teams</span>
# <span class="fs-caption d-block fc-light">Where developers &amp; technologists share private knowledge with coworkers</span>
# </a>
# </li>
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","jobs submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:9})" href="/jobs?so_source=ProductsMenu&amp;so_medium=StackOverflow">
# <span class="fs-body1 d-block">Jobs</span>
# <span class="fs-caption d-block fc-light">Programming &amp; related technical career opportunities</span>
# </a>
# </li>
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","talent submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:5})" href="https://stackoverflow.com/talent">
# <span class="fs-body1 d-block">Talent</span>
# <span class="fs-caption d-block fc-light">Recruit tech talent &amp; build your employer brand</span>
# </a>
# </li>
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","advertising submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:6})" href="https://stackoverflow.com/advertising">
# <span class="fs-body1 d-block">Advertising</span>
# <span class="fs-caption d-block fc-light">Reach developers &amp; technologists worldwide</span>
# </a>
# </li>
# <li class="bg-black-025 bt bc-black-075 py6 px6 bbr-md">
# <a class="fc-light d-block py6 px6 h:fc-black-800 js-gps-track" data-ga='["top navigation","about submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:5, destination:7})" href="/company">About the company</a>
# </li>
# </ol>
# </div>
# <form action="/search" autocomplete="off" class="flex--item fl-grow1 searchbar px12 js-searchbar " id="search" role="search">
# <div class="ps-relative">
# <input aria-controls="top-search" aria-label="Search" autocomplete="off" class="s-input s-input__search js-search-field " data-action="focus-&gt;s-popover#show" data-controller="s-popover" data-s-popover-placement="bottom-start" maxlength="240" name="q" placeholder="Search…" type="text" value="[java]"/>
# <svg aria-hidden="true" class="s-input-icon s-input-icon__search svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18"><path d="m18 16.5-5.14-5.18h-.35a7 7 0 10-1.19 1.19v.35L16.5 18l1.5-1.5ZM12 7A5 5 0 112 7a5 5 0 0110 0Z"></path></svg>
# <div class="s-popover p0 wmx100 wmn4 sm:wmn-initial js-top-search-popover" id="top-search" role="menu">
# <div class="s-popover--arrow"></div>
# <div class="js-spinner p24 d-flex ai-center jc-center d-none">
# <div class="s-spinner s-spinner__sm fc-orange-400">
# <div class="v-visible-sr">Loading…</div>
# </div>
# </div>
# <span class="v-visible-sr js-screen-reader-info"></span>
# <div class="js-ac-results overflow-y-auto hmx3 d-none"></div>
# <div aria-describedby="Tips for searching" class="js-search-hints"></div>
# </div>
# </div>
# </form>
# <ol class="overflow-x-auto ml-auto -secondary d-flex ai-center list-reset h100 user-logged-out" role="presentation">
# <li class="-item searchbar-trigger"><a aria-controls="search" aria-haspopup="true" aria-label="Search" class="-link js-searchbar-trigger" href="#" role="button" title="Click to show search"><svg aria-hidden="true" class="svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18"><path d="m18 16.5-5.14-5.18h-.35a7 7 0 10-1.19 1.19v.35L16.5 18l1.5-1.5ZM12 7A5 5 0 112 7a5 5 0 0110 0Z"></path></svg></a></li>
# <li class="-ctas">
# <a class="login-link s-btn s-btn__filled py8 js-gps-track" data-ga='["top navigation","login button click",null,null,null]' data-gps-track="login.click" href="https://stackoverflow.com/users/login?ssrc=head&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2ftagged%2fjava" rel="nofollow">Log in</a>
# <a class="login-link s-btn s-btn__primary py8" data-ga='["sign up","Sign Up Navigation","Header",null,null]' href="https://stackoverflow.com/users/signup?ssrc=head&amp;returnurl=%2fusers%2fstory%2fcurrent" rel="nofollow">Sign up</a>
# </li>
# <li class="js-topbar-dialog-corral" role="presentation">
# <div class="topbar-dialog siteSwitcher-dialog dno" role="menu">
# <div class="header fw-wrap">
# <h3 class="flex--item">
# <a href="https://stackoverflow.com">current community</a>
# </h3>
# <div class="flex--item fl1">
# <div class="ai-center d-flex jc-end">
# <button aria-label="Close" class="js-close-button s-btn s-btn__muted p0 ml8 d-none sm:d-block" type="button">
# <svg aria-hidden="true" class="svg-icon iconClear" height="18" viewbox="0 0 18 18" width="18"><path d="M15 4.41 13.59 3 9 7.59 4.41 3 3 4.41 7.59 9 3 13.59 4.41 15 9 10.41 13.59 15 15 13.59 10.41 9 15 4.41Z"></path></svg>
# </button>
# </div>
# </div>
# </div>
# <div class="modal-content bg-powder-050 current-site-container">
# <ul class="current-site ">
# <li class="d-flex">
# <div class="fl1">
# <a class="current-site-link site-link js-gps-track d-flex gs8 gsx" data-gps-track="site_switcher.click({ item_type:3 })" data-id="1" href="https://stackoverflow.com">
# <div class="favicon favicon-stackoverflow site-icon flex--item" title="Stack Overflow"></div>
# <span class="flex--item fl1">
#             Stack Overflow
#         </span>
# </a>
# </div>
# <div class="related-links">
# <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:14 })" href="https://stackoverflow.com/help">help</a>
# <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:6 })" href="https://chat.stackoverflow.com/?tab=site&amp;host=stackoverflow.com">chat</a>
# </div>
# </li>
# <li class="related-site d-flex">
# <div class="L-shaped-icon-container">
# <span class="L-shaped-icon"></span>
# </div>
# <a class=" site-link js-gps-track d-flex gs8 gsx" data-gps-track="site.switch({ target_site:552, item_type:3 }),site_switcher.click({ item_type:4 })" data-id="552" href="https://meta.stackoverflow.com">
# <div class="favicon favicon-stackoverflowmeta site-icon flex--item" title="Meta Stack Overflow"></div>
# <span class="flex--item fl1">
#             Meta Stack Overflow
#         </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="header" id="your-communities-header">
# <h3>
# your communities            </h3>
# </div>
# <div class="modal-content" id="your-communities-section">
# <div class="call-to-login">
# <a class="login-link js-gps-track" data-gps-track="site_switcher.click({ item_type:10 })" href="https://stackoverflow.com/users/signup?ssrc=site_switcher&amp;returnurl=%2fusers%2fstory%2fcurrent">Sign up</a> or <a class="login-link js-gps-track" data-gps-track="site_switcher.click({ item_type:11 })" href="https://stackoverflow.com/users/login?ssrc=site_switcher&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2ftagged%2fjava">log in</a> to customize your list.                </div>
# </div>
# <div class="header">
# <h3><a href="https://stackexchange.com/sites">more stack exchange communities</a>
# </h3>
# <a class="float-right" href="https://stackoverflow.blog">company blog</a>
# </div>
# <div class="modal-content">
# <div class="child-content"></div>
# </div>
# </div>
# </li>
# </ol>
# </div>
# </header>
# <script>
#         StackExchange.ready(function () { StackExchange.topbar.init(); });
#         StackExchange.scrollPadding.setPaddingTop(50, 10);
#     </script>
# <div class="container">
# <div class="left-sidebar js-pinned-left-sidebar ps-relative" data-is-here-when="md lg" id="left-sidebar">
# <div class="left-sidebar--sticky-container js-sticky-leftnav">
# <nav role="navigation">
# <ol class="nav-links">
# <li class="">
# <a aria-controls="" class="pl8 js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:8})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                             Home
#                         </div>
# </div>
# </a>
# </li>
# <li>
# <ol class="nav-links">
# <li class="fs-fine tt-uppercase ml8 mt16 mb4 fc-light">Public</li>
# <li class=" youarehere">
# <a aria-controls="" class="pl8 js-gps-track nav-links--link -link__with-icon" data-controller="" data-gps-track="top_nav.click({is_current:true, location:5, destination:1})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/questions" id="nav-questions">
# <svg aria-hidden="true" class="svg-icon iconGlobe" height="18" viewbox="0 0 18 18" width="18"><path d="M9 1C4.64 1 1 4.64 1 9c0 4.36 3.64 8 8 8 4.36 0 8-3.64 8-8 0-4.36-3.64-8-8-8ZM8 15.32a6.46 6.46 0 01-4.3-2.74 6.46 6.46 0 01-.93-5.01L7 11.68v.8c0 .88.12 1.32 1 1.32v1.52Zm5.72-2c-.2-.66-1-1.32-1.72-1.32h-1v-2c0-.44-.56-1-1-1H6V7h1c.44 0 1-.56 1-1V5h2c.88 0 1.4-.72 1.4-1.6v-.33a6.45 6.45 0 013.83 4.51 6.45 6.45 0 01-1.51 5.73v.01Z"></path></svg> <span class="-link--channel-name">Questions</span>
# </a>
# </li>
# <li class="">
# <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:2})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/tags" id="nav-tags">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                             Tags
#                         </div>
# </div>
# </a>
# </li>
# <li class="">
# <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:3})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/users" id="nav-users">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                             Users
#                         </div>
# </div>
# </a>
# </li>
# <li class="d-flex ml8 mt16 mb4 jc-space-between">
# <div class="flex--item tt-uppercase tt-uppercase fs-fine fc-light">Collectives</div>
# <div class="flex--item fs-fine fc-light">
# <a aria-controls="popover-discover-collectives" class="s-link s-link__inherit mr8 js-gps-track" data-action="s-popover#toggle" data-controller="s-popover" data-gps-track="top_nav.click({is_current:false, location:5, destination:17})" data-s-popover-placement="top" data-s-popover-toggle-class="is-selected" href="javascript:void(0)" role="button">
# <svg aria-hidden="true" class="svg-icon iconInfoSm" height="14" viewbox="0 0 14 14" width="14"><path d="M7 1a6 6 0 110 12A6 6 0 017 1Zm1 10V6H6v5h2Zm0-6V3H6v2h2Z"></path></svg>
# </a>
# </div>
# </li>
# <li class="">
# <a aria-controls="" class="pl8 ai-center js-gps-track nav-links--link -link__with-icon" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:18})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/collectives" id="nav-collective-discover">
# <svg aria-hidden="true" class="mt-auto fc-orange-400 svg-icon iconStarVerified" height="18" viewbox="0 0 18 18" width="18"><path d="M9.86.89a1.14 1.14 0 00-1.72 0l-.5.58c-.3.35-.79.48-1.23.33l-.72-.25a1.14 1.14 0 00-1.49.85l-.14.76c-.1.45-.45.8-.9.9l-.76.14c-.67.14-1.08.83-.85 1.49l.25.72c.15.44.02.92-.33 1.23l-.58.5a1.14 1.14 0 000 1.72l.58.5c.35.3.48.79.33 1.23l-.25.72c-.23.66.18 1.35.85 1.49l.76.14c.45.1.8.45.9.9l.14.76c.14.67.83 1.08 1.49.85l.72-.25c.44-.15.92-.02 1.23.33l.5.58c.46.52 1.26.52 1.72 0l.5-.58c.3-.35.79-.48 1.23-.33l.72.25c.66.23 1.35-.18 1.49-.85l.14-.76c.1-.45.45-.8.9-.9l.76-.14c.67-.14 1.08-.83.85-1.49l-.25-.72c-.15-.44-.02-.92.33-1.23l.58-.5c.52-.46.52-1.26 0-1.72l-.58-.5c-.35-.3-.48-.79-.33-1.23l.25-.72a1.14 1.14 0 00-.85-1.49l-.76-.14c-.45-.1-.8-.45-.9-.9l-.14-.76a1.14 1.14 0 00-1.49-.85l-.72.25c-.44.15-.92.02-1.23-.33l-.5-.58Zm-.49 2.67L10.6 6.6c.05.15.19.24.34.25l3.26.22c.36.03.5.48.23.71l-2.5 2.1a.4.4 0 00-.14.4l.8 3.16a.4.4 0 01-.6.44L9.2 12.13a.4.4 0 00-.42 0l-2.77 1.74a.4.4 0 01-.6-.44l.8-3.16a.4.4 0 00-.13-.4l-2.5-2.1a.4.4 0 01.22-.7l3.26-.23a.4.4 0 00.34-.25l1.22-3.03a.4.4 0 01.74 0Z"></path></svg> <span class="-link--channel-name">Explore Collectives</span>
# </a>
# </li>
# <li class="fs-fine tt-uppercase ml8 mt16 mb4 fc-light">Find a Job</li>
# <li class="">
# <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:6})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/jobs?so_medium=StackOverflow&amp;so_source=SiteNav" id="nav-jobs">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                             Jobs
#                         </div>
# </div>
# </a>
# </li>
# <li class="">
# <a aria-controls="" class=" js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:5, destination:12})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/jobs/companies?so_medium=StackOverflow&amp;so_source=SiteNav" id="nav-companies">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                             Companies
#                         </div>
# </div>
# </a>
# </li>
# </ol>
# </li>
# <li>
# <ol class="nav-links">
# <div class="js-freemium-cta ps-relative">
# <div class="fs-fine tt-uppercase ml8 mt16 mb8 fc-light">Teams</div>
# <div class="bt bl bb bc-black-075 p12 pb6 fc-black-600 blr-sm overflow-hidden">
# <strong class="fc-black-750 mb6">Stack Overflow for Teams</strong>
#         – Collaborate and share knowledge with a private group.
#
#         <img alt="" class="wmx100 mx-auto my8 h-auto d-block" height="114" src="https://cdn.sstatic.net/Img/teams/teams-illo-free-sidebar-promo.svg?v=47faa659a05e" width="139"/>
# <a class="w100 s-btn s-btn__primary s-btn__xs js-gps-track" data-ga='["teams left navigation - anonymous","left nav free cta","stackoverflow.com/teams/create/free",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: 6 })" href="https://stackoverflow.com/teams/create/free?utm_source=so-owned&amp;utm_medium=side-bar&amp;utm_campaign=campaign-38&amp;utm_content=cta">Create a free Team</a>
# <a class="w100 s-btn s-btn__muted s-btn__xs js-gps-track" data-ga='["teams left navigation - anonymous","left nav free cta","stackoverflow.com/teams",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: 5 })" href="https://stackoverflow.com/teams">What is Teams?</a>
# </div>
# </div>
# <li class="d-flex ai-center jc-space-between ml8 mt24 mb4 js-create-team-cta d-none">
# <div class="flex--item tt-uppercase fs-fine fc-light">Teams</div>
# <div class="flex--item">
# <a aria-controls="popover-teams-create-cta" class="s-link p12 fc-black-500 h:fc-black-800 js-gps-track" data-action="s-popover#toggle" data-controller="s-popover" data-ga='["teams left navigation - anonymous","left nav show teams info",null,null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: ShowInfo })" data-s-popover-placement="bottom-start" data-s-popover-toggle-class="is-selected" href="javascript:void(0)" role="button">
# <svg aria-hidden="true" class="svg-icon iconInfoSm" height="14" viewbox="0 0 14 14" width="14"><path d="M7 1a6 6 0 110 12A6 6 0 017 1Zm1 10V6H6v5h2Zm0-6V3H6v2h2Z"></path></svg>
# </a>
# </div>
# </li>
# <li class="ps-relative js-create-team-cta d-none">
# <a class="pl8 js-gps-track nav-links--link" data-ga='["teams left navigation - anonymous","left nav team click","stackoverflow.com/teams/create/free",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: FreemiumTeamsCreateClick })" href="https://stackoverflow.com/teams/create/free?utm_source=so-owned&amp;utm_medium=side-bar&amp;utm_campaign=campaign-38&amp;utm_content=cta" title="Stack Overflow for Teams is a private, secure spot for your organization's questions and answers.">
# <div class="d-flex ai-center">
# <div class="flex--item s-avatar va-middle bg-orange-400">
# <div class="s-avatar--letter mtn1">
# <svg aria-hidden="true" class="svg-icon iconBriefcaseSm" height="14" viewbox="0 0 14 14" width="14"><path d="M4 3a1 1 0 011-1h4a1 1 0 011 1v1h.5c.83 0 1.5.67 1.5 1.5v5c0 .83-.67 1.5-1.5 1.5h-7A1.5 1.5 0 012 10.5v-5C2 4.67 2.67 4 3.5 4H4V3Zm5 1V3H5v1h4Z"></path></svg>
# </div>
# <svg aria-hidden="true" class="native s-avatar--badge svg-icon iconShieldXSm" height="10" viewbox="0 0 9 10" width="9"><path d="M0 1.84 4.5 0 9 1.84v3.17C9 7.53 6.3 10 4.5 10 2.7 10 0 7.53 0 5.01V1.84Z" fill="var(--white)"></path><path d="M1 2.5 4.5 1 8 2.5v2.51C8 7.34 5.34 9 4.5 9 3.65 9 1 7.34 1 5.01V2.5Zm2.98 3.02L3.2 7h2.6l-.78-1.48a.4.4 0 01.15-.38c.34-.24.73-.7.73-1.14 0-.71-.5-1.23-1.41-1.23-.92 0-1.39.52-1.39 1.23 0 .44.4.9.73 1.14.12.08.18.23.15.38Z" fill="var(--black-500)"></path></svg>
# </div>
# <div class="flex--item pl6">
#                                                 Create free Team
#                                             </div>
# </div>
# </a>
# </li>
# </ol>
# </li>
# </ol>
# </nav>
# </div>
# <div aria-hidden="true" class="s-popover ws2" id="popover-discover-collectives" role="menu">
# <div class="s-popover--arrow"></div>
# <div>
# <svg aria-hidden="true" class="fc-orange-500 float-right ml24 svg-spot spotCollective" height="48" viewbox="0 0 48 48" width="48"><path d="M25.5 7a2.5 2.5 0 100-5 2.5 2.5 0 0 0 0 5zM14 18.25c0-.69.56-1.25 1.25-1.25h22.5c.69 0 1.25.56 1.25 1.25V37.5a1 1 0 01-1.6.8l-4.07-3.05a1.25 1.25 0 00-.75-.25H15.25c-.69 0-1.25-.56-1.25-1.25v-15.5zM7 24.5a2.5 2.5 0 11-5 0 2.5 2.5 0 0 1 5 0zM25.5 48a2.5 2.5 0 100-5 2.5 2.5 0 0 0 0 5zM48 24.5a2.5 2.5 0 11-5 0 2.5 2.5 0 0 1 5 0z" opacity=".2"></path><path d="M21 3.5a3.5 3.5 0 117 0 3.5 3.5 0 0 1-7 0zM24.5 2a1.5 1.5 0 100 3 1.5 1.5 0 0 0 0-3zM0 23.5a3.5 3.5 0 117 0 3.5 3.5 0 0 1-7 0zM3.5 22a1.5 1.5 0 100 3 1.5 1.5 0 0 0 0-3zM21 44.5a3.5 3.5 0 117 0 3.5 3.5 0 0 1-7 0zm3.5-1.5a1.5 1.5 0 100 3 1.5 1.5 0 0 0 0-3zm20-23a3.5 3.5 0 100 7 3.5 3.5 0 0 0 0-7zM43 23.5a1.5 1.5 0 113 0 1.5 1.5 0 0 1-3 0zm-23.23-3.14a1 1 0 01-.13 1.4l-2.08 1.74 2.08 1.73a1 1 0 11-1.28 1.54l-2.42-2.02a1.63 1.63 0 010-2.5l2.42-2.02a1 1 0 011.4.13zm7.59 1.41a1 1 0 111.28-1.54l2.42 2.02c.78.65.78 1.85 0 2.5l-2.42 2.02a1 1 0 11-1.28-1.54l2.08-1.73-2.08-1.73zM24.12 18a1 1 0 01.87 1.12l-1 8a1 1 0 11-1.98-.24l1-8a1 1 0 011.11-.87zm-11.87-5C11.01 13 10 14 10 15.25v15.5c0 1.24 1 2.25 2.25 2.25h17.33c.06 0 .11.02.15.05l4.07 3.05a2 2 0 003.2-1.6V15.25c0-1.24-1-2.25-2.25-2.25h-22.5zM12 15.25c0-.14.11-.25.25-.25h22.5c.14 0 .25.11.25.25V34.5l-4.07-3.05a2.2 2.2 0 00-1.35-.45H12.25a.25.25 0 01-.25-.25v-15.5zm7.24-10.68a1 1 0 10-.48-1.94A22.04 22.04 0 002.91 17.7a1 1 0 101.92.58 20.04 20.04 0 0 1 14.4-13.72zm11.05-1.66a1 1 0 00-.58 1.92c6.45 1.92 11.54 7 13.46 13.46a1 1 0 101.92-.58 22.05 22.05 0 0 0-14.8-14.8zM4.57 28.76a1 1 0 00-1.94.48 22.03 22.03 0 0 0 16.13 16.13 1 1 0 1 0 .48-1.94A20.03 20.03 0 014.57 28.76zm40.8.48a1 1 0 10-1.94-.48 20.04 20.04 0 0 1-13.72 14.41 1 1 0 0 0 .58 1.92 22.04 22.04 0 0 0 15.08-15.85z"></path></svg>
# <div class="pt4 fw-bold">Collectives on Stack Overflow</div>
# <p class="my16 fs-caption fc-medium">Find centralized, trusted content and collaborate around the technologies you use most.</p>
# <a class="js-gps-track s-btn s-btn__primary s-btn__xs" data-gps-track="top_nav.click({is_current:false, location:5, destination:18})" href="/collectives">
#                     Learn more
#                 </a>
# </div>
# </div>
# <div aria-hidden="true" class="s-popover" id="popover-teams-create-cta" role="menu">
# <div class="s-popover--arrow"></div>
# <div class="ps-relative overflow-hidden">
# <p class="mb2"><strong>Teams</strong></p>
# <p class="mb12 fs-caption fc-black-400">Q&amp;A for work</p>
# <p class="mb12 fs-caption fc-medium">Connect and share knowledge within a single location that is structured and easy to search.</p>
# <a class="js-gps-track s-btn s-btn__primary s-btn__xs" data-ga='["teams left navigation - anonymous","left nav cta","stackoverflow.com/teams",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: CtaClick })" href="https://stackoverflow.com/teams">
#                     Learn more
#                 </a>
# </div>
# <div class="ps-absolute t8 r8">
# <svg aria-hidden="true" class="fc-orange-500 svg-spot spotPeople" height="48" viewbox="0 0 48 48" width="48"><path d="M13.5 28a4.5 4.5 0 100-9 4.5 4.5 0 0 0 0 9zM7 30a1 1 0 011-1h11a1 1 0 011 1v5h11v-5a1 1 0 011-1h12a1 1 0 011 1v10a2 2 0 01-2 2H33v5a1 1 0 01-1 1H20a1 1 0 01-1-1v-5H8a1 1 0 01-1-1V30zm25-6.5a4.5 4.5 0 109 0 4.5 4.5 0 0 0-9 0zM24.5 34a4.5 4.5 0 100-9 4.5 4.5 0 0 0 0 9z" opacity=".2"></path><path d="M16.4 26.08A6 6 0 107.53 26C5.64 26.06 4 27.52 4 29.45V40a1 1 0 001 1h9a1 1 0 100-2h-4v-7a1 1 0 10-2 0v7H6v-9.55c0-.73.67-1.45 1.64-1.45H16a1 1 0 00.4-1.92zM12 18a4 4 0 110 8 4 4 0 0 1 0-8zm16.47 14a6 6 0 10-8.94 0A3.6 3.6 0 0016 35.5V46a1 1 0 001 1h14a1 1 0 001-1V35.5c0-1.94-1.64-3.42-3.53-3.5zM20 28a4 4 0 118 0 4 4 0 0 1-8 0zm-.3 6h8.6c1 0 1.7.75 1.7 1.5V45h-2v-7a1 1 0 10-2 0v7h-4v-7a1 1 0 10-2 0v7h-2v-9.5c0-.75.7-1.5 1.7-1.5zM42 22c0 1.54-.58 2.94-1.53 4A3.5 3.5 0 0144 29.45V40a1 1 0 01-1 1h-9a1 1 0 110-2h4v-7a1 1 0 112 0v7h2v-9.55A1.5 1.5 0 0040.48 28H32a1 1 0 01-.4-1.92A6 6 0 1142 22zm-2 0a4 4 0 10-8 0 4 4 0 0 0 8 0z"></path><path d="M17 10a1 1 0 011-1h12a1 1 0 110 2H18a1 1 0 01-1-1zm1-5a1 1 0 100 2h12a1 1 0 100-2H18zm-4-4a1 1 0 00-1 1v12a1 1 0 001 1h5.09l4.2 4.2a1 1 0 001.46-.04l3.7-4.16H34a1 1 0 001-1V2a1 1 0 00-1-1H14zm1 12V3h18v10h-5a1 1 0 00-.75.34l-3.3 3.7-3.74-3.75a1 1 0 00-.71-.29H15z" opacity=".35"></path></svg>
# </div>
# </div>
# </div>
# <div class="snippet-hidden" id="content">
# <div id="mainbar">
# <div class="d-flex">
# <div class="d-flex fl1 mb24">
# <h1 class="flex--item fs-headline1 mb0">
# Questions tagged [java]        </h1>
# </div>
# <div class="ml12 aside-cta flex--item print:d-none">
# <a class="ws-nowrap s-btn s-btn__primary" href="/questions/ask">
#         Ask Question
#     </a>
# </div>
# </div>
# <style>
# </style>
# <div class="js-zone-container zone-container-main">
# <div class="everyonelovesstackoverflow everyoneloves__tag-sponsorship theme-light__forced bg-white" id="dfp-tag"></div>
# <div class="js-report-ad-button-container " style="width: 728px"></div>
# </div>
# <div class="mb24">
# <p>
# Java is a high-level object oriented programming language. Use this tag when you're having problems using or understanding the language itself. This tag is frequently used alongside other tags for libraries and/or frameworks used by Java developers.                    </p>
# <div class=" d-flex gs12 jc-space-between ai-center fw-wrap">
# <div class="flex--item">
# <ul class="d-flex gs12 list-ls-none fw-wrap">
# <li class="flex--item">
# <a href="/tags/java/info" title="Tag wiki">Learn more…</a>
# </li>
# <li class="flex--item">
# <a href="/tags/java/topusers" title="Top answerers and askers in this tag">Top users</a>
# </li>
# <li class="flex--item">
# <a href="/tags/java/synonyms" title="Common, alternate spellings or phrasings for this tag">Synonyms (11)</a>
# </li>
# <li class="flex--item">
# <a href="/jobs/developer-jobs-using-java?med=site-ui&amp;ref=tag-page_java" title="Find yourself a job">java jobs</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <script>
#     StackExchange.ready(function () {
#         initTagRenderer("".split(" "), "".split(" "));
#         StackExchange.userQuestionList.init({
#             sharingUrl: ""
#         });
#     });
# </script>
# <div data-controller="se-uql" data-se-uql-id="" data-se-uql-sanitize-tag-query="false">
# <div class="d-flex ai-center jc-space-between mb12 sm:fd-column sm:ai-stretch">
# <div class="fs-body3 flex--item fl1 mr12 sm:mr0 sm:mb12">
#             1,816,414
#             questions
#         </div>
# <div class="uql-nav flex--item" data-action="se-uql-list:edit-current-requested@document-&gt;se-uql#toggleEditor">
# <div class="d-flex ai-center jc-space-between">
# <div class="js-uql-navigation s-btn-group flex--item mr16 ff-row-nowrap">
# <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex is-selected" data-nav-value="Newest" data-shortcut="N" href="/questions/tagged/java?tab=Newest">
# <div class="flex--item">Newest</div>
# </a>
# <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex" data-nav-value="Active" data-shortcut="A" href="/questions/tagged/java?tab=Active">
# <div class="flex--item">Active</div>
# </a>
# <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex uql-nav--expanded-item" data-nav-value="Bounties" data-shortcut="E" href="/questions/tagged/java?tab=Bounties">
# <div class="flex--item">Bountied</div>
# <div class="s-badge s-badge__bounty s-badge__bounty s-badge__sm lh-xs ml4 px4 flex--item">20</div>
# </a>
# <a class="s-btn s-btn__muted s-btn__outlined s-btn__sm d-flex uql-nav--expanded-item" data-nav-value="Unanswered" data-shortcut="U" href="/questions/tagged/java?tab=Unanswered">
# <div class="flex--item">Unanswered</div>
# </a>
# <button aria-controls="uql-more-popover" aria-expanded="false" aria-haspopup="true" class="s-btn s-btn__muted s-btn__outlined s-btn__sm s-btn__dropdown" data-action="s-popover#toggle" data-controller="s-popover" data-se-uql-target="toggleMoreButton" role="button">
#                         More
#                     </button>
# </div>
# <div class="s-popover z-dropdown ws2" data-se-uql-target="morePopover" id="uql-more-popover">
# <div class="s-popover--arrow"></div>
# <ul class="list-reset mtn8 mbn8 js-uql-navigation">
# <li class="uql-item my0 uql-nav--collapsed-item">
# <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="" href="/questions/tagged/java?tab=Bounties">
#                                         Bountied
#                                             <span class="s-badge s-badge__bounty s-badge__bounty s-badge__sm lh-xs px4">20</span>
# </a>
# </li>
# <li class="uql-item my0 uql-nav--collapsed-item">
# <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="" href="/questions/tagged/java?tab=Unanswered">
#                                         Unanswered
#                                     </a>
# </li>
# <li class="uql-item my0">
# <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="F" href="/questions/tagged/java?tab=Frequent">
#                                         Frequent
#                                     </a>
# </li>
# <li class="uql-item my0">
# <a class="mln12 mrn12 px12 py6 fl1 s-block-link" data-shortcut="V" href="/questions/tagged/java?tab=Votes">
#                                         Votes
#                                     </a>
# </li>
# <li class="uql-item uql-item__separator bg-black-075 d:bg-black-025"></li>
# <li class="uql-item my0">
# <span class="s-block-link c-default fc-black-350 mln12 mrn12 px12 py6">Unanswered (my tags)</span>
# </li>
# </ul>
# </div>
# <div class="flex--item">
# <button aria-controls="uql-form" aria-expanded="false" class="s-btn s-btn__filled s-btn__sm s-btn__icon ws-nowrap" data-controller="s-expandable-control" data-s-expandable-control-toggle-class="is-selected" data-se-uql-target="toggleFormButton" role="button">
# <svg aria-hidden="true" class="svg-icon iconFilter" height="18" viewbox="0 0 18 18" width="18"><path d="M2 4h14v2H2V4Zm2 4h10v2H4V8Zm8 4H6v2h6v-2Z"></path></svg> Filter
#                     </button>
# </div>
# </div>
# </div>
# </div>
# <form class="s-expandable ps-relative z-active" data-action="se-uql#navigate" data-se-uql-target="form" id="uql-form">
# <input name="uqlId" type="hidden"/>
# <div class="s-expandable--content">
# <div class="bg-black-050 ba bc-black-100 bar-sm mb16">
# <div class="px12 py16">
# <div class="d-flex gs32 fw-wrap">
# <div class="flex--item">
# <fieldset class="d-flex gs8 gsy fd-column">
# <legend class="flex--item s-label px0">Filter by</legend>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-checkbox d-block" id="7d4b1108-7a58-49f2-aa10-a2370cb30668" name="filterId" type="checkbox" value="NoAnswers"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="7d4b1108-7a58-49f2-aa10-a2370cb30668">No answers</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-checkbox d-block" id="062f790c-5c33-4df7-a1ec-982b49098774" name="filterId" type="checkbox" value="NoAcceptedAnswer"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="062f790c-5c33-4df7-a1ec-982b49098774">No accepted answer</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-checkbox d-block" id="95181a74-afa5-4d41-8fff-0aeeb4371521" name="filterId" type="checkbox" value="Bounty"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="95181a74-afa5-4d41-8fff-0aeeb4371521">Has bounty</label>
# </div>
# </div>
# </fieldset>
# </div>
# <div class="flex--item">
# <fieldset class="d-flex gs8 gsy fd-column">
# <legend class="flex--item s-label px0">Sorted by</legend>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input checked="checked" class="s-radio d-block" id="e5873541-3e3d-4795-913e-9c992b13be03" name="sortId" type="radio" value="Newest"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="e5873541-3e3d-4795-913e-9c992b13be03">Newest</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-radio d-block" id="86b630e5-b281-4dfe-abdf-9f72f0963850" name="sortId" type="radio" value="RecentActivity"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="86b630e5-b281-4dfe-abdf-9f72f0963850">Recent activity</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-radio d-block" id="fa505287-5f01-4ac0-99ca-2561ff250d50" name="sortId" type="radio" value="MostVotes"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="fa505287-5f01-4ac0-99ca-2561ff250d50">Most votes</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-radio d-block" id="3f90d890-df34-4c3b-a086-4ec3981f1550" name="sortId" type="radio" value="MostFrequent"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="3f90d890-df34-4c3b-a086-4ec3981f1550">Most frequent</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-radio d-block" id="73c45878-ad48-4552-9fd4-c05257fa254a" name="sortId" type="radio" value="BountyEndingSoon"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="73c45878-ad48-4552-9fd4-c05257fa254a">Bounty ending soon</label>
# </div>
# </div>
# </fieldset>
# </div>
# <div class="flex--item">
# <fieldset class="d-flex gs8 gsy fd-column">
# <legend class="flex--item s-label px0">Tagged with</legend>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input class="s-radio d-block" id="6888d9c1-e225-4f40-bfeb-4108f3892172" name="tagModeId" type="radio" value="Watched"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="6888d9c1-e225-4f40-bfeb-4108f3892172">My watched tags</label>
# </div>
# </div>
# <div class="flex--item">
# <div class="d-flex gs4 gsx ai-center">
# <div class="flex--item">
# <input checked="checked" class="s-radio d-block" id="9855fdb1-a0cf-4d39-8628-e27bcc47a113" name="tagModeId" type="radio" value="Specified"/>
# </div>
# <label class="flex--item s-label fw-normal ws-nowrap" for="9855fdb1-a0cf-4d39-8628-e27bcc47a113">The following tags:</label>
# </div>
# </div>
# </fieldset>
# <div class="ps-relative ml24 mt8 ws2">
# <input class="w100 s-input" data-se-uql-target="tagQuery" id="uql-modal-tag-input" name="tagQuery" placeholder="e.g. javascript or python" size="60" tabindex="0" type="text" value="java"/>
# </div>
# </div>
# </div>
# </div>
# <div class="p12 bt bc-black-100">
# <div class="d-flex">
# <div class="d-flex gs4 gsx fl1">
# <button class="s-btn s-btn__sm s-btn__primary flex--item" data-se-uql-target="applyButton" type="submit">Apply filter</button>
# </div>
# <div class="flex--item">
# <button class="s-btn s-btn__sm" data-action="se-uql#cancelEditor" type="button">Cancel</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# <div class="bt bc-black-100 mln24 pl24" id="questions">
# <div class="mln24">
# <div class="question-summary" id="question-summary-70312057">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post "><strong>0</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status unanswered">
# <strong>0</strong>answers
#             </div>
# </div>
# <div class="views " title="4 views">
#     4 views
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/70312057/match-every-single-string-after-character-in-java-regex">Match every single String after character in Java (RegEx)</a></h3>
# <div class="excerpt">
#             I need help with this, so uhm... I have a String:
# Hey ~firstname ~lastname today is the ~date
#
# I want the program to print out this output:
# firstname lastname date
#
# in a list from the matcher (I ...
#         </div>
# <div class="d-flex ai-start fw-wrap">
# <div class="flex--item">
# <div class="d-flex gs4 fw-wrap tags t-java t-regex t-string t-pattern-matching t-match">
# <a class="post-tag flex--item" href="/questions/tagged/java" rel="tag" title="show questions tagged 'java'">java</a> <a class="post-tag flex--item" href="/questions/tagged/regex" rel="tag" title="show questions tagged 'regex'">regex</a> <a class="post-tag flex--item" href="/questions/tagged/string" rel="tag" title="show questions tagged 'string'">string</a> <a class="post-tag flex--item" href="/questions/tagged/pattern-matching" rel="tag" title="show questions tagged 'pattern-matching'">pattern-matching</a> <a class="post-tag flex--item" href="/questions/tagged/match" rel="tag" title="show questions tagged 'match'">match</a> </div>
# </div>
# <div class="flex--item ml-auto fl-shrink0 started mt0">
# <div class="user-info ">
# <div class="user-action-time">
#         asked <span class="relativetime" title="2021-12-11 01:48:58Z">3 mins ago</span>
# </div>
# <div class="user-gravatar32">
# <a href="/users/16028444/momothesim"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://lh3.googleusercontent.com/a-/AOh14GgZXASPL_t6GhQ6IuxtUI68NXXUStfr52oPD1P1=k-s64" width="32"/></div></a>
# </div>
# <div class="user-details">
# <a href="/users/16028444/momothesim">MomoTheSiM</a>
# <div class="-flair">
# <span class="reputation-score" dir="ltr" title="reputation score ">27</span><span aria-hidden="true" title="2 bronze badges"><span class="badge3"></span><span class="badgecount">2</span></span><span class="v-visible-sr">2 bronze badges</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mln24">
# <div class="question-summary" id="question-summary-70312009">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post "><strong>0</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status unanswered">
# <strong>0</strong>answers
#             </div>
# </div>
# <div class="views " title="6 views">
#     6 views
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/70312009/how-to-highlight-specific-subpanel-in-a-master-jpane">How to highlight specific subpanel in a master JPane?</a></h3>
# <div class="excerpt">
#             I am building a GUI for a maze-based game.
# The main JPanel is made up of smaller JPanels I call Tiles. My goal is to have a specific tile JPanel be highlighted when the player is in that cell. It ...
#         </div>
# <div class="d-flex ai-start fw-wrap">
# <div class="flex--item">
# <div class="d-flex gs4 fw-wrap tags t-java t-swing t-jframe t-jpanel">
# <a class="post-tag flex--item" href="/questions/tagged/java" rel="tag" title="show questions tagged 'java'">java</a> <a class="post-tag flex--item" href="/questions/tagged/swing" rel="tag" title="show questions tagged 'swing'">swing</a> <a class="post-tag flex--item" href="/questions/tagged/jframe" rel="tag" title="show questions tagged 'jframe'">jframe</a> <a class="post-tag flex--item" href="/questions/tagged/jpanel" rel="tag" title="show questions tagged 'jpanel'">jpanel</a> </div>
# </div>
# <div class="flex--item ml-auto fl-shrink0 started mt0">
# <div class="user-info ">
# <div class="user-action-time">
#         asked <span class="relativetime" title="2021-12-11 01:34:06Z">18 mins ago</span>
# </div>
# <div class="user-gravatar32">
# <a href="/users/7966156/nova"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/01e855e8cc4b0867c0685b6cbbd052ec?s=64&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
# </div>
# <div class="user-details">
# <a href="/users/7966156/nova">Nova</a>
# <div class="-flair">
# <span class="reputation-score" dir="ltr" title="reputation score ">466</span><span aria-hidden="true" title="2 silver badges"><span class="badge2"></span><span class="badgecount">2</span></span><span class="v-visible-sr">2 silver badges</span><span aria-hidden="true" title="12 bronze badges"><span class="badge3"></span><span class="badgecount">12</span></span><span class="v-visible-sr">12 bronze badges</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mln24">
# <div class="question-summary" id="question-summary-70311901">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post "><strong>-3</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status unanswered">
# <strong>0</strong>answers
#             </div>
# </div>
# <div class="views " title="16 views">
#     16 views
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/70311901/final-class-and-extending-from-other-classes">Final Class and extending from other classes? [closed]</a></h3>
# <div class="excerpt">
#             public class Parent {
# //implementation
# }
#
# public final class Child extends Parent {
# //implementation
# }
#
# public class Baby extends Parent {
# //implementation
# }
#
# What is wrong with this code given? My ...
#         </div>
# <div class="d-flex ai-start fw-wrap">
# <div class="flex--item">
# <div class="d-flex gs4 fw-wrap tags t-java t-class">
# <a class="post-tag flex--item" href="/questions/tagged/java" rel="tag" title="show questions tagged 'java'">java</a> <a class="post-tag flex--item" href="/questions/tagged/class" rel="tag" title="show questions tagged 'class'">class</a> </div>
# </div>
# <div class="flex--item ml-auto fl-shrink0 started mt0">
# <div class="user-info user-hover">
# <div class="user-action-time">
#         asked <span class="relativetime" title="2021-12-11 01:02:50Z">49 mins ago</span>
# </div>
# <div class="user-gravatar32">
# <a href="/users/10942422/minjun-seo"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/a4cf9778ea6fb3e9c9a0790b972db54f?s=64&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
# </div>
# <div class="user-details">
# <a href="/users/10942422/minjun-seo">Minjun Seo</a>
# <div class="-flair">
# <span class="reputation-score" dir="ltr" title="reputation score ">23</span><span aria-hidden="true" title="6 bronze badges"><span class="badge3"></span><span class="badgecount">6</span></span><span class="v-visible-sr">6 bronze badges</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mln24">
# <div class="question-summary" id="question-summary-70311829">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post "><strong>0</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status unanswered">
# <strong>0</strong>answers
#             </div>
# </div>
# <div class="views " title="8 views">
#     8 views
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/70311829/add-namespace-information-in-xml-root-element">add namespace information in xml root element</a></h3>
# <div class="excerpt">
#             I want to add xmlns:xsi and xsi:noNamespaceSchemaLocation in an xml root element.
# I need something like this:
# &lt;Product xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:...
#         </div>
# <div class="d-flex ai-start fw-wrap">
# <div class="flex--item">
# <div class="d-flex gs4 fw-wrap tags t-java t-xml t-xsd t-jaxb">
# <a class="post-tag flex--item" href="/questions/tagged/java" rel="tag" title="show questions tagged 'java'">java</a> <a class="post-tag flex--item" href="/questions/tagged/xml" rel="tag" title="show questions tagged 'xml'">xml</a> <a class="post-tag flex--item" href="/questions/tagged/xsd" rel="tag" title="show questions tagged 'xsd'">xsd</a> <a class="post-tag flex--item" href="/questions/tagged/jaxb" rel="tag" title="show questions tagged 'jaxb'">jaxb</a> </div>
# </div>
# <div class="flex--item ml-auto fl-shrink0 started mt0">
# <div class="user-info ">
# <div class="user-action-time">
#         asked <span class="relativetime" title="2021-12-11 00:45:18Z">1 hour ago</span>
# </div>
# <div class="user-gravatar32">
# <a href="/users/6865098/jeff"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/ed70071002fea7144ad7e46375548a5d?s=64&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
# </div>
# <div class="user-details">
# <a href="/users/6865098/jeff">jeff</a>
# <div class="-flair">
# <span class="reputation-score" dir="ltr" title="reputation score ">95</span><span aria-hidden="true" title="8 bronze badges"><span class="badge3"></span><span class="badgecount">8</span></span><span class="v-visible-sr">8 bronze badges</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mln24">
# <div class="question-summary" id="question-summary-70311774">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post "><strong>0</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status answered">
# <strong>1</strong>answer
#             </div>
# </div>
# <div class="views " title="10 views">
#     10 views
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/70311774/no-static-method-saveattributedataforstyleable-in-class-landroidx-core-view-view">No static method saveAttributeDataForStyleable in class Landroidx/core/view/ViewCompat; or its super classes</a></h3>
# <div class="excerpt">
#             I keep getting this exception in my Android app when inflating a View located from a separate library. java.lang.NoSuchMethodError: No static method saveAttributeDataForStyleable in class or its super ...
#         </div>
# <div class="d-flex ai-start fw-wrap">
# <div class="flex--item">
# <div class="d-flex gs4 fw-wrap tags t-java t-android">
# <a class="post-tag flex--item" href="/questions/tagged/java" rel="tag" title="show questions tagged 'java'">java</a> <a class="post-tag flex--item" href="/questions/tagged/android" rel="tag" title="show questions tagged 'android'">android</a> </div>
# </div>
# <div class="flex--item ml-auto fl-shrink0 started mt0">
# <div class="user-info ">
# <div class="user-action-time">
#         asked <span class="relativetime" title="2021-12-11 00:31:11Z">1 hour ago</span>
# </div>
# <div class="user-gravatar32">
# <a href="/users/12327726/zetatlas"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/e214e9a56bc2c192e3fba7e844a3d447?s=64&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
# </div>
# <div class="user-details">
# <a href="/users/12327726/zetatlas">zetatlas</a>
# <div class="-flair">
# <span class="reputation-score" dir="ltr" title="reputation score ">111</span><span aria-hidden="true" title="1 silver badge"><span class="badge2"></span><span class="badgecount">1</span></span><span class="v-visible-sr">1 silver badge</span><span aria-hidden="true" title="4 bronze badges"><span class="badge3"></span><span class="badgecount">4</span></span><span class="v-visible-sr">4 bronze badges</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mln24">
# <div class="question-summary" id="question-summary-70311772">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post "><strong>0</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status unanswered">
# <strong>0</strong>answers
#             </div>
# </div>
# <div class="views " title="11 views">
#     11 views
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/70311772/spring-boot-in-intellij-wont-load-image">Spring Boot in Intellij won't load image</a></h3>
# <div class="excerpt">
#             I'm just starting to learn Spring reading "Spring In Action" and I cannot get my image to load on anything other than port 8080 (where tomcat launches).  This would be fine normally, but I ...
#         </div>
# <div class="d-flex ai-start fw-wrap">
# <div class="flex--item">
# <div class="d-flex gs4 fw-wrap tags t-java t-spring-boot t-tomcat t-intellij-idea t-thymeleaf">
# ...
#     var clc = clc || {};
#     clc.collapse = { sb: !0, 'tag-sponsorship': !0, lb: !0, mlb: !0, smlb: !0, bmlb: !0, 'mobile-below-question': !0 };
#     clc.options = clc.options || {};
#     clc.options.sf = !0;
#     clc.options.hb = !1;
#     clc.options.ll = !0;
#     clc.options.targeting_consent = !1;
#     clc.options.performance_consent = !1;
#         clc.cmd = clc.cmd || [];
#         clc.cmd.push(function () { window.clc_request='A-bJV9dIvNkIAAAAAAAAAAACAAAAAQAAAAAABgAAAHxqYXZhfADyVs5sLHIJ5wuW'; clc.load(); });
#         StackExchange.ready(function () { googletag.cmd.push(function () { StackExchange.ads.init(googletag, '/ads/report-ad', 'Report this ad') }) });
# </script>
# <footer class="site-footer js-footer" id="footer" role="contentinfo">
# <div class="site-footer--container">
# <div class="site-footer--logo">
# <a href="https://stackoverflow.com"><svg aria-hidden="true" class="native svg-icon iconLogoGlyphMd" height="37" viewbox="0 0 32 37" width="32"><path d="M26 33v-9h4v13H0V24h4v9h22Z" fill="#BCBBBB"></path><path d="m21.5 0-2.7 2 9.9 13.3 2.7-2L21.5 0ZM26 18.4 13.3 7.8l2.1-2.5 12.7 10.6-2.1 2.5ZM9.1 15.2l15 7 1.4-3-15-7-1.4 3Zm14 10.79.68-2.95-16.1-3.35L7 23l16.1 2.99ZM23 30H7v-3h16v3Z" fill="#F48024"></path></svg></a>
# </div>
# <nav class="site-footer--nav">
# <div class="site-footer--col">
# <h5 class="-title"><a class="js-gps-track" data-gps-track="footer.click({ location: 5, link: 15})" href="https://stackoverflow.com">Stack Overflow</a></h5>
# <ul class="-list js-primary-footer-links">
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 16})" href="/questions">Questions</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 17})" href="https://stackoverflow.com/jobs">Jobs</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 11})" href="https://stackoverflow.com/jobs/directory/developer-jobs">Developer Jobs Directory</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 28})" href="https://stackoverflow.com/jobs/salary">Salary Calculator</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 3 })" href="/help">Help</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 12 })" onclick='StackExchange.switchMobile("on")'>Mobile</a></li>
# </ul>
# </div>
# <div class="site-footer--col">
# <h5 class="-title"><a class="js-gps-track" data-gps-track="footer.click({ location: 5, link: 19 })" href="https://stackoverflowbusiness.com">Products</a></h5>
# <ul class="-list">
# <li><a class="js-gps-track -link" data-ga='["teams traffic","footer - site nav","stackoverflow.com/teams",null,{"dimension4":"teams"}]' data-gps-track="footer.click({ location: 5, link: 29 })" href="https://stackoverflow.com/teams">Teams</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 20 })" href="https://stackoverflow.com/talent">Talent</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 21 })" href="https://stackoverflow.com/advertising">Advertising</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 22 })" href="https://stackoverflowsolutions.com/explore-teams">Enterprise</a></li>
# </ul>
# </div>
# <div class="site-footer--col">
# <h5 class="-title"><a class="js-gps-track" data-gps-track="footer.click({ location: 5, link: 1 })" href="https://stackoverflow.com/company">Company</a></h5>
# <ul class="-list">
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 1 })" href="https://stackoverflow.com/company">About</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 27 })" href="https://stackoverflow.com/company/press">Press</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 9 })" href="https://stackoverflow.com/company/work-here">Work Here</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 7 })" href="https://stackoverflow.com/legal">Legal</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 8 })" href="https://stackoverflow.com/legal/privacy-policy">Privacy Policy</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 37 })" href="https://stackoverflow.com/legal/terms-of-service">Terms of Service</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 13 })" href="https://stackoverflow.com/company/contact">Contact Us</a></li>
# <li class="" id="consent-footer-link"><a class="js-gps-track -link js-cookie-settings" data-consent-popup-loader="footer" data-gps-track="footer.click({ location: 5, link: 38 })" href="#">Cookie Settings</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link: 39 })" href="https://stackoverflow.com/legal/cookie-policy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="site-footer--col site-footer--categories-nav">
# <div>
# <h5 class="-title"><a data-gps-track="footer.click({ location: 5, link: 30 })" href="https://stackexchange.com">Stack Exchange Network</a></h5>
# <ul class="-list">
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#technology">
#                                     Technology
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#culturerecreation">
#                                     Culture &amp; recreation
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#lifearts">
#                                     Life &amp; arts
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#science">
#                                     Science
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#professional">
#                                     Professional
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://stackexchange.com/sites#business">
#                                     Business
#                                 </a>
# </li>
# <li class="mt16 md:mt0">
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://api.stackexchange.com/">
#                                     API
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 24 })" href="https://data.stackexchange.com/">
#                                     Data
#                                 </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="site-footer--copyright fs-fine md:mt24">
# <ul class="-list -social md:mb8">
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 5, link:4 })" href="https://stackoverflow.blog?blb=1">Blog</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 31 })" href="https://www.facebook.com/officialstackoverflow/">Facebook</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 32 })" href="https://twitter.com/stackoverflow">Twitter</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 33 })" href="https://linkedin.com/company/stack-overflow">LinkedIn</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 5, link: 36 })" href="https://www.instagram.com/thestackoverflow">Instagram</a></li>
# </ul>
# <p class="md:mb0">
# site design / logo © 2021 Stack Exchange Inc; user contributions licensed under <a href="https://stackoverflow.com/help/licensing">cc by-sa</a>.                    <span id="svnrev">rev 2021.12.10.40971</span>
# </p>
# </div>
# </div>
# </footer>
# <script>StackExchange.ready(function () { StackExchange.responsiveness.addSwitcher(); })</script>
# <noscript>
# <div id="noscript-warning">Stack Overflow works best with JavaScript enabled
#             <img alt="" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=17440561&amp;cv=3.6.0&amp;cj=1"/>
# </div>
# </noscript>
# <script>
# (function(i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function() { (i[r].q = i[r].q || []).push(arguments) }, i[r].l = 1 * new Date(); a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m);
#             })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#             StackExchange.ready(function () {
#
#                 StackExchange.ga.init({
#                     autoLink: ["stackoverflow.blog","info.stackoverflowsolutions.com","stackoverflowsolutions.com"],
#                     sendTitles: true,
#                     tracker: window.ga,
#                     trackingCodes: [
#                         'UA-108242619-1'
#                     ],
#                         checkDimension: 'dimension42'
#                 });
#
#
#
#                     StackExchange.ga.setDimension('dimension2', '|java|');
#
#
#                     StackExchange.ga.setDimension('dimension3', 'Questions/ListByTag');
#
#
#                 StackExchange.ga.setDimension('dimension7', "1639187528.1706722618");
#
#                 StackExchange.ga.trackPageView();
#             });
#                 </script>
# <div class="ff-sans ps-fixed z-nav-fixed ws4 sm:w-auto p32 sm:p16 bg-black-750 fc-white bar-lg b16 l16 r16 js-consent-banner">
# <svg aria-hidden="true" class="mln4 mb24 sm:d-none svg-spot spotCookieLg" height="96" style="color: var(--theme-button-filled-background-color)" viewbox="0 0 96 96" width="96">
# <path d="M35 45.5a7.5 7.5 0 11-15 0 7.5 7.5 0 0115 0zM63.5 63a7.5 7.5 0 100-15 7.5 7.5 0 000 15zm-19 19a7.5 7.5 0 100-15 7.5 7.5 0 000 15z" opacity=".2"></path>
# <path d="M56.99 2.53a23.1 23.1 0 0114.66 6.15h.01l.01.02c.57.55.61 1.27.5 1.74v.07a10.95 10.95 0 01-3.07 4.77 9 9 0 01-6.9 2.5 10.34 10.34 0 01-9.72-10.44v-.08a10 10 0 011.03-3.74l.01-.03.02-.02c.28-.5.82-.92 1.52-.95.63-.02 1.27-.02 1.93.01zm12.04 7.83a20.1 20.1 0 00-12.2-4.83l-.92-.03c-.23.6-.38 1.25-.43 1.94a7.34 7.34 0 006.95 7.34 6 6 0 004.64-1.7c.94-.88 1.6-1.9 1.96-2.72zm15.3 8.76a6.84 6.84 0 00-5.09-.24 7.9 7.9 0 00-3.28 2.05 1.8 1.8 0 00-.3 1.95l.02.02v.02a15.16 15.16 0 008.74 7.47c.64.23 1.32.08 1.8-.33a6.63 6.63 0 001.63-1.97l.01-.03.01-.03c1.67-3.5-.12-7.32-3.54-8.91zm-5.5 3.28c.36-.25.82-.5 1.35-.67.92-.3 1.92-.35 2.89.1 2.14 1 2.92 3.14 2.11 4.88-.12.21-.26.41-.43.6l-.26-.1a12.29 12.29 0 01-5.66-4.81zM32 24a2 2 0 11-4 0 2 2 0 014 0zm12 21a2 2 0 11-4 0 2 2 0 014 0zm36 4a2 2 0 11-4 0 2 2 0 014 0zm-7 21a2 2 0 11-4 0 2 2 0 014 0zM59 81a2 2 0 11-4 0 2 2 0 014 0zM22 63a2 2 0 11-4 0 2 2 0 014 0zm27 7a9 9 0 11-18 0 9 9 0 0118 0zm-3 0a6 6 0 10-12 0 6 6 0 0012 0zM33 41a9 9 0 11-18 0 9 9 0 0118 0zm-15 0a6 6 0 1012 0 6 6 0 00-12 0zm50 11a9 9 0 11-18 0 9 9 0 0118 0zm-3 0a6 6 0 10-12 0 6 6 0 0012 0zM44.08 4.24c.31.48.33 1.09.05 1.58a17.46 17.46 0 00-2.36 8.8c0 9.55 7.58 17.24 16.85 17.24 2.97 0 5.75-.78 8.16-2.15a1.5 1.5 0 012.1.66 12.08 12.08 0 0011 6.74 12.4 12.4 0 007.85-2.75 1.5 1.5 0 012.38.74A45.76 45.76 0 0192 48.16c0 24.77-19.67 44.9-44 44.9S4 72.93 4 48.16C4 25.23 20.84 6.28 42.64 3.58a1.5 1.5 0 011.44.66zM40.22 7C21.32 10.71 7 27.7 7 48.16c0 23.17 18.39 41.9 41 41.9s41-18.73 41-41.9c0-3.52-.42-6.93-1.22-10.2a15.5 15.5 0 01-7.9 2.15c-5.5 0-10.36-2.83-12.97-7.1a19.46 19.46 0 01-8.28 1.85c-11 0-19.86-9.1-19.86-20.24 0-2.7.52-5.26 1.45-7.62zM92 91a2 2 0 100-4 2 2 0 000 4zM7 8.5a2.5 2.5 0 11-5 0 2.5 2.5 0 015 0zM82.5 90a1.5 1.5 0 100-3 1.5 1.5 0 000 3zm9.5-7.5a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zM13.5 8a1.5 1.5 0 100-3 1.5 1.5 0 000 3zM80 14.5a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zM53.5 20a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path>
# </svg>
# <p class="fs-body2 fw-bold mb4">
#                         Your privacy
#                     </p>
# <p class="mb16 s-anchors s-anchors__inherit s-anchors__underlined">
#                         By clicking “Accept all cookies”, you agree Stack Exchange can store cookies on your device and disclose information in accordance with our <a href="https://stackoverflow.com/legal/cookie-policy">Cookie Policy</a>.
#                     </p>
# <div class="d-flex gs8 ai-stretch fd-column sm:fd-row">
# <button class="flex--item s-btn s-btn__primary js-accept-cookies js-consent-banner-hide">
#                             Accept all cookies
#                         </button>
# <button class="flex--item s-btn s-btn__filled js-cookie-settings" data-consent-popup-loader="banner">
#                             Customize settings
#                         </button>
# </div>
# </div>
# <div class="d-none" id="onetrust-consent-sdk"></div>
# <div data-controller="s-modal" id="onetrust-banner-sdk"></div>
# <div class="d-none" id="ot-pc-content"></div>
# <div class="d-none" id="onetrust-style"> </div>
# <div class="d-none js-consent-banner-version" data-consent-banner-version="baseline"></div>
# </body>

# %% [markdown]
# > Para identificar melhor o que você precisa, você pode inspecionar o código no navegador para encontrar a localização dos itens e nomes de ids;
#
# > A forma normalmente usada para busca os elementos são: **find() e find_all()**.
#
#
# ---
#
#
# "find()" é usada quando queremos recuperar apenas uma ocorrência da tag (a primeira encontrada será retornada) -> O retorno dele é uma tag, possibilitando a realização de pesquisas internas.
#
#
# ---
#
#
# "find_all()" vai buscar todas as ocorrências do elemento procurado imprimindo uma lista desses elementos. -> O retorno dele é um ResultSet,que permite que o usemos como uma lista.
#
#
# ---

# %%
divTitulo = soup.findAll('div', {'class': 'summary'}) # Busca por todas as divs que contém a classe com conteudo "summary";
arrayTitulo = []

for i in range(0, len(divTitulo)): # Percorrendo todas as divs que contem H3
  arrayTitulo.append(divTitulo[i].find('h3').get_text())# Adicionando ao Array todos titulos do StackOverflow de acordo com a pesquisa do usuário 
  print(arrayTitulo[i]) # Printando conteúdo
  print('\n')
# Out:
# Match every single String after character in Java (RegEx)
#
#
# How to highlight specific subpanel in a master JPane?
#
#
# Final Class and extending from other classes? [closed]
#
#
# add namespace information in xml root element
#
#
# No static method saveAttributeDataForStyleable in class Landroidx/core/view/ViewCompat; or its super classes
#
#
# Spring Boot in Intellij won't load image
#
#
# Implemented search functionality for a text file. Now trying to only pull the most recent line of the search result. (READ DESC) [duplicate]
#
#
# I want my button not in the same row as my choose buttons in my gui? How will I do that?
#
#
# Can I change the output device for a program in Java? [closed]
#
#
# Unit Circle Animation setting X as 1 three times instead of 1
#
#
# Implementing and using a generic, abstract interface in Java
#
#
# java coding error, how to get data by using array list to get output in console and add Gui to the code in same package [closed]
#
#
# Can't install Graalvm native-image on ubuntu 20.04.3 LTS
#
#
# HashMap.get returns true instead of an element
#
#
# Installing maven using `apt-get install` overwrites Java8 with Java11
#
#
# Flux - consume infinite flux multiple times
#
#
# How to test the KeyListener in WebView?
#
#
# Location of file that modifies $PATH
#
#
# Trying to pass data through Bundle always gives null
#
#
# Transform a DTO object List into a TreeModel to be used in a Tree Component
#
#
# Android Studio - Measure Decibels / Sound Level from a Fragment
#
#
# How can i find Joda-Time Jar file on my Mac?
#
#
# log4j-vulnerability - Is log4j1.2.17 vulnerable (was unable to find any jndi code in source)?
#
#
# Looking for Assitance with adding Paint to existing Graphics2D in java
#
#
# I get NoSuchElementException when I run Selenium tests in headless mode
#
#
# How can I shift the elements of an Array to the order I desire? [closed]
#
#
# How to set an array as a parameter for a constructor?
#
#
# How to make Java API documentation using Javadoc and openJDK code?
#
#
# Position a number on the position of another number on a 2d array
#
#
# Separate indicator from image slider Android Studio
#
#
# XML - Can't link pages with java XMLHttpRequest Object
#
#
# ¿Que estoy pasando por alto? [closed]
#
#
# How To Sort A Collection of Objects Comparing Strings That Can Be Null and Integer Based [duplicate]
#
#
# Separate float from text efficiently
#
#
# Java - Reading numbers (IDs) from file in one line separated by commas
#
#
# How to calculate using the tool Source Code Metrics in Netbeans
#
#
# Duplicate class in Android Studio (java app)
#
#
# How can i run Web Project in intellij community edition
#
#
# Connection Failure: Upstream connect error or disconnect/reset before headers
#
#
# SyntaxError: Unexpected token S in JSON at position 0 at JSON.parse (<anonymous>)
#
#
# Writing to a json file in the resources folder doesn't work
#
#
# createStoredProcedureQuery - returning wrong value?
#
#
# JUnit - Put Request testing returns status 405 - expected 200 - with Bearer Token
#
#
# Trying to use java with mysql but i get error [ help i need now ] please [closed]
#
#
# using an interface from a java file in a kotlin file [duplicate]
#
#
# What might be the cause for java.util.ConcurrentModificationException in Spring WebServiceTemplate
#
#
# Android App Does Not Show on Google Play Store for Samsung Note S20
#
#
# Is there a way to add personal local notes or annotations to lines of files without affecting the files themselves?
#
#
# Convert libgdx int keycode to non-QWERTY char
#
#
# java program birthday with sign [closed]

# %%
divLinks = soup.findAll('a', {'class': 'question-hyperlink'}) #Busca por Todos os Links da Class = question-hyperlink
arrayLink = []

for j in range(0, 50): #percorrendo Array
  arrayLink.append(divLinks[j]['href']) #Adicionando Links no array de links
  
  print(arrayLink[j]) #Printando todos os links
  print('\n')
# Out:
# /questions/70312057/match-every-single-string-after-character-in-java-regex
#
#
# /questions/70312009/how-to-highlight-specific-subpanel-in-a-master-jpane
#
#
# /questions/70311901/final-class-and-extending-from-other-classes
#
#
# /questions/70311829/add-namespace-information-in-xml-root-element
#
#
# /questions/70311774/no-static-method-saveattributedataforstyleable-in-class-landroidx-core-view-view
#
#
# /questions/70311772/spring-boot-in-intellij-wont-load-image
#
#
# /questions/70311568/implemented-search-functionality-for-a-text-file-now-trying-to-only-pull-the-mo
#
#
# /questions/70311550/i-want-my-button-not-in-the-same-row-as-my-choose-buttons-in-my-gui-how-will-i
#
#
# /questions/70311537/can-i-change-the-output-device-for-a-program-in-java
#
#
# /questions/70311523/unit-circle-animation-setting-x-as-1-three-times-instead-of-1
#
#
# /questions/70311451/implementing-and-using-a-generic-abstract-interface-in-java
#
#
# /questions/70311325/java-coding-error-how-to-get-data-by-using-array-list-to-get-output-in-console
#
#
# /questions/70311315/cant-install-graalvm-native-image-on-ubuntu-20-04-3-lts
#
#
# /questions/70311247/hashmap-get-returns-true-instead-of-an-element
#
#
# /questions/70311220/installing-maven-using-apt-get-install-overwrites-java8-with-java11
#
#
# /questions/70311179/flux-consume-infinite-flux-multiple-times
#
#
# /questions/70311156/how-to-test-the-keylistener-in-webview
#
#
# /questions/70311130/location-of-file-that-modifies-path
#
#
# /questions/70311127/trying-to-pass-data-through-bundle-always-gives-null
#
#
# /questions/70311120/transform-a-dto-object-list-into-a-treemodel-to-be-used-in-a-tree-component
#
#
# /questions/70311007/android-studio-measure-decibels-sound-level-from-a-fragment
#
#
# /questions/70310986/how-can-i-find-joda-time-jar-file-on-my-mac
#
#
# /questions/70310980/log4j-vulnerability-is-log4j1-2-17-vulnerable-was-unable-to-find-any-jndi-cod
#
#
# /questions/70310894/looking-for-assitance-with-adding-paint-to-existing-graphics2d-in-java
#
#
# /questions/70310851/i-get-nosuchelementexception-when-i-run-selenium-tests-in-headless-mode
#
#
# /questions/70310848/how-can-i-shift-the-elements-of-an-array-to-the-order-i-desire
#
#
# /questions/70310844/how-to-set-an-array-as-a-parameter-for-a-constructor
#
#
# /questions/70310690/how-to-make-java-api-documentation-using-javadoc-and-openjdk-code
#
#
# /questions/70310626/position-a-number-on-the-position-of-another-number-on-a-2d-array
#
#
# /questions/70310623/separate-indicator-from-image-slider-android-studio
#
#
# /questions/70310618/xml-cant-link-pages-with-java-xmlhttprequest-object
#
#
# /questions/70310545/que-estoy-pasando-por-alto
#
#
# /questions/70310447/how-to-sort-a-collection-of-objects-comparing-strings-that-can-be-null-and-integ
#
#
# /questions/70310397/separate-float-from-text-efficiently
#
#
# /questions/70310331/java-reading-numbers-ids-from-file-in-one-line-separated-by-commas
#
#
# /questions/70310283/how-to-calculate-using-the-tool-source-code-metrics-in-netbeans
#
#
# /questions/70310282/duplicate-class-in-android-studio-java-app
#
#
# /questions/70310267/how-can-i-run-web-project-in-intellij-community-edition
#
#
# /questions/70310263/connection-failure-upstream-connect-error-or-disconnect-reset-before-headers
#
#
# /questions/70310227/syntaxerror-unexpected-token-s-in-json-at-position-0-at-json-parse-anonymous
#
#
# /questions/70310173/writing-to-a-json-file-in-the-resources-folder-doesnt-work
#
#
# /questions/70310079/createstoredprocedurequery-returning-wrong-value
#
#
# /questions/70310069/junit-put-request-testing-returns-status-405-expected-200-with-bearer-toke
#
#
# /questions/70310057/trying-to-use-java-with-mysql-but-i-get-error-help-i-need-now-please
#
#
# /questions/70309985/using-an-interface-from-a-java-file-in-a-kotlin-file
#
#
# /questions/70309920/what-might-be-the-cause-for-java-util-concurrentmodificationexception-in-spring
#
#
# /questions/70309910/android-app-does-not-show-on-google-play-store-for-samsung-note-s20
#
#
# /questions/70309886/is-there-a-way-to-add-personal-local-notes-or-annotations-to-lines-of-files-with
#
#
# /questions/70309733/convert-libgdx-int-keycode-to-non-qwerty-char
#
#
# /questions/70309726/java-program-birthday-with-sign

# %%
dadosRetorno = {} 
#Printando tamanho dos array para verificar se estão do mesmo tamanho
print(len(arrayTitulo))
print(len(arrayLink))
#Adicionando dados dos titulos e links no dicionario
try:
  dadosRetorno ['titulos'] = arrayTitulo
  dadosRetorno ['links'] = arrayLink
except Exception as e:
  print(e)
# Out:
# 50
# 50

# %%
df = pd.DataFrame(dadosRetorno)#Gerando dataFrame com dados do dicionario  
df_csv_dados = df.to_csv('dados') #Tranformando e gerando em arquivo CSV
pd.read_csv('dados') # Lendo arquivo CSV
# Out:
#     Unnamed: 0  ...                                              links
# 0            0  ...  /questions/70312057/match-every-single-string-...
# 1            1  ...  /questions/70312009/how-to-highlight-specific-...
# 2            2  ...  /questions/70311901/final-class-and-extending-...
# 3            3  ...  /questions/70311829/add-namespace-information-...
# 4            4  ...  /questions/70311774/no-static-method-saveattri...
# 5            5  ...  /questions/70311772/spring-boot-in-intellij-wo...
# 6            6  ...  /questions/70311568/implemented-search-functio...
# 7            7  ...  /questions/70311550/i-want-my-button-not-in-th...
# 8            8  ...  /questions/70311537/can-i-change-the-output-de...
# 9            9  ...  /questions/70311523/unit-circle-animation-sett...
# 10          10  ...  /questions/70311451/implementing-and-using-a-g...
# 11          11  ...  /questions/70311325/java-coding-error-how-to-g...
# 12          12  ...  /questions/70311315/cant-install-graalvm-nativ...
# 13          13  ...  /questions/70311247/hashmap-get-returns-true-i...
# 14          14  ...  /questions/70311220/installing-maven-using-apt...
# 15          15  ...  /questions/70311179/flux-consume-infinite-flux...
# 16          16  ...  /questions/70311156/how-to-test-the-keylistene...
# 17          17  ...  /questions/70311130/location-of-file-that-modi...
# 18          18  ...  /questions/70311127/trying-to-pass-data-throug...
# 19          19  ...  /questions/70311120/transform-a-dto-object-lis...
# 20          20  ...  /questions/70311007/android-studio-measure-dec...
# 21          21  ...  /questions/70310986/how-can-i-find-joda-time-j...
# 22          22  ...  /questions/70310980/log4j-vulnerability-is-log...
# 23          23  ...  /questions/70310894/looking-for-assitance-with...
# 24          24  ...  /questions/70310851/i-get-nosuchelementexcepti...
# 25          25  ...  /questions/70310848/how-can-i-shift-the-elemen...
# 26          26  ...  /questions/70310844/how-to-set-an-array-as-a-p...
# 27          27  ...  /questions/70310690/how-to-make-java-api-docum...
# 28          28  ...  /questions/70310626/position-a-number-on-the-p...
# 29          29  ...  /questions/70310623/separate-indicator-from-im...
# 30          30  ...  /questions/70310618/xml-cant-link-pages-with-j...
# 31          31  ...     /questions/70310545/que-estoy-pasando-por-alto
# 32          32  ...  /questions/70310447/how-to-sort-a-collection-o...
# 33          33  ...  /questions/70310397/separate-float-from-text-e...
# 34          34  ...  /questions/70310331/java-reading-numbers-ids-f...
# 35          35  ...  /questions/70310283/how-to-calculate-using-the...
# 36          36  ...  /questions/70310282/duplicate-class-in-android...
# 37          37  ...  /questions/70310267/how-can-i-run-web-project-...
# 38          38  ...  /questions/70310263/connection-failure-upstrea...
# 39          39  ...  /questions/70310227/syntaxerror-unexpected-tok...
# 40          40  ...  /questions/70310173/writing-to-a-json-file-in-...
# 41          41  ...  /questions/70310079/createstoredprocedurequery...
# 42          42  ...  /questions/70310069/junit-put-request-testing-...
# 43          43  ...  /questions/70310057/trying-to-use-java-with-my...
# 44          44  ...  /questions/70309985/using-an-interface-from-a-...
# 45          45  ...  /questions/70309920/what-might-be-the-cause-fo...
# 46          46  ...  /questions/70309910/android-app-does-not-show-...
# 47          47  ...  /questions/70309886/is-there-a-way-to-add-pers...
# 48          48  ...  /questions/70309733/convert-libgdx-int-keycode...
# 49          49  ...  /questions/70309726/java-program-birthday-with...
#
# [50 rows x 3 columns]
